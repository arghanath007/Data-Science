# %% [markdown]
# # Exercise
#
# > Using `tf.keras.applications.EfficientNetB4` model for checking the accuracy score and if it is better than `tf.keras.applications.EfficientNetB0` model.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Imports

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import seaborn as sns
import tensorflow_datasets as tfds
from tensorflow.keras import layers
from tensorflow.keras.layers.experimental import preprocessing
from tensorflow.keras import regularizers
from tensorflow.keras import mixed_precision

import os
import random
import itertools

from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix

import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Helper Function

# %%
# !wget https://raw.githubusercontent.com/arghanath007/MachineLearning/main/Deep%20Learning/Transfer%20Learning/helper_functions.py
# Out:
# --2022-08-17 04:31:53--  https://raw.githubusercontent.com/arghanath007/MachineLearning/main/Deep%20Learning/Transfer%20Learning/helper_functions.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 19296 (19K) [text/plain]
# Saving to: ‘helper_functions.py’
#
# helper_functions.py 100%[===================>]  18.84K  --.-KB/s    in 0s
#
# 2022-08-17 04:31:53 (88.8 MB/s) - ‘helper_functions.py’ saved [19296/19296]

# %%
from helper_functions import unzip_data, plot_loss_curves, compare_historys, create_data_augmented_layer_for_model, load_and_prep_image, make_confusion_matrix_for_larger_dataset

# %% [markdown]
# ## Loading the dataset

# %%
(train_data, test_data), ds_info= tfds.load(name="food101", split=["train", "validation"], shuffle_files=False, as_supervised=True, with_info=True)
# Out:
# Downloading and preparing dataset 4.65 GiB (download: 4.65 GiB, generated: Unknown size, total: 4.65 GiB) to ~/tensorflow_datasets/food101/2.0.0...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
# Extraction completed...: 0 file [00:00, ? file/s]
# Generating splits...:   0%|          | 0/2 [00:00<?, ? splits/s]
# Generating train examples...:   0%|          | 0/75750 [00:00<?, ? examples/s]
# Shuffling ~/tensorflow_datasets/food101/2.0.0.incompleteA4VZO6/food101-train.tfrecord*...:   0%|          | 0/…
# Generating validation examples...:   0%|          | 0/25250 [00:00<?, ? examples/s]
# Shuffling ~/tensorflow_datasets/food101/2.0.0.incompleteA4VZO6/food101-validation.tfrecord*...:   0%|         …
# Dataset food101 downloaded and prepared to ~/tensorflow_datasets/food101/2.0.0. Subsequent calls will reuse this data.

# %%
ds_info
# Out:
# tfds.core.DatasetInfo(
#     name='food101',
#     full_name='food101/2.0.0',
#     description="""
#     This dataset consists of 101 food categories, with 101'000 images. For each class, 250 manually reviewed test images are provided as well as 750 training images. On purpose, the training images were not cleaned, and thus still contain some amount of noise. This comes mostly in the form of intense colors and sometimes wrong labels. All images were rescaled to have a maximum side length of 512 pixels.
#     """,
#     homepage='https://data.vision.ee.ethz.ch/cvl/datasets_extra/food-101/',
#     data_path='~/tensorflow_datasets/food101/2.0.0',
#     file_format=tfrecord,
#     download_size=4.65 GiB,
#     dataset_size=4.77 GiB,
#     features=FeaturesDict({
#         'image': Image(shape=(None, None, 3), dtype=tf.uint8),
#         'label': ClassLabel(shape=(), dtype=tf.int64, num_classes=101),
#     }),
#     supervised_keys=('image', 'label'),
#     disable_shuffling=False,
#     splits={
#         'train': <SplitInfo num_examples=75750, num_shards=32>,
#         'validation': <SplitInfo num_examples=25250, num_shards=16>,
#     },
#     citation="""@inproceedings{bossard14,
#       title = {Food-101 -- Mining Discriminative Components with Random Forests},
#       author = {Bossard, Lukas and Guillaumin, Matthieu and Van Gool, Luc},
#       booktitle = {European Conference on Computer Vision},
#       year = {2014}
#     }""",
# )

# %%
class_names= ds_info.features['label'].names
len(class_names)
# Out:
# 101

# %%
sample_1= train_data.take(5)
sample_1
# Out:
# <TakeDataset element_spec=(TensorSpec(shape=(None, None, 3), dtype=tf.uint8, name=None), TensorSpec(shape=(), dtype=tf.int64, name=None))>

# %%
for image, label in sample_1:
  print(f"""
  Image shape: {image.shape}
  Image dtype: {image.dtype}
  Target class or Label from Food101 (tensor form): {label}
  Class name (str form): {class_names[label.numpy()]}
        """)
# Out:
#   Image shape: (512, 512, 3)
#   Image dtype: <dtype: 'uint8'>
#   Target class or Label from Food101 (tensor form): 56
#   Class name (str form): huevos_rancheros
#
#
#   Image shape: (384, 512, 3)
#   Image dtype: <dtype: 'uint8'>
#   Target class or Label from Food101 (tensor form): 76
#   Class name (str form): pizza
#
#
#   Image shape: (512, 512, 3)
#   Image dtype: <dtype: 'uint8'>
#   Target class or Label from Food101 (tensor form): 21
#   Class name (str form): chocolate_cake
#
#
#   Image shape: (512, 512, 3)
#   Image dtype: <dtype: 'uint8'>
#   Target class or Label from Food101 (tensor form): 64
#   Class name (str form): miso_soup
#
#
#   Image shape: (512, 512, 3)
#   Image dtype: <dtype: 'uint8'>
#   Target class or Label from Food101 (tensor form): 10
#   Class name (str form): bruschetta

# %%
image.shape
# Out:
# TensorShape([512, 512, 3])

# %% [markdown]
# ## Plotting image from the dataset

# %%
plt.imshow(image/255)
plt.title(class_names[label.numpy()])
plt.axis(False);

# %% [markdown]
# ## Preprocessing Image Function

# %%
from helper_functions import preprocess_image

# %%
processed_image, processed_label= preprocess_image(image, label)

# %%
processed_image
# Out:
# <tf.Tensor: shape=(224, 224, 3), dtype=float32, numpy=
# array([[[ 12.943877  ,  12.943877  ,  12.943877  ],
#         [ 12.357142  ,  12.357142  ,  12.357142  ],
#         [ 11.280612  ,  11.280612  ,  11.280612  ],
#         ...,
#         [  1.        ,   5.        ,   4.        ],
#         [  0.92855835,   4.9285583 ,   3.9285583 ],
#         [  0.        ,   4.        ,   3.        ]],
#
#        [[ 11.        ,  11.        ,  11.        ],
#         [ 11.        ,  11.        ,  11.        ],
#         [ 11.928572  ,  11.928572  ,  11.928572  ],
#         ...,
#         [  1.9285717 ,   5.9285717 ,   4.9285717 ],
#         [  1.        ,   5.        ,   4.        ],
#         [  0.9744874 ,   4.9744873 ,   3.9744873 ]],
#
#        [[ 13.        ,  13.        ,  13.        ],
#         [ 12.801021  ,  12.801021  ,  12.801021  ],
#         [ 11.954082  ,  11.954082  ,  11.954082  ],
#         ...,
#         [  2.        ,   6.        ,   5.        ],
#         [  1.9438673 ,   5.943867  ,   4.943867  ],
#         [  1.1377478 ,   5.137748  ,   4.137748  ]],
#
#        ...,
#
#        [[158.57141   , 161.57141   , 176.57141   ],
#         [157.62749   , 160.62749   , 175.62749   ],
#         [161.23973   , 164.23973   , 179.6683    ],
#         ...,
#         [206.76033   , 216.40312   , 233.18886   ],
#         [211.5307    , 221.1735    , 237.95923   ],
#         [206.22444   , 215.86723   , 232.65297   ]],
#
#        [[155.64285   , 158.64285   , 173.64285   ],
#         [159.06636   , 162.06636   , 177.06636   ],
#         [158.82654   , 161.82654   , 177.2551    ],
#         ...,
#         [202.18881   , 211.18881   , 228.18881   ],
#         [207.57645   , 216.57645   , 233.57645   ],
#         [205.21931   , 214.21931   , 231.21931   ]],
#
#        [[158.48477   , 161.48477   , 176.48477   ],
#         [161.551     , 164.551     , 179.551     ],
#         [160.00514   , 163.00514   , 178.43372   ],
#         ...,
#         [198.92348   , 207.92348   , 224.92348   ],
#         [196.68875   , 205.68875   , 222.68875   ],
#         [201.35718   , 210.35718   , 227.35718   ]]], dtype=float32)>

# %%
processed_image_1, processed_label_1= preprocess_image(image, label, scaling=True)

# %%
processed_image_1
# Out:
# <tf.Tensor: shape=(224, 224, 3), dtype=float32, numpy=
# array([[[0.0507603 , 0.0507603 , 0.0507603 ],
#         [0.04845938, 0.04845938, 0.04845938],
#         [0.0442377 , 0.0442377 , 0.0442377 ],
#         ...,
#         [0.00392157, 0.01960784, 0.01568628],
#         [0.00364141, 0.01932768, 0.01540611],
#         [0.        , 0.01568628, 0.01176471]],
#
#        [[0.04313726, 0.04313726, 0.04313726],
#         [0.04313726, 0.04313726, 0.04313726],
#         [0.04677871, 0.04677871, 0.04677871],
#         ...,
#         [0.00756303, 0.0232493 , 0.01932773],
#         [0.00392157, 0.01960784, 0.01568628],
#         [0.00382152, 0.01950779, 0.01558622]],
#
#        [[0.05098039, 0.05098039, 0.05098039],
#         [0.05020008, 0.05020008, 0.05020008],
#         [0.04687875, 0.04687875, 0.04687875],
#         ...,
#         [0.00784314, 0.02352941, 0.01960784],
#         [0.00762301, 0.02330928, 0.01938771],
#         [0.00446176, 0.02014803, 0.01622646]],
#
#        ...,
#
#        [[0.62184864, 0.63361335, 0.69243693],
#         [0.618147  , 0.6299117 , 0.68873525],
#         [0.63231266, 0.64407736, 0.70458156],
#         ...,
#         [0.8108248 , 0.84863967, 0.9144661 ],
#         [0.82953215, 0.867347  , 0.9331734 ],
#         [0.8087233 , 0.8465382 , 0.9123646 ]],
#
#        [[0.61036414, 0.62212884, 0.68095237],
#         [0.62378967, 0.6355544 , 0.6943779 ],
#         [0.62284917, 0.6346139 , 0.695118  ],
#         ...,
#         [0.7928973 , 0.8281914 , 0.89485806],
#         [0.8140253 , 0.8493194 , 0.91598606],
#         [0.8047816 , 0.84007573, 0.9067424 ]],
#
#        [[0.6215089 , 0.6332736 , 0.6920971 ],
#         [0.6335333 , 0.645298  , 0.70412153],
#         [0.62747115, 0.63923585, 0.69974005],
#         ...,
#         [0.78009206, 0.8153862 , 0.88205284],
#         [0.77132845, 0.80662256, 0.8732892 ],
#         [0.789636  , 0.82493013, 0.8915968 ]]], dtype=float32)>

# %%
print("original Image")
plt.imshow(image)
plt.title(class_names[label.numpy()])
print(f"""Image shape: {image.shape} Image dtype: {image.dtype} Target class or Label from Food101 (tensor form): {label}
    Class name (str form): {class_names[label.numpy()]}""")
plt.axis(False);
# Out:
# original Image
# Image shape: (512, 512, 3) Image dtype: <dtype: 'uint8'> Target class or Label from Food101 (tensor form): 10
#     Class name (str form): bruschetta

# %%
print("original Image")
plt.imshow(processed_image)
plt.title(class_names[processed_label.numpy()])
print(f"""Image shape: {processed_image.shape} Image dtype: {processed_image.dtype} Target class or Label from Food101 (tensor form): {processed_label}
    Class name (str form): {class_names[processed_label.numpy()]}""")
plt.axis(False);
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# original Image
# Image shape: (224, 224, 3) Image dtype: <dtype: 'float32'> Target class or Label from Food101 (tensor form): 10
#     Class name (str form): bruschetta

# %%
print("original Image")
plt.imshow(processed_image_1)
plt.title(class_names[processed_label_1.numpy()])
print(f"""Image shape: {processed_image_1.shape} Image dtype: {processed_image_1.dtype} Target class or Label from Food101 (tensor form): {processed_label_1}
    Class name (str form): {class_names[processed_label_1.numpy()]}""")
plt.axis(False);
# Out:
# original Image
# Image shape: (224, 224, 3) Image dtype: <dtype: 'float32'> Target class or Label from Food101 (tensor form): 10
#     Class name (str form): bruschetta

# %% [markdown]
# ## Creating the `train and test` dataset batches

# %%
train_data= train_data.map(map_func= preprocess_image, num_parallel_calls=tf.data.AUTOTUNE)
train_data= train_data.shuffle(buffer_size=1000).batch(32).prefetch(buffer_size=tf.data.AUTOTUNE) # Shuffeling the training dataset
test_data= test_data.map(map_func=preprocess_image, num_parallel_calls=tf.data.AUTOTUNE).batch(32).prefetch(tf.data.AUTOTUNE)

# %%
train_data, test_data
# Out:
# (<PrefetchDataset element_spec=(TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int64, name=None))>,
#  <PrefetchDataset element_spec=(TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int64, name=None))>)

# %% [markdown]
# ## Feature Extraction Model Callbacks

# %%
from helper_functions import  create_tensorboard_callback, model_check_point_callback, create_early_stopping_callback, reduce_learning_rate_callback

# %%
# Model Checkpoint Callback
checkpoint_feature_extraction= 'checkpoints/feature_extraction_model'
checkpoint_callback=model_check_point_callback(checkpoint_feature_extraction, save_weights_only=True, save_best_only=True, monitor="val_loss")

# Tensorboard Callback
tensorboard_callback= create_tensorboard_callback("transfer_learning", "101_classes_feature_extraction_all_data")

# Early Stopping Callback
early_stopping_callback= create_early_stopping_callback(monitor="val_accuracy", patience=5)

# Learning Rate Scheduler

def scheduler(epoch, lr):
  if epoch < 5:
    return lr
  else:
    return lr * tf.math.exp(-0.1)

lr_scheduler_callback = tf.keras.callbacks.LearningRateScheduler(scheduler)

## Reduce Learing Rate Callback

learning_rate_reduce_callback= reduce_learning_rate_callback(monitor="val_loss", factor=0.2, patience=2, minimum_lr=1e-7)
# Out:
# Saving TensorBoard log files to: transfer_learning/101_classes_feature_extraction_all_data/20220817-044148

# %% [markdown]
# ## Augmented Layer

# %%
augmented_layer=create_data_augmented_layer_for_model(RandomFlip="horizontal", RandomRotation=0.2, RandomZoom=0.2, RandomHeight=0.2, RandomWidth=0.2)
augmented_layer

# %% [markdown]
# ## Turning on Mixed Precision Training

# %%
mixed_precision.set_global_policy("mixed_float16")

# %%
mixed_precision.global_policy()
# Out:
# <Policy "mixed_float16">

# %% [markdown]
# ## Feature Extraction Model

# %%
# Create base model
input_shape = (224, 224, 3)
CLASS_COUNT= len(class_names)
base_model = tf.keras.applications.EfficientNetB4(include_top=False)
base_model.trainable = False # freeze base model layers

# Create Functional model 
inputs = layers.Input(shape=input_shape, name="input_layer")
# Note: EfficientNetBX models have rescaling built-in but if your model didn't you could have a layer like below
# x = preprocessing.Rescaling(1./255)(x)
x= augmented_layer(inputs)
x = base_model(x, training=False) # set base_model to inference mode only
x = layers.GlobalAveragePooling2D(name="pooling_layer")(x)
x=  tf.keras.layers.Dropout(0.2, name="dropout_layer")(x) # Dropout Layer
x= layers.Dense(units= CLASS_COUNT,kernel_regularizer=regularizers.L1L2(l1=1e-5, l2=1e-4),bias_regularizer=regularizers.L2(1e-4), activity_regularizer=regularizers.L2(1e-5), name='regularization_layer')(x) # Regularization Layer
x = layers.Dense(CLASS_COUNT)(x) # want one output neuron per class 
# Separate activation of output layer so we can output float32 activations
outputs = layers.Activation("softmax", dtype=tf.float32, name="softmax_float32")(x) 
model = tf.keras.Model(inputs, outputs)

# Compile the model
model.compile(loss="sparse_categorical_crossentropy", # Use sparse_categorical_crossentropy when labels are *not* one-hot
              optimizer=tf.keras.optimizers.Adam(),
              metrics=["accuracy"])
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb4_notop.h5
# 71688192/71686520 [==============================] - 0s 0us/step
# 71696384/71686520 [==============================] - 0s 0us/step

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_layer (InputLayer)    [(None, 224, 224, 3)]     0
#
#  efficientnetb4 (Functional)  (None, None, None, 1792)  17673823
#
#  pooling_layer (GlobalAverag  (None, 1792)             0
#  ePooling2D)
#
#  dropout_layer (Dropout)     (None, 1792)              0
#
#  regularization_layer (Dense  (None, 101)              181093
#  )
#
#  dense (Dense)               (None, 101)               10302
#
#  softmax_float32 (Activation  (None, 101)              0
#  )
#
# =================================================================
# Total params: 17,865,218
# Trainable params: 191,395
# Non-trainable params: 17,673,823
# _________________________________________________________________

# %%
for layer in base_model.layers:
  print(layer, layer.name, layer.dtype, layer.dtype_policy)
# Out:
# <keras.engine.input_layer.InputLayer object at 0x7f7f8f589210> input_1 float32 <Policy "float32">
# <keras.layers.preprocessing.image_preprocessing.Rescaling object at 0x7f7f8ec65610> rescaling float32 <Policy "mixed_float16">
# <keras.layers.preprocessing.normalization.Normalization object at 0x7f7f9306a710> normalization float32 <Policy "mixed_float16">
# <keras.layers.convolutional.ZeroPadding2D object at 0x7f7f8f56a250> stem_conv_pad float32 <Policy "mixed_float16">
# <keras.layers.convolutional.Conv2D object at 0x7f7f93063b50> stem_conv float32 <Policy "mixed_float16">
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7f8f44d0d0> stem_bn float32 <Policy "mixed_float16">
# <keras.layers.core.activation.Activation object at 0x7f7f93779d10> stem_activation float32 <Policy "mixed_float16">
# <keras.layers.convolutional.DepthwiseConv2D object at 0x7f7f8f519dd0> block1a_dwconv float32 <Policy "mixed_float16">
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7f8f4f8410> block1a_bn float32 <Policy "mixed_float16">
# <keras.layers.core.activation.Activation object at 0x7f7f8f4ebe10> block1a_activation float32 <Policy "mixed_float16">
# <keras.layers.pooling.GlobalAveragePooling2D object at 0x7f7f8f4ebfd0> block1a_se_squeeze float32 <Policy "mixed_float16">
# <keras.layers.core.reshape.Reshape object at 0x7f7f93319f50> block1a_se_reshape float32 <Policy "mixed_float16">
# <keras.layers.convolutional.Conv2D object at 0x7f7f9308a4d0> block1a_se_reduce float32 <Policy "mixed_float16">
# <keras.layers.convolutional.Conv2D object at 0x7f7f932f35d0> block1a_se_expand float32 <Policy "mixed_float16">
# <keras.layers.merge.Multiply object at 0x7f7f93311990> block1a_se_excite float32 <Policy "mixed_float16">
# <keras.layers.convolutional.Conv2D object at 0x7f7f8ec6f350> block1a_project_conv float32 <Policy "mixed_float16">
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7f8ec6fcd0> block1a_project_bn float32 <Policy "mixed_float16">
# <keras.layers.convolutional.DepthwiseConv2D object at 0x7f7f93309110> block1b_dwconv float32 <Policy "mixed_float16">
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7f932e4950> block1b_bn float32 <Policy "mixed_float16">
# <keras.layers.core.activation.Activation object at 0x7f7f8f158410> block1b_activation float32 <Policy "mixed_float16">
# <keras.layers.pooling.GlobalAveragePooling2D object at 0x7f7f8f56bc90> block1b_se_squeeze float32 <Policy "mixed_float16">
# <keras.layers.core.reshape.Reshape object at 0x7f7f93070b90> block1b_se_reshape float32 <Policy "mixed_float16">
# <keras.layers.convolutional.Conv2D object at 0x7f7f8f15e110> block1b_se_reduce float32 <Policy "mixed_float16">
# <keras.layers.convolutional.Conv2D object at 0x7f7f8f5830d0> block1b_se_expand float32 <Policy "mixed_float16">
# <keras.layers.merge.Multiply object at 0x7f7f8f150310> block1b_se_excite float32 <Policy "mixed_float16">
# <keras.layers.convolutional.Conv2D object at 0x7f7f9377d210> block1b_project_conv float32 <Policy "mixed_float16">
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7f930da950> block1b_project_bn float32 <Policy "mixed_float16">
# <keras.layers.core.dropout.Dropout object at 0x7f7f8f138f90> block1b_drop float32 <Policy "mixed_float16">
# <keras.layers.merge.Add object at 0x7f7f950d4250> block1b_add float32 <Policy "mixed_float16">
# <keras.layers.convolutional.Conv2D object at 0x7f7f8f59b390> block2a_expand_conv float32 <Policy "mixed_float16">
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7f8f12ff50> block2a_expand_bn float32 <Policy "mixed_float16">
# <keras.layers.core.activation.Activation object at 0x7f7f93062090> block2a_expand_activation float32 <Policy "mixed_float16">
# <keras.layers.convolutional.ZeroPadding2D object at 0x7f7f8f12ac10> block2a_dwconv_pad float32 <Policy "mixed_float16">
# <keras.layers.convolutional.DepthwiseConv2D object at 0x7f7f8f8521d0> block2a_dwconv float32 <Policy "mixed_float16">
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7f8f85ad10> block2a_bn float32 <Policy "mixed_float16">
# <keras.layers.core.activation.Activation object at 0x7f7f9377d310> block2a_activation float32 <Policy "mixed_float16">
# <keras.layers.pooling.GlobalAveragePooling2D object at 0x7f7f8ed07d90> block2a_se_squeeze float32 <Policy "mixed_float16">
# <keras.layers.core.reshape.Reshape object at 0x7f7f8ec65950> block2a_se_reshape float32 <Policy "mixed_float16">
# <keras.layers.convolutional.Conv2D object at 0x7f7f8f83f2d0> block2a_se_reduce float32 <Policy "mixed_float16">
# <keras.layers.convolutional.Conv2D object at 0x7f7f8f824290> block2a_se_expand float32 <Policy "mixed_float16">
# <keras.layers.merge.Multiply object at 0x7f7f8f83a650> block2a_se_excite float32 <Policy "mixed_float16">
# <keras.layers.convolutional.Conv2D object at 0x7f7f8f83aa90> block2a_project_conv float32 <Policy "mixed_float16">
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7f8fe9f6d0> block2a_project_bn float32 <Policy "mixed_float16">
# <keras.layers.convolutional.Conv2D object at 0x7f7f8fe9fb10> block2b_expand_conv float32 <Policy "mixed_float16">
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7f8f822510> block2b_expand_bn float32 <Policy "mixed_float16">
# <keras.layers.core.activation.Activation object at 0x7f7f8fe86410> block2b_expand_activation float32 <Policy "mixed_float16">
# <keras.layers.convolutional.DepthwiseConv2D object at 0x7f7f8fe84610> block2b_dwconv float32 <Policy "mixed_float16">
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7f8fe7a490> block2b_bn float32 <Policy "mixed_float16">
# <keras.layers.core.activation.Activation object at 0x7f7f8fe92350> block2b_activation float32 <Policy "mixed_float16">
# <keras.layers.pooling.GlobalAveragePooling2D object at 0x7f7f8fe81e50> block2b_se_squeeze float32 <Policy "mixed_float16">
# <keras.layers.core.reshape.Reshape object at 0x7f7f8fe84c90> block2b_se_reshape float32 <Policy "mixed_float16">
# <keras.layers.convolutional.Conv2D object at 0x7f7f8f833cd0> block2b_se_reduce float32 <Policy "mixed_float16">
# <keras.layers.convolutional.Conv2D object at 0x7f7f8f13c1d0> block2b_se_expand float32 <Policy "mixed_float16">
# <keras.layers.merge.Multiply object at 0x7f7f8f82ded0> block2b_se_excite float32 <Policy "mixed_float16">
# <keras.layers.convolutional.Conv2D object at 0x7f7f93309c90> block2b_project_conv float32 <Policy "mixed_float16">
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7f8fe71290> block2b_project_bn float32 <Policy "mixed_float16">
# <keras.layers.core.dropout.Dropout object at 0x7f7f8fe6fa90> block2b_drop float32 <Policy "mixed_float16">
# <keras.layers.merge.Add object at 0x7f7f8fe6d3d0> block2b_add float32 <Policy "mixed_float16">
# <keras.layers.convolutional.Conv2D object at 0x7f7f8ec6f810> block2c_expand_conv float32 <Policy "mixed_float16">
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7f931bec90> block2c_expand_bn float32 <Policy "mixed_float16">
# <keras.layers.core.activation.Activation object at 0x7f7f8fe64c90> block2c_expand_activation float32 <Policy "mixed_float16">
# <keras.layers.convolutional.DepthwiseConv2D object at 0x7f7f8fe62b90> block2c_dwconv float32 <Policy "mixed_float16">
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7f931d1bd0> block2c_bn float32 <Policy "mixed_float16">
# <keras.layers.core.activation.Activation object at 0x7f7f8fe62e90> block2c_activation float32 <Policy "mixed_float16">
# <keras.layers.pooling.GlobalAveragePooling2D object at 0x7f7f8fe62d10> block2c_se_squeeze float32 <Policy "mixed_float16">
# <keras.layers.core.reshape.Reshape object at 0x7f7f931b2950> block2c_se_reshape float32 <Policy "mixed_float16">
# <keras.layers.convolutional.Conv2D object at 0x7f7f931b2f50> block2c_se_reduce float32 <Policy "mixed_float16">
# <keras.layers.convolutional.Conv2D object at 0x7f7f931a6990> block2c_se_expand float32 <Policy "mixed_float16">
# <keras.layers.merge.Multiply object at 0x7f7f934c85d0> block2c_se_excite float32 <Policy "mixed_float16">
# <keras.layers.convolutional.Conv2D object at 0x7f7f934c8bd0> block2c_project_conv float32 <Policy "mixed_float16">
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7f934d7d10> block2c_project_bn float32 <Policy "mixed_float16">
# <keras.layers.core.dropout.Dropout object at 0x7f7f934d0d10> block2c_drop float32 <Policy "mixed_float16">
# <keras.layers.merge.Add object at 0x7f7f934d0b50> block2c_add float32 <Policy "mixed_float16">
# <keras.layers.convolutional.Conv2D object at 0x7f7f8f583e10> block2d_expand_conv float32 <Policy "mixed_float16">
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7f934bdb90> block2d_expand_bn float32 <Policy "mixed_float16">
# <keras.layers.core.activation.Activation object at 0x7f7f934b5990> block2d_expand_activation float32 <Policy "mixed_float16">
# <keras.layers.convolutional.DepthwiseConv2D object at 0x7f7f934b9ed0> block2d_dwconv float32 <Policy "mixed_float16">
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7f934a8f50> block2d_bn float32 <Policy "mixed_float16">
# <keras.layers.core.activation.Activation object at 0x7f7f934b8d90> block2d_activation float32 <Policy "mixed_float16">
# <keras.layers.pooling.GlobalAveragePooling2D object at 0x7f7f934b8550> block2d_se_squeeze float32 <Policy "mixed_float16">
# <keras.layers.core.reshape.Reshape object at 0x7f7f934b8750> block2d_se_reshape float32 <Policy "mixed_float16">
# <keras.layers.convolutional.Conv2D object at 0x7f7f93631e10> block2d_se_reduce float32 <Policy "mixed_float16">
# <keras.layers.convolutional.Conv2D object at 0x7f7f9362db50> block2d_se_expand float32 <Policy "mixed_float16">
# <keras.layers.merge.Multiply object at 0x7f7f93645c10> block2d_se_excite float32 <Policy "mixed_float16">
# <keras.layers.convolutional.Conv2D object at 0x7f7f93635490> block2d_project_conv float32 <Policy "mixed_float16">
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7f93779f10> block2d_project_bn float32 <Policy "mixed_float16">
# <keras.layers.core.dropout.Dropout object at 0x7f7f936572d0> block2d_drop float32 <Policy "mixed_float16">
# <keras.layers.merge.Add object at 0x7f7f94059a10> block2d_add float32 <Policy "mixed_float16">
# <keras.layers.convolutional.Conv2D object at 0x7f7f94059b50> block3a_expand_conv float32 <Policy "mixed_float16">
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7f9364e5d0> block3a_expand_bn float32 <Policy "mixed_float16">
# <keras.layers.core.activation.Activation object at 0x7f7f93631290> block3a_expand_activation float32 <Policy "mixed_float16">
# <keras.layers.convolutional.ZeroPadding2D object at 0x7f7f93639310> block3a_dwconv_pad float32 <Policy "mixed_float16">
# <keras.layers.convolutional.DepthwiseConv2D object at 0x7f7f93631550> block3a_dwconv float32 <Policy "mixed_float16">
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7f934c4190> block3a_bn float32 <Policy "mixed_float16">
# <keras.layers.core.activation.Activation object at 0x7f7f931b91d0> block3a_activation float32 <Policy "mixed_float16">
# <keras.layers.pooling.GlobalAveragePooling2D object at 0x7f7f931a61d0> block3a_se_squeeze float32 <Policy "mixed_float16">
# <keras.layers.core.reshape.Reshape object at 0x7f7f8ec6f310> block3a_se_reshape float32 <Policy "mixed_float16">
# <keras.layers.convolutional.Conv2D object at 0x7f7f8fe6d1d0> block3a_se_reduce float32 <Policy "mixed_float16">
# <keras.layers.convolutional.Conv2D object at 0x7f7f94061890> block3a_se_expand float32 <Policy "mixed_float16">
# <keras.layers.merge.Multiply object at 0x7f7f9402b890> block3a_se_excite float32 <Policy "mixed_float16">
# <keras.layers.convolutional.Conv2D object at 0x7f7f9404b110> block3a_project_conv float32 <Policy "mixed_float16">
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7f94053410> block3a_project_bn float32 <Policy "mixed_float16">
# <keras.layers.convolutional.Conv2D object at 0x7f7f94050750> block3b_expand_conv float32 <Policy "mixed_float16">
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7f94058e90> block3b_expand_bn float32 <Policy "mixed_float16">
# <keras.layers.core.activation.Activation object at 0x7f7f94048290> block3b_expand_activation float32 <Policy "mixed_float16">
# <keras.layers.convolutional.DepthwiseConv2D object at 0x7f7f94043910> block3b_dwconv float32 <Policy "mixed_float16">
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7f94035950> block3b_bn float32 <Policy "mixed_float16">
# <keras.layers.core.activation.Activation object at 0x7f7f94024a10> block3b_activation float32 <Policy "mixed_float16">
# <keras.layers.pooling.GlobalAveragePooling2D object at 0x7f7f94024d90> block3b_se_squeeze float32 <Policy "mixed_float16">
# <keras.layers.core.reshape.Reshape object at 0x7f7f94037d10> block3b_se_reshape float32 <Policy "mixed_float16">
# <keras.layers.convolutional.Conv2D object at 0x7f7f9421c810> block3b_se_reduce float32 <Policy "mixed_float16">
# <keras.layers.convolutional.Conv2D object at 0x7f7f94215710> block3b_se_expand float32 <Policy "mixed_float16">
# <keras.layers.merge.Multiply object at 0x7f7f9420d810> block3b_se_excite float32 <Policy "mixed_float16">
# <keras.layers.convolutional.Conv2D object at 0x7f7f941fce90> block3b_project_conv float32 <Policy "mixed_float16">
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7f9420e410> block3b_project_bn float32 <Policy "mixed_float16">
# <keras.layers.core.dropout.Dropout object at 0x7f7f94200210> block3b_drop float32 <Policy "mixed_float16">
# <keras.layers.merge.Add object at 0x7f7f941f0e50> block3b_add float32 <Policy "mixed_float16">
# <keras.layers.convolutional.Conv2D object at 0x7f7f941f0250> block3c_expand_conv float32 <Policy "mixed_float16">
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7f94200a50> block3c_expand_bn float32 <Policy "mixed_float16">
# <keras.layers.core.activation.Activation object at 0x7f7f9438a390> block3c_expand_activation float32 <Policy "mixed_float16">
# <keras.layers.convolutional.DepthwiseConv2D object at 0x7f7f943a0e90> block3c_dwconv float32 <Policy "mixed_float16">
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7f9437e950> block3c_bn float32 <Policy "mixed_float16">
# <keras.layers.core.activation.Activation object at 0x7f7f943797d0> block3c_activation float32 <Policy "mixed_float16">
# <keras.layers.pooling.GlobalAveragePooling2D object at 0x7f7f9308a910> block3c_se_squeeze float32 <Policy "mixed_float16">
# <keras.layers.core.reshape.Reshape object at 0x7f7f94379b10> block3c_se_reshape float32 <Policy "mixed_float16">
# <keras.layers.convolutional.Conv2D object at 0x7f7f94371190> block3c_se_reduce float32 <Policy "mixed_float16">
# <keras.layers.convolutional.Conv2D object at 0x7f7f94363990> block3c_se_expand float32 <Policy "mixed_float16">
# <keras.layers.merge.Multiply object at 0x7f7f94379810> block3c_se_excite float32 <Policy "mixed_float16">
# <keras.layers.convolutional.Conv2D object at 0x7f7f94379510> block3c_project_conv float32 <Policy "mixed_float16">
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7f942156d0> block3c_project_bn float32 <Policy "mixed_float16">
# <keras.layers.core.dropout.Dropout object at 0x7f7f9438f990> block3c_drop float32 <Policy "mixed_float16">
# <keras.layers.merge.Add object at 0x7f7f940283d0> block3c_add float32 <Policy "mixed_float16">
# <keras.layers.convolutional.Conv2D object at 0x7f7f9403ded0> block3d_expand_conv float32 <Policy "mixed_float16">
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7f931a6090> block3d_expand_bn float32 <Policy "mixed_float16">
# <keras.layers.core.activation.Activation object at 0x7f7f9404c850> block3d_expand_activation float32 <Policy "mixed_float16">
# <keras.layers.convolutional.DepthwiseConv2D object at 0x7f7f9403d310> block3d_dwconv float32 <Policy "mixed_float16">
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7f944c4950> block3d_bn float32 <Policy "mixed_float16">
# <keras.layers.core.activation.Activation object at 0x7f7f940482d0> block3d_activation float32 <Policy "mixed_float16">
# <keras.layers.pooling.GlobalAveragePooling2D object at 0x7f7f944c4d10> block3d_se_squeeze float32 <Policy "mixed_float16">
# <keras.layers.core.reshape.Reshape object at 0x7f7f944c12d0> block3d_se_reshape float32 <Policy "mixed_float16">
# <keras.layers.convolutional.Conv2D object at 0x7f7f944c1ed0> block3d_se_reduce float32 <Policy "mixed_float16">
# <keras.layers.convolutional.Conv2D object at 0x7f7f944b2850> block3d_se_expand float32 <Policy "mixed_float16">
# <keras.layers.merge.Multiply object at 0x7f7f944be410> block3d_se_excite float32 <Policy "mixed_float16">
# <keras.layers.convolutional.Conv2D object at 0x7f7f944be8d0> block3d_project_conv float32 <Policy "mixed_float16">
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7f944aa550> block3d_project_bn float32 <Policy "mixed_float16">
# <keras.layers.core.dropout.Dropout object at 0x7f7f944a2dd0> block3d_drop float32 <Policy "mixed_float16">
# <keras.layers.merge.Add object at 0x7f7f944a2610> block3d_add float32 <Policy "mixed_float16">
# <keras.layers.convolutional.Conv2D object at 0x7f7f94648610> block4a_expand_conv float32 <Policy "mixed_float16">
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7f94660910> block4a_expand_bn float32 <Policy "mixed_float16">
# <keras.layers.core.activation.Activation object at 0x7f7f9464d650> block4a_expand_activation float32 <Policy "mixed_float16">
# <keras.layers.convolutional.ZeroPadding2D object at 0x7f7f9464dd50> block4a_dwconv_pad float32 <Policy "mixed_float16">
# <keras.layers.convolutional.DepthwiseConv2D object at 0x7f7f9463d610> block4a_dwconv float32 <Policy "mixed_float16">
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7f94643d90> block4a_bn float32 <Policy "mixed_float16">
# <keras.layers.core.activation.Activation object at 0x7f7f94643fd0> block4a_activation float32 <Policy "mixed_float16">
# <keras.layers.pooling.GlobalAveragePooling2D object at 0x7f7f94646a50> block4a_se_squeeze float32 <Policy "mixed_float16">
# <keras.layers.core.reshape.Reshape object at 0x7f7f94637e50> block4a_se_reshape float32 <Policy "mixed_float16">
# <keras.layers.convolutional.Conv2D object at 0x7f7f946305d0> block4a_se_reduce float32 <Policy "mixed_float16">
# <keras.layers.convolutional.Conv2D object at 0x7f7f9468c7d0> block4a_se_expand float32 <Policy "mixed_float16">
# <keras.layers.merge.Multiply object at 0x7f7f94699210> block4a_se_excite float32 <Policy "mixed_float16">
# <keras.layers.convolutional.Conv2D object at 0x7f7f94699590> block4a_project_conv float32 <Policy "mixed_float16">
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7f94682710> block4a_project_bn float32 <Policy "mixed_float16">
# <keras.layers.convolutional.Conv2D object at 0x7f7f946871d0> block4b_expand_conv float32 <Policy "mixed_float16">
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7f94670d50> block4b_expand_bn float32 <Policy "mixed_float16">
# <keras.layers.core.activation.Activation object at 0x7f7f94687210> block4b_expand_activation float32 <Policy "mixed_float16">
# <keras.layers.convolutional.DepthwiseConv2D object at 0x7f7f946794d0> block4b_dwconv float32 <Policy "mixed_float16">
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7f9466e390> block4b_bn float32 <Policy "mixed_float16">
# <keras.layers.core.activation.Activation object at 0x7f7f9467bfd0> block4b_activation float32 <Policy "mixed_float16">
# <keras.layers.pooling.GlobalAveragePooling2D object at 0x7f7f94687890> block4b_se_squeeze float32 <Policy "mixed_float16">
# <keras.layers.core.reshape.Reshape object at 0x7f7f94652210> block4b_se_reshape float32 <Policy "mixed_float16">
# <keras.layers.convolutional.Conv2D object at 0x7f7f9465bfd0> block4b_se_reduce float32 <Policy "mixed_float16">
# <keras.layers.convolutional.Conv2D object at 0x7f7f944aa350> block4b_se_expand float32 <Policy "mixed_float16">
# <keras.layers.merge.Multiply object at 0x7f7f9403d5d0> block4b_se_excite float32 <Policy "mixed_float16">
# <keras.layers.convolutional.Conv2D object at 0x7f7f9436ce10> block4b_project_conv float32 <Policy "mixed_float16">
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7f947c83d0> block4b_project_bn float32 <Policy "mixed_float16">
# <keras.layers.core.dropout.Dropout object at 0x7f7f941f0a10> block4b_drop float32 <Policy "mixed_float16">
# <keras.layers.merge.Add object at 0x7f7f947c8850> block4b_add float32 <Policy "mixed_float16">
# <keras.layers.convolutional.Conv2D object at 0x7f7f947d6c10> block4c_expand_conv float32 <Policy "mixed_float16">
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7f947dd0d0> block4c_expand_bn float32 <Policy "mixed_float16">
# <keras.layers.core.activation.Activation object at 0x7f7f947cc590> block4c_expand_activation float32 <Policy "mixed_float16">
# <keras.layers.convolutional.DepthwiseConv2D object at 0x7f7f947dddd0> block4c_dwconv float32 <Policy "mixed_float16">
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7f947bc590> block4c_bn float32 <Policy "mixed_float16">
# <keras.layers.core.activation.Activation object at 0x7f7f947c5350> block4c_activation float32 <Policy "mixed_float16">
# <keras.layers.pooling.GlobalAveragePooling2D object at 0x7f7f947c5710> block4c_se_squeeze float32 <Policy "mixed_float16">
# <keras.layers.core.reshape.Reshape object at 0x7f7f947ace50> block4c_se_reshape float32 <Policy "mixed_float16">
# <keras.layers.convolutional.Conv2D object at 0x7f7f947bf8d0> block4c_se_reduce float32 <Policy "mixed_float16">
# <keras.layers.convolutional.Conv2D object at 0x7f7f947b3390> block4c_se_expand float32 <Policy "mixed_float16">
# <keras.layers.merge.Multiply object at 0x7f7f9484d250> block4c_se_excite float32 <Policy "mixed_float16">
# <keras.layers.convolutional.Conv2D object at 0x7f7f9484d5d0> block4c_project_conv float32 <Policy "mixed_float16">
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7f94854a10> block4c_project_bn float32 <Policy "mixed_float16">
# <keras.layers.core.dropout.Dropout object at 0x7f7f9483fc10> block4c_drop float32 <Policy "mixed_float16">
# <keras.layers.merge.Add object at 0x7f7f94833b50> block4c_add float32 <Policy "mixed_float16">
# <keras.layers.convolutional.Conv2D object at 0x7f7f94833b10> block4d_expand_conv float32 <Policy "mixed_float16">
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7f9483fcd0> block4d_expand_bn float32 <Policy "mixed_float16">
# <keras.layers.core.activation.Activation object at 0x7f7f9482bad0> block4d_expand_activation float32 <Policy "mixed_float16">
# <keras.layers.convolutional.DepthwiseConv2D object at 0x7f7f9482be50> block4d_dwconv float32 <Policy "mixed_float16">
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7f8ee20190> block4d_bn float32 <Policy "mixed_float16">
# <keras.layers.core.activation.Activation object at 0x7f7f8ee0d4d0> block4d_activation float32 <Policy "mixed_float16">
# <keras.layers.pooling.GlobalAveragePooling2D object at 0x7f7f8ee0db50> block4d_se_squeeze float32 <Policy "mixed_float16">
# <keras.layers.core.reshape.Reshape object at 0x7f7f8ee16310> block4d_se_reshape float32 <Policy "mixed_float16">
# <keras.layers.convolutional.Conv2D object at 0x7f7f8ee16f10> block4d_se_reduce float32 <Policy "mixed_float16">
# <keras.layers.convolutional.Conv2D object at 0x7f7f8edec690> block4d_se_expand float32 <Policy "mixed_float16">
# <keras.layers.merge.Multiply object at 0x7f7f8ededed0> block4d_se_excite float32 <Policy "mixed_float16">
# <keras.layers.convolutional.Conv2D object at 0x7f7f8edef290> block4d_project_conv float32 <Policy "mixed_float16">
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7f8edecc10> block4d_project_bn float32 <Policy "mixed_float16">
# <keras.layers.core.dropout.Dropout object at 0x7f7f8ede5fd0> block4d_drop float32 <Policy "mixed_float16">
# <keras.layers.merge.Add object at 0x7f7f8edf8610> block4d_add float32 <Policy "mixed_float16">
# <keras.layers.convolutional.Conv2D object at 0x7f7f8edf1990> block4e_expand_conv float32 <Policy "mixed_float16">
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7f8ede56d0> block4e_expand_bn float32 <Policy "mixed_float16">
# <keras.layers.core.activation.Activation object at 0x7f7f8ede57d0> block4e_expand_activation float32 <Policy "mixed_float16">
# <keras.layers.convolutional.DepthwiseConv2D object at 0x7f7f9485c450> block4e_dwconv float32 <Policy "mixed_float16">
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7f9483f550> block4e_bn float32 <Policy "mixed_float16">
# <keras.layers.core.activation.Activation object at 0x7f7f941fcad0> block4e_activation float32 <Policy "mixed_float16">
# <keras.layers.pooling.GlobalAveragePooling2D object at 0x7f7f94847cd0> block4e_se_squeeze float32 <Policy "mixed_float16">
# <keras.layers.core.reshape.Reshape object at 0x7f7f8ee20490> block4e_se_reshape float32 <Policy "mixed_float16">
# <keras.layers.convolutional.Conv2D object at 0x7f7f94682b50> block4e_se_reduce float32 <Policy "mixed_float16">
# <keras.layers.convolutional.Conv2D object at 0x7f7f8ee0dcd0> block4e_se_expand float32 <Policy "mixed_float16">
# <keras.layers.merge.Multiply object at 0x7f7f94896810> block4e_se_excite float32 <Policy "mixed_float16">
# <keras.layers.convolutional.Conv2D object at 0x7f7f948a0f10> block4e_project_conv float32 <Policy "mixed_float16">
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7f94896b50> block4e_project_bn float32 <Policy "mixed_float16">
# <keras.layers.core.dropout.Dropout object at 0x7f7f9488f910> block4e_drop float32 <Policy "mixed_float16">
# <keras.layers.merge.Add object at 0x7f7f94880a50> block4e_add float32 <Policy "mixed_float16">
# <keras.layers.convolutional.Conv2D object at 0x7f7f94880850> block4f_expand_conv float32 <Policy "mixed_float16">
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7f94886f10> block4f_expand_bn float32 <Policy "mixed_float16">
# <keras.layers.core.activation.Activation object at 0x7f7f9488ff10> block4f_expand_activation float32 <Policy "mixed_float16">
# <keras.layers.convolutional.DepthwiseConv2D object at 0x7f7f9486de50> block4f_dwconv float32 <Policy "mixed_float16">
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7f94884bd0> block4f_bn float32 <Policy "mixed_float16">
# <keras.layers.core.activation.Activation object at 0x7f7f94880210> block4f_activation float32 <Policy "mixed_float16">
# <keras.layers.pooling.GlobalAveragePooling2D object at 0x7f7f92bee350> block4f_se_squeeze float32 <Policy "mixed_float16">
# <keras.layers.core.reshape.Reshape object at 0x7f7f8ee20650> block4f_se_reshape float32 <Policy "mixed_float16">
# <keras.layers.convolutional.Conv2D object at 0x7f7f92bee2d0> block4f_se_reduce float32 <Policy "mixed_float16">
# <keras.layers.convolutional.Conv2D object at 0x7f7f92bfb810> block4f_se_expand float32 <Policy "mixed_float16">
# <keras.layers.merge.Multiply object at 0x7f7f94872e90> block4f_se_excite float32 <Policy "mixed_float16">
# <keras.layers.convolutional.Conv2D object at 0x7f7f92bf34d0> block4f_project_conv float32 <Policy "mixed_float16">
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7f92be9f10> block4f_project_bn float32 <Policy "mixed_float16">
# <keras.layers.core.dropout.Dropout object at 0x7f7f92c1af50> block4f_drop float32 <Policy "mixed_float16">
# <keras.layers.merge.Add object at 0x7f7f948667d0> block4f_add float32 <Policy "mixed_float16">
# <keras.layers.convolutional.Conv2D object at 0x7f7f9488fe10> block5a_expand_conv float32 <Policy "mixed_float16">
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7f92be6290> block5a_expand_bn float32 <Policy "mixed_float16">
# <keras.layers.core.activation.Activation object at 0x7f7f94899990> block5a_expand_activation float32 <Policy "mixed_float16">
# <keras.layers.convolutional.DepthwiseConv2D object at 0x7f7f94880950> block5a_dwconv float32 <Policy "mixed_float16">
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7f92abf790> block5a_bn float32 <Policy "mixed_float16">
# <keras.layers.core.activation.Activation object at 0x7f7f92aafc10> block5a_activation float32 <Policy "mixed_float16">
# <keras.layers.pooling.GlobalAveragePooling2D object at 0x7f7f948668d0> block5a_se_squeeze float32 <Policy "mixed_float16">
# <keras.layers.core.reshape.Reshape object at 0x7f7f92aa5a90> block5a_se_reshape float32 <Policy "mixed_float16">
# <keras.layers.convolutional.Conv2D object at 0x7f7f92ad56d0> block5a_se_reduce float32 <Policy "mixed_float16">
# <keras.layers.convolutional.Conv2D object at 0x7f7f92acc050> block5a_se_expand float32 <Policy "mixed_float16">
# <keras.layers.merge.Multiply object at 0x7f7f92acc8d0> block5a_se_excite float32 <Policy "mixed_float16">
# <keras.layers.convolutional.Conv2D object at 0x7f7f94880050> block5a_project_conv float32 <Policy "mixed_float16">
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7f92accb90> block5a_project_bn float32 <Policy "mixed_float16">
# <keras.layers.convolutional.Conv2D object at 0x7f7f944d5090> block5b_expand_conv float32 <Policy "mixed_float16">
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7f92ab4b90> block5b_expand_bn float32 <Policy "mixed_float16">
# <keras.layers.core.activation.Activation object at 0x7f7f947c8410> block5b_expand_activation float32 <Policy "mixed_float16">
# <keras.layers.convolutional.DepthwiseConv2D object at 0x7f7f92adacd0> block5b_dwconv float32 <Policy "mixed_float16">
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7f948260d0> block5b_bn float32 <Policy "mixed_float16">
# <keras.layers.core.activation.Activation object at 0x7f7f92adf750> block5b_activation float32 <Policy "mixed_float16">
# <keras.layers.pooling.GlobalAveragePooling2D object at 0x7f7f928adf50> block5b_se_squeeze float32 <Policy "mixed_float16">
# <keras.layers.core.reshape.Reshape object at 0x7f7f928a4690> block5b_se_reshape float32 <Policy "mixed_float16">
# <keras.layers.convolutional.Conv2D object at 0x7f7f928b6890> block5b_se_reduce float32 <Policy "mixed_float16">
# <keras.layers.convolutional.Conv2D object at 0x7f7f92ada3d0> block5b_se_expand float32 <Policy "mixed_float16">
# <keras.layers.merge.Multiply object at 0x7f7f928bae50> block5b_se_excite float32 <Policy "mixed_float16">
# <keras.layers.convolutional.Conv2D object at 0x7f7f928d5890> block5b_project_conv float32 <Policy "mixed_float16">
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7f928c4350> block5b_project_bn float32 <Policy "mixed_float16">
# <keras.layers.core.dropout.Dropout object at 0x7f7f928c8150> block5b_drop float32 <Policy "mixed_float16">
# <keras.layers.merge.Add object at 0x7f7f9276ca10> block5b_add float32 <Policy "mixed_float16">
# <keras.layers.convolutional.Conv2D object at 0x7f7f92766fd0> block5c_expand_conv float32 <Policy "mixed_float16">
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7f928d0510> block5c_expand_bn float32 <Policy "mixed_float16">
# <keras.layers.core.activation.Activation object at 0x7f7f92762790> block5c_expand_activation float32 <Policy "mixed_float16">
# <keras.layers.convolutional.DepthwiseConv2D object at 0x7f7f92780c10> block5c_dwconv float32 <Policy "mixed_float16">
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7f92778e90> block5c_bn float32 <Policy "mixed_float16">
# <keras.layers.core.activation.Activation object at 0x7f7f927780d0> block5c_activation float32 <Policy "mixed_float16">
# <keras.layers.pooling.GlobalAveragePooling2D object at 0x7f7f92799710> block5c_se_squeeze float32 <Policy "mixed_float16">
# <keras.layers.core.reshape.Reshape object at 0x7f7f92ade850> block5c_se_reshape float32 <Policy "mixed_float16">
# <keras.layers.convolutional.Conv2D object at 0x7f7f92799c90> block5c_se_reduce float32 <Policy "mixed_float16">
# <keras.layers.convolutional.Conv2D object at 0x7f7f9276cf10> block5c_se_expand float32 <Policy "mixed_float16">
# <keras.layers.merge.Multiply object at 0x7f7f9278a990> block5c_se_excite float32 <Policy "mixed_float16">
# <keras.layers.convolutional.Conv2D object at 0x7f7f9262aa10> block5c_project_conv float32 <Policy "mixed_float16">
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7f92799ed0> block5c_project_bn float32 <Policy "mixed_float16">
# <keras.layers.core.dropout.Dropout object at 0x7f7f92625590> block5c_drop float32 <Policy "mixed_float16">
# <keras.layers.merge.Add object at 0x7f7f92632250> block5c_add float32 <Policy "mixed_float16">
# <keras.layers.convolutional.Conv2D object at 0x7f7f92766250> block5d_expand_conv float32 <Policy "mixed_float16">
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7f92c0dfd0> block5d_expand_bn float32 <Policy "mixed_float16">
# <keras.layers.core.activation.Activation object at 0x7f7f92632850> block5d_expand_activation float32 <Policy "mixed_float16">
# <keras.layers.convolutional.DepthwiseConv2D object at 0x7f7f92635990> block5d_dwconv float32 <Policy "mixed_float16">
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7f927783d0> block5d_bn float32 <Policy "mixed_float16">
# <keras.layers.core.activation.Activation object at 0x7f7f92648d90> block5d_activation float32 <Policy "mixed_float16">
# <keras.layers.pooling.GlobalAveragePooling2D object at 0x7f7f9265c1d0> block5d_se_squeeze float32 <Policy "mixed_float16">
# <keras.layers.core.reshape.Reshape object at 0x7f7f92462090> block5d_se_reshape float32 <Policy "mixed_float16">
# <keras.layers.convolutional.Conv2D object at 0x7f7f92660350> block5d_se_reduce float32 <Policy "mixed_float16">
# <keras.layers.convolutional.Conv2D object at 0x7f7f9262d550> block5d_se_expand float32 <Policy "mixed_float16">
# <keras.layers.merge.Multiply object at 0x7f7f9278a790> block5d_se_excite float32 <Policy "mixed_float16">
# <keras.layers.convolutional.Conv2D object at 0x7f7f92790990> block5d_project_conv float32 <Policy "mixed_float16">
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7f92632d50> block5d_project_bn float32 <Policy "mixed_float16">
# <keras.layers.core.dropout.Dropout object at 0x7f7f948264d0> block5d_drop float32 <Policy "mixed_float16">
# <keras.layers.merge.Add object at 0x7f7f92adf550> block5d_add float32 <Policy "mixed_float16">
# <keras.layers.convolutional.Conv2D object at 0x7f7f928c8a50> block5e_expand_conv float32 <Policy "mixed_float16">
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7f92476cd0> block5e_expand_bn float32 <Policy "mixed_float16">
# <keras.layers.core.activation.Activation object at 0x7f7f9246b890> block5e_expand_activation float32 <Policy "mixed_float16">
# <keras.layers.convolutional.DepthwiseConv2D object at 0x7f7f92476fd0> block5e_dwconv float32 <Policy "mixed_float16">
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7f92476110> block5e_bn float32 <Policy "mixed_float16">
# <keras.layers.core.activation.Activation object at 0x7f7f92489590> block5e_activation float32 <Policy "mixed_float16">
# <keras.layers.pooling.GlobalAveragePooling2D object at 0x7f7f924890d0> block5e_se_squeeze float32 <Policy "mixed_float16">
# <keras.layers.core.reshape.Reshape object at 0x7f7f92477f10> block5e_se_reshape float32 <Policy "mixed_float16">
# <keras.layers.convolutional.Conv2D object at 0x7f7f92491d90> block5e_se_reduce float32 <Policy "mixed_float16">
# <keras.layers.convolutional.Conv2D object at 0x7f7f92adee90> block5e_se_expand float32 <Policy "mixed_float16">
# <keras.layers.merge.Multiply object at 0x7f7f92495b10> block5e_se_excite float32 <Policy "mixed_float16">
# <keras.layers.convolutional.Conv2D object at 0x7f7f922ec210> block5e_project_conv float32 <Policy "mixed_float16">
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7f92498810> block5e_project_bn float32 <Policy "mixed_float16">
# <keras.layers.core.dropout.Dropout object at 0x7f7f922f5a90> block5e_drop float32 <Policy "mixed_float16">
# <keras.layers.merge.Add object at 0x7f7f92300e50> block5e_add float32 <Policy "mixed_float16">
# <keras.layers.convolutional.Conv2D object at 0x7f7f9230d510> block5f_expand_conv float32 <Policy "mixed_float16">
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7f922f09d0> block5f_expand_bn float32 <Policy "mixed_float16">
# <keras.layers.core.activation.Activation object at 0x7f7f92300f50> block5f_expand_activation float32 <Policy "mixed_float16">
# <keras.layers.convolutional.DepthwiseConv2D object at 0x7f7f92318c90> block5f_dwconv float32 <Policy "mixed_float16">
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7f923218d0> block5f_bn float32 <Policy "mixed_float16">
# <keras.layers.core.activation.Activation object at 0x7f7f9231d510> block5f_activation float32 <Policy "mixed_float16">
# <keras.layers.pooling.GlobalAveragePooling2D object at 0x7f7f921ab910> block5f_se_squeeze float32 <Policy "mixed_float16">
# <keras.layers.core.reshape.Reshape object at 0x7f7f921aef50> block5f_se_reshape float32 <Policy "mixed_float16">
# <keras.layers.convolutional.Conv2D object at 0x7f7f921ae910> block5f_se_reduce float32 <Policy "mixed_float16">
# <keras.layers.convolutional.Conv2D object at 0x7f7f9230d6d0> block5f_se_expand float32 <Policy "mixed_float16">
# <keras.layers.merge.Multiply object at 0x7f7f921d3fd0> block5f_se_excite float32 <Policy "mixed_float16">
# <keras.layers.convolutional.Conv2D object at 0x7f7f921d3ed0> block5f_project_conv float32 <Policy "mixed_float16">
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7f921bb6d0> block5f_project_bn float32 <Policy "mixed_float16">
# <keras.layers.core.dropout.Dropout object at 0x7f7f91fe4990> block5f_drop float32 <Policy "mixed_float16">
# <keras.layers.merge.Add object at 0x7f7f921d24d0> block5f_add float32 <Policy "mixed_float16">
# <keras.layers.convolutional.Conv2D object at 0x7f7f921d9590> block6a_expand_conv float32 <Policy "mixed_float16">
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7f91ff2a90> block6a_expand_bn float32 <Policy "mixed_float16">
# <keras.layers.core.activation.Activation object at 0x7f7f91ff2590> block6a_expand_activation float32 <Policy "mixed_float16">
# <keras.layers.convolutional.ZeroPadding2D object at 0x7f7f91ff2f10> block6a_dwconv_pad float32 <Policy "mixed_float16">
# <keras.layers.convolutional.DepthwiseConv2D object at 0x7f7f9231de50> block6a_dwconv float32 <Policy "mixed_float16">
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7f9231de10> block6a_bn float32 <Policy "mixed_float16">
# <keras.layers.core.activation.Activation object at 0x7f7f91ff2190> block6a_activation float32 <Policy "mixed_float16">
# <keras.layers.pooling.GlobalAveragePooling2D object at 0x7f7f92300150> block6a_se_squeeze float32 <Policy "mixed_float16">
# <keras.layers.core.reshape.Reshape object at 0x7f7f922f5e10> block6a_se_reshape float32 <Policy "mixed_float16">
# <keras.layers.convolutional.Conv2D object at 0x7f7f922f9210> block6a_se_reduce float32 <Policy "mixed_float16">
# <keras.layers.convolutional.Conv2D object at 0x7f7f921d2c10> block6a_se_expand float32 <Policy "mixed_float16">
# <keras.layers.merge.Multiply object at 0x7f7f922f98d0> block6a_se_excite float32 <Policy "mixed_float16">
# <keras.layers.convolutional.Conv2D object at 0x7f7f91ffce50> block6a_project_conv float32 <Policy "mixed_float16">
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7f9247f7d0> block6a_project_bn float32 <Policy "mixed_float16">
# <keras.layers.convolutional.Conv2D object at 0x7f7f921b6e10> block6b_expand_conv float32 <Policy "mixed_float16">
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7f92001ad0> block6b_expand_bn float32 <Policy "mixed_float16">
# <keras.layers.core.activation.Activation object at 0x7f7f92009e10> block6b_expand_activation float32 <Policy "mixed_float16">
# <keras.layers.convolutional.DepthwiseConv2D object at 0x7f7f91ea5210> block6b_dwconv float32 <Policy "mixed_float16">
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7f92300bd0> block6b_bn float32 <Policy "mixed_float16">
# <keras.layers.core.activation.Activation object at 0x7f7f92009850> block6b_activation float32 <Policy "mixed_float16">
# <keras.layers.pooling.GlobalAveragePooling2D object at 0x7f7f91ea5e50> block6b_se_squeeze float32 <Policy "mixed_float16">
# <keras.layers.core.reshape.Reshape object at 0x7f7f923003d0> block6b_se_reshape float32 <Policy "mixed_float16">
# <keras.layers.convolutional.Conv2D object at 0x7f7f91eb9b10> block6b_se_reduce float32 <Policy "mixed_float16">
# <keras.layers.convolutional.Conv2D object at 0x7f7f92014790> block6b_se_expand float32 <Policy "mixed_float16">
# <keras.layers.merge.Multiply object at 0x7f7f91ecd450> block6b_se_excite float32 <Policy "mixed_float16">
# <keras.layers.convolutional.Conv2D object at 0x7f7f91ecddd0> block6b_project_conv float32 <Policy "mixed_float16">
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7f91ec01d0> block6b_project_bn float32 <Policy "mixed_float16">
# <keras.layers.core.dropout.Dropout object at 0x7f7f91ea8450> block6b_drop float32 <Policy "mixed_float16">
# <keras.layers.merge.Add object at 0x7f7f91ed9090> block6b_add float32 <Policy "mixed_float16">
# <keras.layers.convolutional.Conv2D object at 0x7f7f91fe4550> block6c_expand_conv float32 <Policy "mixed_float16">
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7f91ecef90> block6c_expand_bn float32 <Policy "mixed_float16">
# <keras.layers.core.activation.Activation object at 0x7f7f91ed9710> block6c_expand_activation float32 <Policy "mixed_float16">
# <keras.layers.convolutional.DepthwiseConv2D object at 0x7f7f91d3b890> block6c_dwconv float32 <Policy "mixed_float16">
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7f91d3ba90> block6c_bn float32 <Policy "mixed_float16">
# <keras.layers.core.activation.Activation object at 0x7f7f91d36e50> block6c_activation float32 <Policy "mixed_float16">
# <keras.layers.pooling.GlobalAveragePooling2D object at 0x7f7f91d45f50> block6c_se_squeeze float32 <Policy "mixed_float16">
# <keras.layers.core.reshape.Reshape object at 0x7f7f91d4fd50> block6c_se_reshape float32 <Policy "mixed_float16">
# <keras.layers.convolutional.Conv2D object at 0x7f7f91d4f550> block6c_se_reduce float32 <Policy "mixed_float16">
# <keras.layers.convolutional.Conv2D object at 0x7f7f91d26fd0> block6c_se_expand float32 <Policy "mixed_float16">
# <keras.layers.merge.Multiply object at 0x7f7f91d33ad0> block6c_se_excite float32 <Policy "mixed_float16">
# <keras.layers.convolutional.Conv2D object at 0x7f7f91b69bd0> block6c_project_conv float32 <Policy "mixed_float16">
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7f91b7ef50> block6c_project_bn float32 <Policy "mixed_float16">
# <keras.layers.core.dropout.Dropout object at 0x7f7f91b76e10> block6c_drop float32 <Policy "mixed_float16">
# <keras.layers.merge.Add object at 0x7f7f91b76b50> block6c_add float32 <Policy "mixed_float16">
# <keras.layers.convolutional.Conv2D object at 0x7f7f91b71210> block6d_expand_conv float32 <Policy "mixed_float16">
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7f91d5fb90> block6d_expand_bn float32 <Policy "mixed_float16">
# <keras.layers.core.activation.Activation object at 0x7f7f91ed5d10> block6d_expand_activation float32 <Policy "mixed_float16">
# <keras.layers.convolutional.DepthwiseConv2D object at 0x7f7f91d222d0> block6d_dwconv float32 <Policy "mixed_float16">
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7f921b2610> block6d_bn float32 <Policy "mixed_float16">
# <keras.layers.core.activation.Activation object at 0x7f7f91ea8850> block6d_activation float32 <Policy "mixed_float16">
# <keras.layers.pooling.GlobalAveragePooling2D object at 0x7f7f922f9610> block6d_se_squeeze float32 <Policy "mixed_float16">
# <keras.layers.core.reshape.Reshape object at 0x7f7f91d3bc10> block6d_se_reshape float32 <Policy "mixed_float16">
# <keras.layers.convolutional.Conv2D object at 0x7f7f92471390> block6d_se_reduce float32 <Policy "mixed_float16">
# <keras.layers.convolutional.Conv2D object at 0x7f7f91b7e3d0> block6d_se_expand float32 <Policy "mixed_float16">
# <keras.layers.merge.Multiply object at 0x7f7f91b8a190> block6d_se_excite float32 <Policy "mixed_float16">
# <keras.layers.convolutional.Conv2D object at 0x7f7f91b91490> block6d_project_conv float32 <Policy "mixed_float16">
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7f91b8a710> block6d_project_bn float32 <Policy "mixed_float16">
# <keras.layers.core.dropout.Dropout object at 0x7f7f91d33910> block6d_drop float32 <Policy "mixed_float16">
# <keras.layers.merge.Add object at 0x7f7f91b76050> block6d_add float32 <Policy "mixed_float16">
# <keras.layers.convolutional.Conv2D object at 0x7f7f91a2efd0> block6e_expand_conv float32 <Policy "mixed_float16">
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7f91b9f550> block6e_expand_bn float32 <Policy "mixed_float16">
# <keras.layers.core.activation.Activation object at 0x7f7f91a2ca50> block6e_expand_activation float32 <Policy "mixed_float16">
# <keras.layers.convolutional.DepthwiseConv2D object at 0x7f7f91a46210> block6e_dwconv float32 <Policy "mixed_float16">
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7f91ec0810> block6e_bn float32 <Policy "mixed_float16">
# <keras.layers.core.activation.Activation object at 0x7f7f91a3b3d0> block6e_activation float32 <Policy "mixed_float16">
# <keras.layers.pooling.GlobalAveragePooling2D object at 0x7f7f91a2ea50> block6e_se_squeeze float32 <Policy "mixed_float16">
# <keras.layers.core.reshape.Reshape object at 0x7f7f91d3b790> block6e_se_reshape float32 <Policy "mixed_float16">
# <keras.layers.convolutional.Conv2D object at 0x7f7f91a5bad0> block6e_se_reduce float32 <Policy "mixed_float16">
# <keras.layers.convolutional.Conv2D object at 0x7f7f91a36590> block6e_se_expand float32 <Policy "mixed_float16">
# <keras.layers.merge.Multiply object at 0x7f7f91a51f10> block6e_se_excite float32 <Policy "mixed_float16">
# <keras.layers.convolutional.Conv2D object at 0x7f7f918f7310> block6e_project_conv float32 <Policy "mixed_float16">
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7f91a4bf10> block6e_project_bn float32 <Policy "mixed_float16">
# <keras.layers.core.dropout.Dropout object at 0x7f7f918ff050> block6e_drop float32 <Policy "mixed_float16">
# <keras.layers.merge.Add object at 0x7f7f91a2edd0> block6e_add float32 <Policy "mixed_float16">
# <keras.layers.convolutional.Conv2D object at 0x7f7f91908050> block6f_expand_conv float32 <Policy "mixed_float16">
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7f918e4fd0> block6f_expand_bn float32 <Policy "mixed_float16">
# <keras.layers.core.activation.Activation object at 0x7f7f9190f2d0> block6f_expand_activation float32 <Policy "mixed_float16">
# <keras.layers.convolutional.DepthwiseConv2D object at 0x7f7f918fac50> block6f_dwconv float32 <Policy "mixed_float16">
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7f8f510810> block6f_bn float32 <Policy "mixed_float16">
# <keras.layers.core.activation.Activation object at 0x7f7f91770ad0> block6f_activation float32 <Policy "mixed_float16">
# <keras.layers.pooling.GlobalAveragePooling2D object at 0x7f7f91770410> block6f_se_squeeze float32 <Policy "mixed_float16">
# <keras.layers.core.reshape.Reshape object at 0x7f7f9176e5d0> block6f_se_reshape float32 <Policy "mixed_float16">
# <keras.layers.convolutional.Conv2D object at 0x7f7f91921f50> block6f_se_reduce float32 <Policy "mixed_float16">
# <keras.layers.convolutional.Conv2D object at 0x7f7f9176c0d0> block6f_se_expand float32 <Policy "mixed_float16">
# <keras.layers.merge.Multiply object at 0x7f7f91782b50> block6f_se_excite float32 <Policy "mixed_float16">
# <keras.layers.convolutional.Conv2D object at 0x7f7f918e4c50> block6f_project_conv float32 <Policy "mixed_float16">
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7f9177dc90> block6f_project_bn float32 <Policy "mixed_float16">
# <keras.layers.core.dropout.Dropout object at 0x7f7f91a23d50> block6f_drop float32 <Policy "mixed_float16">
# <keras.layers.merge.Add object at 0x7f7f91904e10> block6f_add float32 <Policy "mixed_float16">
# <keras.layers.convolutional.Conv2D object at 0x7f7f921b6e50> block6g_expand_conv float32 <Policy "mixed_float16">
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7f9176e810> block6g_expand_bn float32 <Policy "mixed_float16">
# <keras.layers.core.activation.Activation object at 0x7f7f91b87a90> block6g_expand_activation float32 <Policy "mixed_float16">
# <keras.layers.convolutional.DepthwiseConv2D object at 0x7f7f91787dd0> block6g_dwconv float32 <Policy "mixed_float16">
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7f91794890> block6g_bn float32 <Policy "mixed_float16">
# <keras.layers.core.activation.Activation object at 0x7f7f91b87450> block6g_activation float32 <Policy "mixed_float16">
# <keras.layers.pooling.GlobalAveragePooling2D object at 0x7f7f917972d0> block6g_se_squeeze float32 <Policy "mixed_float16">
# <keras.layers.core.reshape.Reshape object at 0x7f7f9176e750> block6g_se_reshape float32 <Policy "mixed_float16">
# <keras.layers.convolutional.Conv2D object at 0x7f7f915aab50> block6g_se_reduce float32 <Policy "mixed_float16">
# <keras.layers.convolutional.Conv2D object at 0x7f7f91b8ae10> block6g_se_expand float32 <Policy "mixed_float16">
# <keras.layers.merge.Multiply object at 0x7f7f915c1590> block6g_se_excite float32 <Policy "mixed_float16">
# <keras.layers.convolutional.Conv2D object at 0x7f7f915c18d0> block6g_project_conv float32 <Policy "mixed_float16">
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7f915aab10> block6g_project_bn float32 <Policy "mixed_float16">
# <keras.layers.core.dropout.Dropout object at 0x7f7f9179d990> block6g_drop float32 <Policy "mixed_float16">
# <keras.layers.merge.Add object at 0x7f7f915c9a50> block6g_add float32 <Policy "mixed_float16">
# <keras.layers.convolutional.Conv2D object at 0x7f7f915d2610> block6h_expand_conv float32 <Policy "mixed_float16">
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7f91b91810> block6h_expand_bn float32 <Policy "mixed_float16">
# <keras.layers.core.activation.Activation object at 0x7f7f914653d0> block6h_expand_activation float32 <Policy "mixed_float16">
# <keras.layers.convolutional.DepthwiseConv2D object at 0x7f7f915ddc50> block6h_dwconv float32 <Policy "mixed_float16">
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7f91465210> block6h_bn float32 <Policy "mixed_float16">
# <keras.layers.core.activation.Activation object at 0x7f7f915bc610> block6h_activation float32 <Policy "mixed_float16">
# <keras.layers.pooling.GlobalAveragePooling2D object at 0x7f7f91465750> block6h_se_squeeze float32 <Policy "mixed_float16">
# <keras.layers.core.reshape.Reshape object at 0x7f7f9147d850> block6h_se_reshape float32 <Policy "mixed_float16">
# <keras.layers.convolutional.Conv2D object at 0x7f7f914779d0> block6h_se_reduce float32 <Policy "mixed_float16">
# <keras.layers.convolutional.Conv2D object at 0x7f7f915d27d0> block6h_se_expand float32 <Policy "mixed_float16">
# <keras.layers.merge.Multiply object at 0x7f7f91498ed0> block6h_se_excite float32 <Policy "mixed_float16">
# <keras.layers.convolutional.Conv2D object at 0x7f7f91498c50> block6h_project_conv float32 <Policy "mixed_float16">
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7f914826d0> block6h_project_bn float32 <Policy "mixed_float16">
# <keras.layers.core.dropout.Dropout object at 0x7f7f915b7d90> block6h_drop float32 <Policy "mixed_float16">
# <keras.layers.merge.Add object at 0x7f7f915d2810> block6h_add float32 <Policy "mixed_float16">
# <keras.layers.convolutional.Conv2D object at 0x7f7f914786d0> block7a_expand_conv float32 <Policy "mixed_float16">
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7f91339d50> block7a_expand_bn float32 <Policy "mixed_float16">
# <keras.layers.core.activation.Activation object at 0x7f7f915cd610> block7a_expand_activation float32 <Policy "mixed_float16">
# <keras.layers.convolutional.DepthwiseConv2D object at 0x7f7f91334890> block7a_dwconv float32 <Policy "mixed_float16">
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7f91354750> block7a_bn float32 <Policy "mixed_float16">
# <keras.layers.core.activation.Activation object at 0x7f7f913392d0> block7a_activation float32 <Policy "mixed_float16">
# <keras.layers.pooling.GlobalAveragePooling2D object at 0x7f7f91354c90> block7a_se_squeeze float32 <Policy "mixed_float16">
# <keras.layers.core.reshape.Reshape object at 0x7f7f913418d0> block7a_se_reshape float32 <Policy "mixed_float16">
# <keras.layers.convolutional.Conv2D object at 0x7f7f915d8d10> block7a_se_reduce float32 <Policy "mixed_float16">
# <keras.layers.convolutional.Conv2D object at 0x7f7f91327d10> block7a_se_expand float32 <Policy "mixed_float16">
# <keras.layers.merge.Multiply object at 0x7f7f915b0410> block7a_se_excite float32 <Policy "mixed_float16">
# <keras.layers.convolutional.Conv2D object at 0x7f7f915b01d0> block7a_project_conv float32 <Policy "mixed_float16">
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7f915bc090> block7a_project_bn float32 <Policy "mixed_float16">
# <keras.layers.convolutional.Conv2D object at 0x7f7f91a23cd0> block7b_expand_conv float32 <Policy "mixed_float16">
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7f91b87510> block7b_expand_bn float32 <Policy "mixed_float16">
# <keras.layers.core.activation.Activation object at 0x7f7f9135acd0> block7b_expand_activation float32 <Policy "mixed_float16">
# <keras.layers.convolutional.DepthwiseConv2D object at 0x7f7f9112b2d0> block7b_dwconv float32 <Policy "mixed_float16">
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7f91341d50> block7b_bn float32 <Policy "mixed_float16">
# <keras.layers.core.activation.Activation object at 0x7f7f9112b810> block7b_activation float32 <Policy "mixed_float16">
# <keras.layers.pooling.GlobalAveragePooling2D object at 0x7f7f91146190> block7b_se_squeeze float32 <Policy "mixed_float16">
# <keras.layers.core.reshape.Reshape object at 0x7f7f9135dad0> block7b_se_reshape float32 <Policy "mixed_float16">
# <keras.layers.convolutional.Conv2D object at 0x7f7f9135df10> block7b_se_reduce float32 <Policy "mixed_float16">
# <keras.layers.convolutional.Conv2D object at 0x7f7f9135d690> block7b_se_expand float32 <Policy "mixed_float16">
# <keras.layers.merge.Multiply object at 0x7f7f9114ee90> block7b_se_excite float32 <Policy "mixed_float16">
# <keras.layers.convolutional.Conv2D object at 0x7f7f90fe3410> block7b_project_conv float32 <Policy "mixed_float16">
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7f9114ed10> block7b_project_bn float32 <Policy "mixed_float16">
# <keras.layers.core.dropout.Dropout object at 0x7f7f90fe70d0> block7b_drop float32 <Policy "mixed_float16">
# <keras.layers.merge.Add object at 0x7f7f91006f10> block7b_add float32 <Policy "mixed_float16">
# <keras.layers.convolutional.Conv2D object at 0x7f7f8f570150> top_conv float32 <Policy "mixed_float16">
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7f90ffed50> top_bn float32 <Policy "mixed_float16">
# <keras.layers.core.activation.Activation object at 0x7f7f90ff7390> top_activation float32 <Policy "mixed_float16">

# %%
for layer in model.layers:
  print(layer, layer.name, layer.dtype, layer.dtype_policy)
# Out:
# <keras.engine.input_layer.InputLayer object at 0x7f7f8ec652d0> input_layer float32 <Policy "float32">
# <keras.engine.functional.Functional object at 0x7f7f90ff3f90> efficientnetb4 float32 <Policy "mixed_float16">
# <keras.layers.pooling.GlobalAveragePooling2D object at 0x7f7f91146490> pooling_layer float32 <Policy "mixed_float16">
# <keras.layers.core.dropout.Dropout object at 0x7f7f8ec65850> dropout_layer float32 <Policy "mixed_float16">
# <keras.layers.core.dense.Dense object at 0x7f7f8f48ac50> regularization_layer float32 <Policy "mixed_float16">
# <keras.layers.core.dense.Dense object at 0x7f7f8f486690> dense float32 <Policy "mixed_float16">
# <keras.layers.core.activation.Activation object at 0x7f7f8f48ae90> softmax_float32 float32 <Policy "float32">

# %%
history_101_food_classes_feature_extract = model.fit(train_data, epochs=10,steps_per_epoch=len(train_data), validation_data=test_data, validation_steps=int(0.15 * len(test_data)),callbacks=[tensorboard_callback, checkpoint_callback, lr_scheduler_callback, learning_rate_reduce_callback])
# Out:
# Epoch 1/10
# 2368/2368 [==============================] - ETA: 0s - loss: 2.0394 - accuracy: 0.5125
# Epoch 1: val_loss improved from inf to 1.50169, saving model to checkpoints/feature_extraction_model
# 2368/2368 [==============================] - 313s 121ms/step - loss: 2.0394 - accuracy: 0.5125 - val_loss: 1.5017 - val_accuracy: 0.6377 - lr: 0.0010
# Epoch 2/10
# 2367/2368 [============================>.] - ETA: 0s - loss: 1.6876 - accuracy: 0.5996
# Epoch 2: val_loss improved from 1.50169 to 1.48036, saving model to checkpoints/feature_extraction_model
# 2368/2368 [==============================] - 288s 121ms/step - loss: 1.6876 - accuracy: 0.5996 - val_loss: 1.4804 - val_accuracy: 0.6451 - lr: 0.0010
# Epoch 3/10
# 2367/2368 [============================>.] - ETA: 0s - loss: 1.6256 - accuracy: 0.6179
# Epoch 3: val_loss improved from 1.48036 to 1.43857, saving model to checkpoints/feature_extraction_model
# 2368/2368 [==============================] - 289s 121ms/step - loss: 1.6256 - accuracy: 0.6179 - val_loss: 1.4386 - val_accuracy: 0.6700 - lr: 0.0010
# Epoch 4/10
# 2367/2368 [============================>.] - ETA: 0s - loss: 1.5930 - accuracy: 0.6304
# Epoch 4: val_loss did not improve from 1.43857
# 2368/2368 [==============================] - 296s 124ms/step - loss: 1.5930 - accuracy: 0.6304 - val_loss: 1.4469 - val_accuracy: 0.6679 - lr: 0.0010
# Epoch 5/10
# 2367/2368 [============================>.] - ETA: 0s - loss: 1.5735 - accuracy: 0.6376
# Epoch 5: val_loss did not improve from 1.43857
#
# Epoch 5: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 2368/2368 [==============================] - 287s 121ms/step - loss: 1.5734 - accuracy: 0.6377 - val_loss: 1.4503 - val_accuracy: 0.6703 - lr: 0.0010
# Epoch 6/10
# 2367/2368 [============================>.] - ETA: 0s - loss: 1.3924 - accuracy: 0.6856
# Epoch 6: val_loss improved from 1.43857 to 1.34428, saving model to checkpoints/feature_extraction_model
# 2368/2368 [==============================] - 288s 121ms/step - loss: 1.3924 - accuracy: 0.6856 - val_loss: 1.3443 - val_accuracy: 0.7002 - lr: 1.8097e-04
# Epoch 7/10
# 2367/2368 [============================>.] - ETA: 0s - loss: 1.3567 - accuracy: 0.6917
# Epoch 7: val_loss improved from 1.34428 to 1.33713, saving model to checkpoints/feature_extraction_model
# 2368/2368 [==============================] - 288s 121ms/step - loss: 1.3567 - accuracy: 0.6917 - val_loss: 1.3371 - val_accuracy: 0.6997 - lr: 1.6375e-04
# Epoch 8/10
# 2367/2368 [============================>.] - ETA: 0s - loss: 1.3375 - accuracy: 0.6956
# Epoch 8: val_loss improved from 1.33713 to 1.32822, saving model to checkpoints/feature_extraction_model
# 2368/2368 [==============================] - 288s 121ms/step - loss: 1.3375 - accuracy: 0.6956 - val_loss: 1.3282 - val_accuracy: 0.7026 - lr: 1.4816e-04
# Epoch 9/10
# 2367/2368 [============================>.] - ETA: 0s - loss: 1.3203 - accuracy: 0.6995
# Epoch 9: val_loss improved from 1.32822 to 1.32282, saving model to checkpoints/feature_extraction_model
# 2368/2368 [==============================] - 288s 121ms/step - loss: 1.3203 - accuracy: 0.6995 - val_loss: 1.3228 - val_accuracy: 0.7029 - lr: 1.3406e-04
# Epoch 10/10
# 2367/2368 [============================>.] - ETA: 0s - loss: 1.3092 - accuracy: 0.7017
# Epoch 10: val_loss improved from 1.32282 to 1.31780, saving model to checkpoints/feature_extraction_model
# 2368/2368 [==============================] - 288s 121ms/step - loss: 1.3093 - accuracy: 0.7017 - val_loss: 1.3178 - val_accuracy: 0.7037 - lr: 1.2131e-04

# %%
model.evaluate(test_data)
# Out:
# 790/790 [==============================] - 85s 107ms/step - loss: 1.3183 - accuracy: 0.7013
# [1.3182523250579834, 0.7012673020362854]

# %%
plot_loss_curves(history_101_food_classes_feature_extract)

# %%
result_feature_extraction= model.evaluate(test_data)
result_feature_extraction
# Out:
# 790/790 [==============================] - 85s 107ms/step - loss: 1.3183 - accuracy: 0.7013
# [1.3182523250579834, 0.7012673020362854]

# %%
saved_model_dir='saved_models/model_feature_extraction_model'

# %%
model.save(saved_model_dir)

# %% [markdown]
# ## Load the saved Feature Extraction Model

# %%
loaded_model= tf.keras.models.load_model(saved_model_dir)

# %%
loaded_model_result=loaded_model.evaluate(test_data)
loaded_model_result
# Out:
# 790/790 [==============================] - 91s 111ms/step - loss: 1.3183 - accuracy: 0.7013
# [1.3182523250579834, 0.7012673020362854]

# %% [markdown]
# ## Checking if the model saved/loaded correctly

# %%
loaded_model_result == result_feature_extraction
# Out:
# True

# %%
np.allclose(result_feature_extraction, loaded_model_result)
# Out:
# True

# %% [markdown]
# ## Checking the layers of the loaded model

# %%
for layer in loaded_model.layers:
  print(layer, layer.name, layer.trainable)
# Out:
# <keras.engine.input_layer.InputLayer object at 0x7f7ef2226990> input_layer True
# <keras.engine.functional.Functional object at 0x7f7ef235ea90> efficientnetb4 False
# <keras.layers.pooling.GlobalAveragePooling2D object at 0x7f7ef1b8e7d0> pooling_layer True
# <keras.layers.core.dropout.Dropout object at 0x7f7eef6de790> dropout_layer True
# <keras.layers.core.dense.Dense object at 0x7f7efc2a4690> regularization_layer True
# <keras.layers.core.dense.Dense object at 0x7f7efc099a90> dense True
# <keras.layers.core.activation.Activation object at 0x7f7ef25db810> softmax_float32 True

# %%
for layer in loaded_model.layers[1].layers:
  print(layer, layer.name, layer.trainable)
# Out:
# <keras.engine.input_layer.InputLayer object at 0x7f7ef25db450> input_1 True
# <keras.layers.preprocessing.image_preprocessing.Rescaling object at 0x7f7ef1c0c6d0> rescaling False
# <keras.layers.preprocessing.normalization.Normalization object at 0x7f7ef25d4490> normalization False
# <keras.layers.convolutional.ZeroPadding2D object at 0x7f7ef1baa690> stem_conv_pad False
# <keras.layers.convolutional.Conv2D object at 0x7f7ef1b95290> stem_conv False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7ef25c0210> stem_bn False
# <keras.layers.core.activation.Activation object at 0x7f7ef1cfb9d0> stem_activation False
# <keras.layers.convolutional.DepthwiseConv2D object at 0x7f7efc1b8150> block1a_dwconv False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7efc28fb10> block1a_bn False
# <keras.layers.core.activation.Activation object at 0x7f7efc2d2ad0> block1a_activation False
# <keras.layers.pooling.GlobalAveragePooling2D object at 0x7f7eeb28a190> block1a_se_squeeze False
# <keras.layers.core.reshape.Reshape object at 0x7f7efc2cc510> block1a_se_reshape False
# <keras.layers.convolutional.Conv2D object at 0x7f7ef1b5acd0> block1a_se_reduce False
# <keras.layers.convolutional.Conv2D object at 0x7f7efc20a190> block1a_se_expand False
# <keras.layers.merge.Multiply object at 0x7f7ef2610690> block1a_se_excite False
# <keras.layers.convolutional.Conv2D object at 0x7f7efc2b1610> block1a_project_conv False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7ef1ba3050> block1a_project_bn False
# <keras.layers.convolutional.DepthwiseConv2D object at 0x7f7ef26680d0> block1b_dwconv False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7efc3594d0> block1b_bn False
# <keras.layers.core.activation.Activation object at 0x7f7ef265f610> block1b_activation False
# <keras.layers.pooling.GlobalAveragePooling2D object at 0x7f7ef2650e90> block1b_se_squeeze False
# <keras.layers.core.reshape.Reshape object at 0x7f7ef251d890> block1b_se_reshape False
# <keras.layers.convolutional.Conv2D object at 0x7f7efc350e90> block1b_se_reduce False
# <keras.layers.convolutional.Conv2D object at 0x7f7ef1beea10> block1b_se_expand False
# <keras.layers.merge.Multiply object at 0x7f7efc3a7f90> block1b_se_excite False
# <keras.layers.convolutional.Conv2D object at 0x7f7ef264c310> block1b_project_conv False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7ef26ba250> block1b_project_bn False
# <keras.layers.core.dropout.Dropout object at 0x7f7efc193710> block1b_drop False
# <keras.layers.merge.Add object at 0x7f7ef1c33550> block1b_add False
# <keras.layers.convolutional.Conv2D object at 0x7f7ef1c79cd0> block2a_expand_conv False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7ef1b26450> block2a_expand_bn False
# <keras.layers.core.activation.Activation object at 0x7f7efc3b9a10> block2a_expand_activation False
# <keras.layers.convolutional.ZeroPadding2D object at 0x7f7ef1c4bbd0> block2a_dwconv_pad False
# <keras.layers.convolutional.DepthwiseConv2D object at 0x7f7ef1c4b4d0> block2a_dwconv False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7ef1ac9990> block2a_bn False
# <keras.layers.core.activation.Activation object at 0x7f7ef1b19e90> block2a_activation False
# <keras.layers.pooling.GlobalAveragePooling2D object at 0x7f7ef26989d0> block2a_se_squeeze False
# <keras.layers.core.reshape.Reshape object at 0x7f7ef26980d0> block2a_se_reshape False
# <keras.layers.convolutional.Conv2D object at 0x7f7ef268e190> block2a_se_reduce False
# <keras.layers.convolutional.Conv2D object at 0x7f7ef1b0c150> block2a_se_expand False
# <keras.layers.merge.Multiply object at 0x7f7efc22bfd0> block2a_se_excite False
# <keras.layers.convolutional.Conv2D object at 0x7f7ef1ae1e50> block2a_project_conv False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7ef1b7f3d0> block2a_project_bn False
# <keras.layers.convolutional.Conv2D object at 0x7f7efc2969d0> block2b_expand_conv False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7efc3fc150> block2b_expand_bn False
# <keras.layers.core.activation.Activation object at 0x7f7efc3f29d0> block2b_expand_activation False
# <keras.layers.convolutional.DepthwiseConv2D object at 0x7f7eeb437390> block2b_dwconv False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7ef1a92550> block2b_bn False
# <keras.layers.core.activation.Activation object at 0x7f7ef26dbe10> block2b_activation False
# <keras.layers.pooling.GlobalAveragePooling2D object at 0x7f7ef26d0950> block2b_se_squeeze False
# <keras.layers.core.reshape.Reshape object at 0x7f7ef1a9edd0> block2b_se_reshape False
# <keras.layers.convolutional.Conv2D object at 0x7f7ef1a9e690> block2b_se_reduce False
# <keras.layers.convolutional.Conv2D object at 0x7f7ef1aab550> block2b_se_expand False
# <keras.layers.merge.Multiply object at 0x7f7ef2733cd0> block2b_se_excite False
# <keras.layers.convolutional.Conv2D object at 0x7f7ef2727a90> block2b_project_conv False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7ef1af0b50> block2b_project_bn False
# <keras.layers.core.dropout.Dropout object at 0x7f7efc47fb90> block2b_drop False
# <keras.layers.merge.Add object at 0x7f7ef1a437d0> block2b_add False
# <keras.layers.convolutional.Conv2D object at 0x7f7efc477110> block2c_expand_conv False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7ef2721e90> block2c_expand_bn False
# <keras.layers.core.activation.Activation object at 0x7f7efc471210> block2c_expand_activation False
# <keras.layers.convolutional.DepthwiseConv2D object at 0x7f7efc471190> block2c_dwconv False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7eeb499b50> block2c_bn False
# <keras.layers.core.activation.Activation object at 0x7f7efc4c0c10> block2c_activation False
# <keras.layers.pooling.GlobalAveragePooling2D object at 0x7f7efc4a83d0> block2c_se_squeeze False
# <keras.layers.core.reshape.Reshape object at 0x7f7ef2712650> block2c_se_reshape False
# <keras.layers.convolutional.Conv2D object at 0x7f7ef2712810> block2c_se_reduce False
# <keras.layers.convolutional.Conv2D object at 0x7f7ef1b9d3d0> block2c_se_expand False
# <keras.layers.merge.Multiply object at 0x7f7efc563150> block2c_se_excite False
# <keras.layers.convolutional.Conv2D object at 0x7f7efc55f9d0> block2c_project_conv False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7efc4f3b90> block2c_project_bn False
# <keras.layers.core.dropout.Dropout object at 0x7f7ef276fe90> block2c_drop False
# <keras.layers.merge.Add object at 0x7f7ef276fa10> block2c_add False
# <keras.layers.convolutional.Conv2D object at 0x7f7ef1a82f10> block2d_expand_conv False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7eeb51ef10> block2d_expand_bn False
# <keras.layers.core.activation.Activation object at 0x7f7ef09dafd0> block2d_expand_activation False
# <keras.layers.convolutional.DepthwiseConv2D object at 0x7f7ef1b3be90> block2d_dwconv False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7ef1a599d0> block2d_bn False
# <keras.layers.core.activation.Activation object at 0x7f7ef274edd0> block2d_activation False
# <keras.layers.pooling.GlobalAveragePooling2D object at 0x7f7ef274ea90> block2d_se_squeeze False
# <keras.layers.core.reshape.Reshape object at 0x7f7ef1c44b10> block2d_se_reshape False
# <keras.layers.convolutional.Conv2D object at 0x7f7ef2744590> block2d_se_reduce False
# <keras.layers.convolutional.Conv2D object at 0x7f7ef2795450> block2d_se_expand False
# <keras.layers.merge.Multiply object at 0x7f7ef27886d0> block2d_se_excite False
# <keras.layers.convolutional.Conv2D object at 0x7f7ef27836d0> block2d_project_conv False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7efc5b3a50> block2d_project_bn False
# <keras.layers.core.dropout.Dropout object at 0x7f7ef27f6fd0> block2d_drop False
# <keras.layers.merge.Add object at 0x7f7ef27f06d0> block2d_add False
# <keras.layers.convolutional.Conv2D object at 0x7f7ef1a20c90> block3a_expand_conv False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7ef1a5da10> block3a_expand_bn False
# <keras.layers.core.activation.Activation object at 0x7f7efc664810> block3a_expand_activation False
# <keras.layers.convolutional.ZeroPadding2D object at 0x7f7efc664550> block3a_dwconv_pad False
# <keras.layers.convolutional.DepthwiseConv2D object at 0x7f7eeb5faad0> block3a_dwconv False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7efc5f8e10> block3a_bn False
# <keras.layers.core.activation.Activation object at 0x7f7efc4f0710> block3a_activation False
# <keras.layers.pooling.GlobalAveragePooling2D object at 0x7f7efc6a37d0> block3a_se_squeeze False
# <keras.layers.core.reshape.Reshape object at 0x7f7efc6a3d50> block3a_se_reshape False
# <keras.layers.convolutional.Conv2D object at 0x7f7efc6a3a10> block3a_se_reduce False
# <keras.layers.convolutional.Conv2D object at 0x7f7ef27d9cd0> block3a_se_expand False
# <keras.layers.merge.Multiply object at 0x7f7ef1a07510> block3a_se_excite False
# <keras.layers.convolutional.Conv2D object at 0x7f7ef1b348d0> block3a_project_conv False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7efc6835d0> block3a_project_bn False
# <keras.layers.convolutional.Conv2D object at 0x7f7ef27c9e90> block3b_expand_conv False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7efc675d50> block3b_expand_bn False
# <keras.layers.core.activation.Activation object at 0x7f7ef1a7fa90> block3b_expand_activation False
# <keras.layers.convolutional.DepthwiseConv2D object at 0x7f7efc67fed0> block3b_dwconv False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7ef1a14a50> block3b_bn False
# <keras.layers.core.activation.Activation object at 0x7f7ef1a6a5d0> block3b_activation False
# <keras.layers.pooling.GlobalAveragePooling2D object at 0x7f7ef2827e90> block3b_se_squeeze False
# <keras.layers.core.reshape.Reshape object at 0x7f7ef2821e50> block3b_se_reshape False
# <keras.layers.convolutional.Conv2D object at 0x7f7ef21e0410> block3b_se_reduce False
# <keras.layers.convolutional.Conv2D object at 0x7f7ef19f7750> block3b_se_expand False
# <keras.layers.merge.Multiply object at 0x7f7efc5a29d0> block3b_se_excite False
# <keras.layers.convolutional.Conv2D object at 0x7f7ef1ab2390> block3b_project_conv False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7efc722610> block3b_project_bn False
# <keras.layers.core.dropout.Dropout object at 0x7f7ef2814d10> block3b_drop False
# <keras.layers.merge.Add object at 0x7f7efc708b90> block3b_add False
# <keras.layers.convolutional.Conv2D object at 0x7f7efc708a90> block3c_expand_conv False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7ef19a6ad0> block3c_expand_bn False
# <keras.layers.core.activation.Activation object at 0x7f7ef2878e90> block3c_expand_activation False
# <keras.layers.convolutional.DepthwiseConv2D object at 0x7f7ef286b250> block3c_dwconv False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7ef1cf5c10> block3c_bn False
# <keras.layers.core.activation.Activation object at 0x7f7ef2855ed0> block3c_activation False
# <keras.layers.pooling.GlobalAveragePooling2D object at 0x7f7ef19bd610> block3c_se_squeeze False
# <keras.layers.core.reshape.Reshape object at 0x7f7ef19bdb90> block3c_se_reshape False
# <keras.layers.convolutional.Conv2D object at 0x7f7ef20da6d0> block3c_se_reduce False
# <keras.layers.convolutional.Conv2D object at 0x7f7ef194bf50> block3c_se_expand False
# <keras.layers.merge.Multiply object at 0x7f7efc62d590> block3c_se_excite False
# <keras.layers.convolutional.Conv2D object at 0x7f7efc62d350> block3c_project_conv False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7efc736e10> block3c_project_bn False
# <keras.layers.core.dropout.Dropout object at 0x7f7ef28b06d0> block3c_drop False
# <keras.layers.merge.Add object at 0x7f7ef19db290> block3c_add False
# <keras.layers.convolutional.Conv2D object at 0x7f7ef19dbb90> block3d_expand_conv False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7efc76f8d0> block3d_expand_bn False
# <keras.layers.core.activation.Activation object at 0x7f7ef28a7f90> block3d_expand_activation False
# <keras.layers.convolutional.DepthwiseConv2D object at 0x7f7ef28ab050> block3d_dwconv False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7ef1a196d0> block3d_bn False
# <keras.layers.core.activation.Activation object at 0x7f7ef288e390> block3d_activation False
# <keras.layers.pooling.GlobalAveragePooling2D object at 0x7f7ef1a96b50> block3d_se_squeeze False
# <keras.layers.core.reshape.Reshape object at 0x7f7ef19c8250> block3d_se_reshape False
# <keras.layers.convolutional.Conv2D object at 0x7f7efc821610> block3d_se_reduce False
# <keras.layers.convolutional.Conv2D object at 0x7f7efc814a90> block3d_se_expand False
# <keras.layers.merge.Multiply object at 0x7f7ef1998410> block3d_se_excite False
# <keras.layers.convolutional.Conv2D object at 0x7f7ef28f5e10> block3d_project_conv False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7ef28e2150> block3d_project_bn False
# <keras.layers.core.dropout.Dropout object at 0x7f7ef1920510> block3d_drop False
# <keras.layers.merge.Add object at 0x7f7ef1907e10> block3d_add False
# <keras.layers.convolutional.Conv2D object at 0x7f7ef196ea50> block4a_expand_conv False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7efc8313d0> block4a_expand_bn False
# <keras.layers.core.activation.Activation object at 0x7f7efc8292d0> block4a_expand_activation False
# <keras.layers.convolutional.ZeroPadding2D object at 0x7f7efc84fdd0> block4a_dwconv_pad False
# <keras.layers.convolutional.DepthwiseConv2D object at 0x7f7ef24c0790> block4a_dwconv False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7ef28c4e90> block4a_bn False
# <keras.layers.core.activation.Activation object at 0x7f7ef18cf2d0> block4a_activation False
# <keras.layers.pooling.GlobalAveragePooling2D object at 0x7f7ef293bdd0> block4a_se_squeeze False
# <keras.layers.core.reshape.Reshape object at 0x7f7ef293bc10> block4a_se_reshape False
# <keras.layers.convolutional.Conv2D object at 0x7f7ef19b7410> block4a_se_reduce False
# <keras.layers.convolutional.Conv2D object at 0x7f7ef2924150> block4a_se_expand False
# <keras.layers.merge.Multiply object at 0x7f7ef2914710> block4a_se_excite False
# <keras.layers.convolutional.Conv2D object at 0x7f7ef2914990> block4a_project_conv False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7ef191b210> block4a_project_bn False
# <keras.layers.convolutional.Conv2D object at 0x7f7efc8d5950> block4b_expand_conv False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7ef18d6a50> block4b_expand_bn False
# <keras.layers.core.activation.Activation object at 0x7f7ef2900ed0> block4b_expand_activation False
# <keras.layers.convolutional.DepthwiseConv2D object at 0x7f7ef2977ad0> block4b_dwconv False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7ef190d050> block4b_bn False
# <keras.layers.core.activation.Activation object at 0x7f7efc8cecd0> block4b_activation False
# <keras.layers.pooling.GlobalAveragePooling2D object at 0x7f7efc8ce590> block4b_se_squeeze False
# <keras.layers.core.reshape.Reshape object at 0x7f7efc918090> block4b_se_reshape False
# <keras.layers.convolutional.Conv2D object at 0x7f7efc90e0d0> block4b_se_reduce False
# <keras.layers.convolutional.Conv2D object at 0x7f7ef29571d0> block4b_se_expand False
# <keras.layers.merge.Multiply object at 0x7f7ef197b710> block4b_se_excite False
# <keras.layers.convolutional.Conv2D object at 0x7f7efc922f90> block4b_project_conv False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7ef197fd50> block4b_project_bn False
# <keras.layers.core.dropout.Dropout object at 0x7f7ef189da10> block4b_drop False
# <keras.layers.merge.Add object at 0x7f7efc934250> block4b_add False
# <keras.layers.convolutional.Conv2D object at 0x7f7efc934650> block4c_expand_conv False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7eeb8ef7d0> block4c_expand_bn False
# <keras.layers.core.activation.Activation object at 0x7f7ef18ad8d0> block4c_expand_activation False
# <keras.layers.convolutional.DepthwiseConv2D object at 0x7f7ef18ada50> block4c_dwconv False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7ef29b5c90> block4c_bn False
# <keras.layers.core.activation.Activation object at 0x7f7ef299aa90> block4c_activation False
# <keras.layers.pooling.GlobalAveragePooling2D object at 0x7f7ef299fb90> block4c_se_squeeze False
# <keras.layers.core.reshape.Reshape object at 0x7f7ef299f690> block4c_se_reshape False
# <keras.layers.convolutional.Conv2D object at 0x7f7ef18bffd0> block4c_se_reduce False
# <keras.layers.convolutional.Conv2D object at 0x7f7ef18baa50> block4c_se_expand False
# <keras.layers.merge.Multiply object at 0x7f7f1205b610> block4c_se_excite False
# <keras.layers.convolutional.Conv2D object at 0x7f7f12065490> block4c_project_conv False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7f12053550> block4c_project_bn False
# <keras.layers.core.dropout.Dropout object at 0x7f7ef1875dd0> block4c_drop False
# <keras.layers.merge.Add object at 0x7f7ef1875b10> block4c_add False
# <keras.layers.convolutional.Conv2D object at 0x7f7ef29ef390> block4d_expand_conv False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7ef29e2650> block4d_expand_bn False
# <keras.layers.core.activation.Activation object at 0x7f7ef29eab50> block4d_expand_activation False
# <keras.layers.convolutional.DepthwiseConv2D object at 0x7f7ef29dba90> block4d_dwconv False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7ef18cbb10> block4d_bn False
# <keras.layers.core.activation.Activation object at 0x7f7ef1895690> block4d_activation False
# <keras.layers.pooling.GlobalAveragePooling2D object at 0x7f7ef18190d0> block4d_se_squeeze False
# <keras.layers.core.reshape.Reshape object at 0x7f7ef18198d0> block4d_se_reshape False
# <keras.layers.convolutional.Conv2D object at 0x7f7ef1819c10> block4d_se_reduce False
# <keras.layers.convolutional.Conv2D object at 0x7f7f1207e2d0> block4d_se_expand False
# <keras.layers.merge.Multiply object at 0x7f7f120f0350> block4d_se_excite False
# <keras.layers.convolutional.Conv2D object at 0x7f7ef29c3a50> block4d_project_conv False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7ef19730d0> block4d_project_bn False
# <keras.layers.core.dropout.Dropout object at 0x7f7ef18f1250> block4d_drop False
# <keras.layers.merge.Add object at 0x7f7ef18b10d0> block4d_add False
# <keras.layers.convolutional.Conv2D object at 0x7f7f120b9090> block4e_expand_conv False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7f800541d0> block4e_expand_bn False
# <keras.layers.core.activation.Activation object at 0x7f7ef188bfd0> block4e_expand_activation False
# <keras.layers.convolutional.DepthwiseConv2D object at 0x7f7ef2a1f990> block4e_dwconv False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7ef17c8f50> block4e_bn False
# <keras.layers.core.activation.Activation object at 0x7f7f120c9150> block4e_activation False
# <keras.layers.pooling.GlobalAveragePooling2D object at 0x7f7f80092790> block4e_se_squeeze False
# <keras.layers.core.reshape.Reshape object at 0x7f7f8008a090> block4e_se_reshape False
# <keras.layers.convolutional.Conv2D object at 0x7f7f80021410> block4e_se_reduce False
# <keras.layers.convolutional.Conv2D object at 0x7f7ef17c2510> block4e_se_expand False
# <keras.layers.merge.Multiply object at 0x7f7ef1822410> block4e_se_excite False
# <keras.layers.convolutional.Conv2D object at 0x7f7ef2a78950> block4e_project_conv False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7ef2a6c850> block4e_project_bn False
# <keras.layers.core.dropout.Dropout object at 0x7f7ef2a60ad0> block4e_drop False
# <keras.layers.merge.Add object at 0x7f7f80082f90> block4e_add False
# <keras.layers.convolutional.Conv2D object at 0x7f7f8011c150> block4f_expand_conv False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7f800ace10> block4f_expand_bn False
# <keras.layers.core.activation.Activation object at 0x7f7ef1794e10> block4f_expand_activation False
# <keras.layers.convolutional.DepthwiseConv2D object at 0x7f7ef1937150> block4f_dwconv False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7ef2a41550> block4f_bn False
# <keras.layers.core.activation.Activation object at 0x7f7ef19cfa50> block4f_activation False
# <keras.layers.pooling.GlobalAveragePooling2D object at 0x7f7ef1835810> block4f_se_squeeze False
# <keras.layers.core.reshape.Reshape object at 0x7f7ef18354d0> block4f_se_reshape False
# <keras.layers.convolutional.Conv2D object at 0x7f7ef2ab5a90> block4f_se_reduce False
# <keras.layers.convolutional.Conv2D object at 0x7f7f800a5910> block4f_se_expand False
# <keras.layers.merge.Multiply object at 0x7f7ef185b4d0> block4f_se_excite False
# <keras.layers.convolutional.Conv2D object at 0x7f7eebaf9650> block4f_project_conv False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7ef1745fd0> block4f_project_bn False
# <keras.layers.core.dropout.Dropout object at 0x7f7f801393d0> block4f_drop False
# <keras.layers.merge.Add object at 0x7f7ef179ec10> block4f_add False
# <keras.layers.convolutional.Conv2D object at 0x7f7f80140d10> block5a_expand_conv False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7f120798d0> block5a_expand_bn False
# <keras.layers.core.activation.Activation object at 0x7f7ef184cb50> block5a_expand_activation False
# <keras.layers.convolutional.DepthwiseConv2D object at 0x7f7f80173790> block5a_dwconv False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7f80161310> block5a_bn False
# <keras.layers.core.activation.Activation object at 0x7f7ef2aefa50> block5a_activation False
# <keras.layers.pooling.GlobalAveragePooling2D object at 0x7f7ef17a5910> block5a_se_squeeze False
# <keras.layers.core.reshape.Reshape object at 0x7f7ef17a5250> block5a_se_reshape False
# <keras.layers.convolutional.Conv2D object at 0x7f7f80184950> block5a_se_reduce False
# <keras.layers.convolutional.Conv2D object at 0x7f7f80132ed0> block5a_se_expand False
# <keras.layers.merge.Multiply object at 0x7f7ef17ebdd0> block5a_se_excite False
# <keras.layers.convolutional.Conv2D object at 0x7f7f8ecdd450> block5a_project_conv False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7f8eccc150> block5a_project_bn False
# <keras.layers.convolutional.Conv2D object at 0x7f7ef2ac0350> block5b_expand_conv False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7ef176d910> block5b_expand_bn False
# <keras.layers.core.activation.Activation object at 0x7f7ef2b2b990> block5b_expand_activation False
# <keras.layers.convolutional.DepthwiseConv2D object at 0x7f7ef2b2b4d0> block5b_dwconv False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7ef172f990> block5b_bn False
# <keras.layers.core.activation.Activation object at 0x7f7f8ed3a090> block5b_activation False
# <keras.layers.pooling.GlobalAveragePooling2D object at 0x7f7f8ed52a90> block5b_se_squeeze False
# <keras.layers.core.reshape.Reshape object at 0x7f7eebbeff90> block5b_se_reshape False
# <keras.layers.convolutional.Conv2D object at 0x7f7ef17518d0> block5b_se_reduce False
# <keras.layers.convolutional.Conv2D object at 0x7f7ef2b0dcd0> block5b_se_expand False
# <keras.layers.merge.Multiply object at 0x7f7ef1738850> block5b_se_excite False
# <keras.layers.convolutional.Conv2D object at 0x7f7ef1862810> block5b_project_conv False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7ef2b672d0> block5b_project_bn False
# <keras.layers.core.dropout.Dropout object at 0x7f7ef17387d0> block5b_drop False
# <keras.layers.merge.Add object at 0x7f7f8ed28850> block5b_add False
# <keras.layers.convolutional.Conv2D object at 0x7f7f8ed28c90> block5c_expand_conv False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7ef16db8d0> block5c_expand_bn False
# <keras.layers.core.activation.Activation object at 0x7f7ef17156d0> block5c_expand_activation False
# <keras.layers.convolutional.DepthwiseConv2D object at 0x7f7ef1706f50> block5c_dwconv False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7ef16d0290> block5c_bn False
# <keras.layers.core.activation.Activation object at 0x7f7ef16e9550> block5c_activation False
# <keras.layers.pooling.GlobalAveragePooling2D object at 0x7f7ef16e9a10> block5c_se_squeeze False
# <keras.layers.core.reshape.Reshape object at 0x7f7ef16c1ad0> block5c_se_reshape False
# <keras.layers.convolutional.Conv2D object at 0x7f7ef16c1690> block5c_se_reduce False
# <keras.layers.convolutional.Conv2D object at 0x7f7f8ee50bd0> block5c_se_expand False
# <keras.layers.merge.Multiply object at 0x7f7ef17be1d0> block5c_se_excite False
# <keras.layers.convolutional.Conv2D object at 0x7f7f8ee8e550> block5c_project_conv False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7eebc40550> block5c_project_bn False
# <keras.layers.core.dropout.Dropout object at 0x7f7ef2ba44d0> block5c_drop False
# <keras.layers.merge.Add object at 0x7f7ef17aaf10> block5c_add False
# <keras.layers.convolutional.Conv2D object at 0x7f7ef17fd850> block5d_expand_conv False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7ef183bf10> block5d_expand_bn False
# <keras.layers.core.activation.Activation object at 0x7f7f8007ac50> block5d_expand_activation False
# <keras.layers.convolutional.DepthwiseConv2D object at 0x7f7ef1767610> block5d_dwconv False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7f8ee22c90> block5d_bn False
# <keras.layers.core.activation.Activation object at 0x7f7ef2b88c10> block5d_activation False
# <keras.layers.pooling.GlobalAveragePooling2D object at 0x7f7ef2b821d0> block5d_se_squeeze False
# <keras.layers.core.reshape.Reshape object at 0x7f7ef2b82410> block5d_se_reshape False
# <keras.layers.convolutional.Conv2D object at 0x7f7ef1727810> block5d_se_reduce False
# <keras.layers.convolutional.Conv2D object at 0x7f7f8eeefb50> block5d_se_expand False
# <keras.layers.merge.Multiply object at 0x7f7f8eed0590> block5d_se_excite False
# <keras.layers.convolutional.Conv2D object at 0x7f7ef2bf4890> block5d_project_conv False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7ef2be1dd0> block5d_project_bn False
# <keras.layers.core.dropout.Dropout object at 0x7f7ef2bcfe90> block5d_drop False
# <keras.layers.merge.Add object at 0x7f7ef16a7f90> block5d_add False
# <keras.layers.convolutional.Conv2D object at 0x7f7ef2bc45d0> block5e_expand_conv False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7f8ef5d5d0> block5e_expand_bn False
# <keras.layers.core.activation.Activation object at 0x7f7f8ee87890> block5e_expand_activation False
# <keras.layers.convolutional.DepthwiseConv2D object at 0x7f7f8ee87f50> block5e_dwconv False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7f8efcca50> block5e_bn False
# <keras.layers.core.activation.Activation object at 0x7f7ef2c27cd0> block5e_activation False
# <keras.layers.pooling.GlobalAveragePooling2D object at 0x7f7ef2c1d210> block5e_se_squeeze False
# <keras.layers.core.reshape.Reshape object at 0x7f7ef2c19350> block5e_se_reshape False
# <keras.layers.convolutional.Conv2D object at 0x7f7f8eee5450> block5e_se_reduce False
# <keras.layers.convolutional.Conv2D object at 0x7f7ef16472d0> block5e_se_expand False
# <keras.layers.merge.Multiply object at 0x7f7f8f050310> block5e_se_excite False
# <keras.layers.convolutional.Conv2D object at 0x7f7f8f044750> block5e_project_conv False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7f8f05de50> block5e_project_bn False
# <keras.layers.core.dropout.Dropout object at 0x7f7ef2c38a10> block5e_drop False
# <keras.layers.merge.Add object at 0x7f7ef2c38e90> block5e_add False
# <keras.layers.convolutional.Conv2D object at 0x7f7ef17cf3d0> block5f_expand_conv False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7ef2c79710> block5f_expand_bn False
# <keras.layers.core.activation.Activation object at 0x7f7ef168ac90> block5f_expand_activation False
# <keras.layers.convolutional.DepthwiseConv2D object at 0x7f7ef1710cd0> block5f_dwconv False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7ef16ad150> block5f_bn False
# <keras.layers.core.activation.Activation object at 0x7f7f8f069b10> block5f_activation False
# <keras.layers.pooling.GlobalAveragePooling2D object at 0x7f7f8f03cf90> block5f_se_squeeze False
# <keras.layers.core.reshape.Reshape object at 0x7f7f8f063e90> block5f_se_reshape False
# <keras.layers.convolutional.Conv2D object at 0x7f7f8f063710> block5f_se_reduce False
# <keras.layers.convolutional.Conv2D object at 0x7f7f8f083050> block5f_se_expand False
# <keras.layers.merge.Multiply object at 0x7f7ef1660a50> block5f_se_excite False
# <keras.layers.convolutional.Conv2D object at 0x7f7ef16603d0> block5f_project_conv False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7ef298e410> block5f_project_bn False
# <keras.layers.core.dropout.Dropout object at 0x7f7ef2c6db10> block5f_drop False
# <keras.layers.merge.Add object at 0x7f7ef2c68c50> block5f_add False
# <keras.layers.convolutional.Conv2D object at 0x7f7eebe19350> block6a_expand_conv False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7ef16846d0> block6a_expand_bn False
# <keras.layers.core.activation.Activation object at 0x7f7f8f1103d0> block6a_expand_activation False
# <keras.layers.convolutional.ZeroPadding2D object at 0x7f7f8f107b10> block6a_dwconv_pad False
# <keras.layers.convolutional.DepthwiseConv2D object at 0x7f7f8f107110> block6a_dwconv False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7f8f0a5750> block6a_bn False
# <keras.layers.core.activation.Activation object at 0x7f7f8f0568d0> block6a_activation False
# <keras.layers.pooling.GlobalAveragePooling2D object at 0x7f7ef1784a10> block6a_se_squeeze False
# <keras.layers.core.reshape.Reshape object at 0x7f7ef1784710> block6a_se_reshape False
# <keras.layers.convolutional.Conv2D object at 0x7f7ef2cb8fd0> block6a_se_reduce False
# <keras.layers.convolutional.Conv2D object at 0x7f7ef1626190> block6a_se_expand False
# <keras.layers.merge.Multiply object at 0x7f7ef26f49d0> block6a_se_excite False
# <keras.layers.convolutional.Conv2D object at 0x7f7ef16fde10> block6a_project_conv False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7ef2cfd610> block6a_project_bn False
# <keras.layers.convolutional.Conv2D object at 0x7f7f8f16b5d0> block6b_expand_conv False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7ef15d3210> block6b_expand_bn False
# <keras.layers.core.activation.Activation object at 0x7f7f8f1649d0> block6b_expand_activation False
# <keras.layers.convolutional.DepthwiseConv2D object at 0x7f7f8f1c2790> block6b_dwconv False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7ef15f0c50> block6b_bn False
# <keras.layers.core.activation.Activation object at 0x7f7f8f1bb1d0> block6b_activation False
# <keras.layers.pooling.GlobalAveragePooling2D object at 0x7f7ef2cdae90> block6b_se_squeeze False
# <keras.layers.core.reshape.Reshape object at 0x7f7ef167ca90> block6b_se_reshape False
# <keras.layers.convolutional.Conv2D object at 0x7f7f8f1b5850> block6b_se_reduce False
# <keras.layers.convolutional.Conv2D object at 0x7f7ef2cce950> block6b_se_expand False
# <keras.layers.merge.Multiply object at 0x7f7ef159a1d0> block6b_se_excite False
# <keras.layers.convolutional.Conv2D object at 0x7f7ef1691b50> block6b_project_conv False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7ef166f610> block6b_project_bn False
# <keras.layers.core.dropout.Dropout object at 0x7f7f8f2483d0> block6b_drop False
# <keras.layers.merge.Add object at 0x7f7f8f2482d0> block6b_add False
# <keras.layers.convolutional.Conv2D object at 0x7f7eebf7e990> block6c_expand_conv False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7ef2d361d0> block6c_expand_bn False
# <keras.layers.core.activation.Activation object at 0x7f7ef2d2cc50> block6c_expand_activation False
# <keras.layers.convolutional.DepthwiseConv2D object at 0x7f7ef2d2cdd0> block6c_dwconv False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7ef2d20bd0> block6c_bn False
# <keras.layers.core.activation.Activation object at 0x7f7ef1e214d0> block6c_activation False
# <keras.layers.pooling.GlobalAveragePooling2D object at 0x7f7ef2d14c10> block6c_se_squeeze False
# <keras.layers.core.reshape.Reshape object at 0x7f7ef15b6690> block6c_se_reshape False
# <keras.layers.convolutional.Conv2D object at 0x7f7f8f252dd0> block6c_se_reduce False
# <keras.layers.convolutional.Conv2D object at 0x7f7f8f2a5f90> block6c_se_expand False
# <keras.layers.merge.Multiply object at 0x7f7f8f2c4450> block6c_se_excite False
# <keras.layers.convolutional.Conv2D object at 0x7f7ef2d100d0> block6c_project_conv False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7ef15ad150> block6c_project_bn False
# <keras.layers.core.dropout.Dropout object at 0x7f7ef2d01c90> block6c_drop False
# <keras.layers.merge.Add object at 0x7f7ef15e4190> block6c_add False
# <keras.layers.convolutional.Conv2D object at 0x7f7ef15e4790> block6d_expand_conv False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7ef2d75d10> block6d_expand_bn False
# <keras.layers.core.activation.Activation object at 0x7f7ef2d75610> block6d_expand_activation False
# <keras.layers.convolutional.DepthwiseConv2D object at 0x7f7f8f2b2a50> block6d_dwconv False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7ef1631f10> block6d_bn False
# <keras.layers.core.activation.Activation object at 0x7f7ef1510c10> block6d_activation False
# <keras.layers.pooling.GlobalAveragePooling2D object at 0x7f7f8f414c10> block6d_se_squeeze False
# <keras.layers.core.reshape.Reshape object at 0x7f7ef2dbc610> block6d_se_reshape False
# <keras.layers.convolutional.Conv2D object at 0x7f7ef2dbcbd0> block6d_se_reduce False
# <keras.layers.convolutional.Conv2D object at 0x7f7ef2daba90> block6d_se_expand False
# <keras.layers.merge.Multiply object at 0x7f7f8f1e3f50> block6d_se_excite False
# <keras.layers.convolutional.Conv2D object at 0x7f7f8f4cb690> block6d_project_conv False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7f8f4d9b10> block6d_project_bn False
# <keras.layers.core.dropout.Dropout object at 0x7f7ef2d99c90> block6d_drop False
# <keras.layers.merge.Add object at 0x7f7ef1576fd0> block6d_add False
# <keras.layers.convolutional.Conv2D object at 0x7f7ef154c0d0> block6e_expand_conv False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7eec065410> block6e_expand_bn False
# <keras.layers.core.activation.Activation object at 0x7f7ef2d88290> block6e_expand_activation False
# <keras.layers.convolutional.DepthwiseConv2D object at 0x7f7ef15d0a50> block6e_dwconv False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7ef2bef590> block6e_bn False
# <keras.layers.core.activation.Activation object at 0x7f7f8f529350> block6e_activation False
# <keras.layers.pooling.GlobalAveragePooling2D object at 0x7f7f8f544450> block6e_se_squeeze False
# <keras.layers.core.reshape.Reshape object at 0x7f7f8f544b90> block6e_se_reshape False
# <keras.layers.convolutional.Conv2D object at 0x7f7eec0b5450> block6e_se_reduce False
# <keras.layers.convolutional.Conv2D object at 0x7f7ef15369d0> block6e_se_expand False
# <keras.layers.merge.Multiply object at 0x7f7ef2de8410> block6e_se_excite False
# <keras.layers.convolutional.Conv2D object at 0x7f7ef1541d90> block6e_project_conv False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7ef2dda610> block6e_project_bn False
# <keras.layers.core.dropout.Dropout object at 0x7f7ef14c7210> block6e_drop False
# <keras.layers.merge.Add object at 0x7f7ef14c77d0> block6e_add False
# <keras.layers.convolutional.Conv2D object at 0x7f7eec0e1190> block6f_expand_conv False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7eec0d7250> block6f_expand_bn False
# <keras.layers.core.activation.Activation object at 0x7f7ef151f910> block6f_expand_activation False
# <keras.layers.convolutional.DepthwiseConv2D object at 0x7f7ef151fe10> block6f_dwconv False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7ef2e3a210> block6f_bn False
# <keras.layers.core.activation.Activation object at 0x7f7ef2e34b50> block6f_activation False
# <keras.layers.pooling.GlobalAveragePooling2D object at 0x7f7ef2e2a950> block6f_se_squeeze False
# <keras.layers.core.reshape.Reshape object at 0x7f7f8ee58b50> block6f_se_reshape False
# <keras.layers.convolutional.Conv2D object at 0x7f7f8ee58a90> block6f_se_reduce False
# <keras.layers.convolutional.Conv2D object at 0x7f7ef2e248d0> block6f_se_expand False
# <keras.layers.merge.Multiply object at 0x7f7ef2e0b810> block6f_se_excite False
# <keras.layers.convolutional.Conv2D object at 0x7f7ef2e0bc50> block6f_project_conv False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7f8f6ab5d0> block6f_project_bn False
# <keras.layers.core.dropout.Dropout object at 0x7f7f8f75bc10> block6f_drop False
# <keras.layers.merge.Add object at 0x7f7ef1494810> block6f_add False
# <keras.layers.convolutional.Conv2D object at 0x7f7ef2e7dd90> block6g_expand_conv False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7ef14a2d10> block6g_expand_bn False
# <keras.layers.core.activation.Activation object at 0x7f7f8f72b850> block6g_expand_activation False
# <keras.layers.convolutional.DepthwiseConv2D object at 0x7f7f8f81de50> block6g_dwconv False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7eec1a5f90> block6g_bn False
# <keras.layers.core.activation.Activation object at 0x7f7ef14af590> block6g_activation False
# <keras.layers.pooling.GlobalAveragePooling2D object at 0x7f7f8f8178d0> block6g_se_squeeze False
# <keras.layers.core.reshape.Reshape object at 0x7f7f8f8171d0> block6g_se_reshape False
# <keras.layers.convolutional.Conv2D object at 0x7f7ef2e4ef90> block6g_se_reduce False
# <keras.layers.convolutional.Conv2D object at 0x7f7ef1548090> block6g_se_expand False
# <keras.layers.merge.Multiply object at 0x7f7f8f88b050> block6g_se_excite False
# <keras.layers.convolutional.Conv2D object at 0x7f7f8f8a1150> block6g_project_conv False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7ef149a310> block6g_project_bn False
# <keras.layers.core.dropout.Dropout object at 0x7f7ef2eb33d0> block6g_drop False
# <keras.layers.merge.Add object at 0x7f7ef2ead050> block6g_add False
# <keras.layers.convolutional.Conv2D object at 0x7f7ef14e2b10> block6h_expand_conv False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7ef2e9a790> block6h_expand_bn False
# <keras.layers.core.activation.Activation object at 0x7f7ef1465450> block6h_expand_activation False
# <keras.layers.convolutional.DepthwiseConv2D object at 0x7f7ef1465a50> block6h_dwconv False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7ef0b14c50> block6h_bn False
# <keras.layers.core.activation.Activation object at 0x7f7f8f8bf2d0> block6h_activation False
# <keras.layers.pooling.GlobalAveragePooling2D object at 0x7f7f8f6a4c50> block6h_se_squeeze False
# <keras.layers.core.reshape.Reshape object at 0x7f7f8f6a4250> block6h_se_reshape False
# <keras.layers.convolutional.Conv2D object at 0x7f7ef2e872d0> block6h_se_reduce False
# <keras.layers.convolutional.Conv2D object at 0x7f7f8f95c550> block6h_se_expand False
# <keras.layers.merge.Multiply object at 0x7f7f8f879090> block6h_se_excite False
# <keras.layers.convolutional.Conv2D object at 0x7f7f8f879810> block6h_project_conv False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7ef2ee9090> block6h_project_bn False
# <keras.layers.core.dropout.Dropout object at 0x7f7ef142cd50> block6h_drop False
# <keras.layers.merge.Add object at 0x7f7ef2ee4d90> block6h_add False
# <keras.layers.convolutional.Conv2D object at 0x7f7ef2ed5050> block7a_expand_conv False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7ef14e8590> block7a_expand_bn False
# <keras.layers.core.activation.Activation object at 0x7f7ef13c5b90> block7a_expand_activation False
# <keras.layers.convolutional.DepthwiseConv2D object at 0x7f7ef2eceed0> block7a_dwconv False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7ef13d3e50> block7a_bn False
# <keras.layers.core.activation.Activation object at 0x7f7ef2f3c3d0> block7a_activation False
# <keras.layers.pooling.GlobalAveragePooling2D object at 0x7f7ef2f30650> block7a_se_squeeze False
# <keras.layers.core.reshape.Reshape object at 0x7f7ef0ad5f50> block7a_se_reshape False
# <keras.layers.convolutional.Conv2D object at 0x7f7f8f97d850> block7a_se_reduce False
# <keras.layers.convolutional.Conv2D object at 0x7f7f8f882d10> block7a_se_expand False
# <keras.layers.merge.Multiply object at 0x7f7f8f9be610> block7a_se_excite False
# <keras.layers.convolutional.Conv2D object at 0x7f7ef20f8590> block7a_project_conv False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7ef1470e50> block7a_project_bn False
# <keras.layers.convolutional.Conv2D object at 0x7f7ef2f0f990> block7b_expand_conv False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7ef152c610> block7b_expand_bn False
# <keras.layers.core.activation.Activation object at 0x7f7f8f736d10> block7b_expand_activation False
# <keras.layers.convolutional.DepthwiseConv2D object at 0x7f7f8f736750> block7b_dwconv False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7f8fa27ad0> block7b_bn False
# <keras.layers.core.activation.Activation object at 0x7f7f8f983dd0> block7b_activation False
# <keras.layers.pooling.GlobalAveragePooling2D object at 0x7f7f8f983fd0> block7b_se_squeeze False
# <keras.layers.core.reshape.Reshape object at 0x7f7ef2f7b810> block7b_se_reshape False
# <keras.layers.convolutional.Conv2D object at 0x7f7f8fa54a90> block7b_se_reduce False
# <keras.layers.convolutional.Conv2D object at 0x7f7ef2f742d0> block7b_se_expand False
# <keras.layers.merge.Multiply object at 0x7f7ef2f679d0> block7b_se_excite False
# <keras.layers.convolutional.Conv2D object at 0x7f7ef2f618d0> block7b_project_conv False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7ef143e690> block7b_project_bn False
# <keras.layers.core.dropout.Dropout object at 0x7f7f8fadb610> block7b_drop False
# <keras.layers.merge.Add object at 0x7f7f8fad30d0> block7b_add False
# <keras.layers.convolutional.Conv2D object at 0x7f7f8facc250> top_conv False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7ef1c18bd0> top_bn False
# <keras.layers.core.activation.Activation object at 0x7f7ef2fb9dd0> top_activation False

# %% [markdown]
# ## Unfreezing all the layers of the base_model i.e EfficientNetB4 for Fine-Tuning

# %%
for layer in loaded_model.layers:
  layer.trainable= True
  print(layer, layer.name, layer.trainable)
# Out:
# <keras.engine.input_layer.InputLayer object at 0x7f7ef2226990> input_layer True
# <keras.engine.functional.Functional object at 0x7f7ef235ea90> efficientnetb4 True
# <keras.layers.pooling.GlobalAveragePooling2D object at 0x7f7ef1b8e7d0> pooling_layer True
# <keras.layers.core.dropout.Dropout object at 0x7f7eef6de790> dropout_layer True
# <keras.layers.core.dense.Dense object at 0x7f7efc2a4690> regularization_layer True
# <keras.layers.core.dense.Dense object at 0x7f7efc099a90> dense True
# <keras.layers.core.activation.Activation object at 0x7f7ef25db810> softmax_float32 True

# %%
for layer in loaded_model.layers[1].layers:
  print(layer, layer.name, layer.trainable)
# Out:
# <keras.engine.input_layer.InputLayer object at 0x7f7ef25db450> input_1 True
# <keras.layers.preprocessing.image_preprocessing.Rescaling object at 0x7f7ef1c0c6d0> rescaling True
# <keras.layers.preprocessing.normalization.Normalization object at 0x7f7ef25d4490> normalization True
# <keras.layers.convolutional.ZeroPadding2D object at 0x7f7ef1baa690> stem_conv_pad True
# <keras.layers.convolutional.Conv2D object at 0x7f7ef1b95290> stem_conv True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7ef25c0210> stem_bn True
# <keras.layers.core.activation.Activation object at 0x7f7ef1cfb9d0> stem_activation True
# <keras.layers.convolutional.DepthwiseConv2D object at 0x7f7efc1b8150> block1a_dwconv True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7efc28fb10> block1a_bn True
# <keras.layers.core.activation.Activation object at 0x7f7efc2d2ad0> block1a_activation True
# <keras.layers.pooling.GlobalAveragePooling2D object at 0x7f7eeb28a190> block1a_se_squeeze True
# <keras.layers.core.reshape.Reshape object at 0x7f7efc2cc510> block1a_se_reshape True
# <keras.layers.convolutional.Conv2D object at 0x7f7ef1b5acd0> block1a_se_reduce True
# <keras.layers.convolutional.Conv2D object at 0x7f7efc20a190> block1a_se_expand True
# <keras.layers.merge.Multiply object at 0x7f7ef2610690> block1a_se_excite True
# <keras.layers.convolutional.Conv2D object at 0x7f7efc2b1610> block1a_project_conv True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7ef1ba3050> block1a_project_bn True
# <keras.layers.convolutional.DepthwiseConv2D object at 0x7f7ef26680d0> block1b_dwconv True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7efc3594d0> block1b_bn True
# <keras.layers.core.activation.Activation object at 0x7f7ef265f610> block1b_activation True
# <keras.layers.pooling.GlobalAveragePooling2D object at 0x7f7ef2650e90> block1b_se_squeeze True
# <keras.layers.core.reshape.Reshape object at 0x7f7ef251d890> block1b_se_reshape True
# <keras.layers.convolutional.Conv2D object at 0x7f7efc350e90> block1b_se_reduce True
# <keras.layers.convolutional.Conv2D object at 0x7f7ef1beea10> block1b_se_expand True
# <keras.layers.merge.Multiply object at 0x7f7efc3a7f90> block1b_se_excite True
# <keras.layers.convolutional.Conv2D object at 0x7f7ef264c310> block1b_project_conv True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7ef26ba250> block1b_project_bn True
# <keras.layers.core.dropout.Dropout object at 0x7f7efc193710> block1b_drop True
# <keras.layers.merge.Add object at 0x7f7ef1c33550> block1b_add True
# <keras.layers.convolutional.Conv2D object at 0x7f7ef1c79cd0> block2a_expand_conv True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7ef1b26450> block2a_expand_bn True
# <keras.layers.core.activation.Activation object at 0x7f7efc3b9a10> block2a_expand_activation True
# <keras.layers.convolutional.ZeroPadding2D object at 0x7f7ef1c4bbd0> block2a_dwconv_pad True
# <keras.layers.convolutional.DepthwiseConv2D object at 0x7f7ef1c4b4d0> block2a_dwconv True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7ef1ac9990> block2a_bn True
# <keras.layers.core.activation.Activation object at 0x7f7ef1b19e90> block2a_activation True
# <keras.layers.pooling.GlobalAveragePooling2D object at 0x7f7ef26989d0> block2a_se_squeeze True
# <keras.layers.core.reshape.Reshape object at 0x7f7ef26980d0> block2a_se_reshape True
# <keras.layers.convolutional.Conv2D object at 0x7f7ef268e190> block2a_se_reduce True
# <keras.layers.convolutional.Conv2D object at 0x7f7ef1b0c150> block2a_se_expand True
# <keras.layers.merge.Multiply object at 0x7f7efc22bfd0> block2a_se_excite True
# <keras.layers.convolutional.Conv2D object at 0x7f7ef1ae1e50> block2a_project_conv True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7ef1b7f3d0> block2a_project_bn True
# <keras.layers.convolutional.Conv2D object at 0x7f7efc2969d0> block2b_expand_conv True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7efc3fc150> block2b_expand_bn True
# <keras.layers.core.activation.Activation object at 0x7f7efc3f29d0> block2b_expand_activation True
# <keras.layers.convolutional.DepthwiseConv2D object at 0x7f7eeb437390> block2b_dwconv True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7ef1a92550> block2b_bn True
# <keras.layers.core.activation.Activation object at 0x7f7ef26dbe10> block2b_activation True
# <keras.layers.pooling.GlobalAveragePooling2D object at 0x7f7ef26d0950> block2b_se_squeeze True
# <keras.layers.core.reshape.Reshape object at 0x7f7ef1a9edd0> block2b_se_reshape True
# <keras.layers.convolutional.Conv2D object at 0x7f7ef1a9e690> block2b_se_reduce True
# <keras.layers.convolutional.Conv2D object at 0x7f7ef1aab550> block2b_se_expand True
# <keras.layers.merge.Multiply object at 0x7f7ef2733cd0> block2b_se_excite True
# <keras.layers.convolutional.Conv2D object at 0x7f7ef2727a90> block2b_project_conv True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7ef1af0b50> block2b_project_bn True
# <keras.layers.core.dropout.Dropout object at 0x7f7efc47fb90> block2b_drop True
# <keras.layers.merge.Add object at 0x7f7ef1a437d0> block2b_add True
# <keras.layers.convolutional.Conv2D object at 0x7f7efc477110> block2c_expand_conv True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7ef2721e90> block2c_expand_bn True
# <keras.layers.core.activation.Activation object at 0x7f7efc471210> block2c_expand_activation True
# <keras.layers.convolutional.DepthwiseConv2D object at 0x7f7efc471190> block2c_dwconv True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7eeb499b50> block2c_bn True
# <keras.layers.core.activation.Activation object at 0x7f7efc4c0c10> block2c_activation True
# <keras.layers.pooling.GlobalAveragePooling2D object at 0x7f7efc4a83d0> block2c_se_squeeze True
# <keras.layers.core.reshape.Reshape object at 0x7f7ef2712650> block2c_se_reshape True
# <keras.layers.convolutional.Conv2D object at 0x7f7ef2712810> block2c_se_reduce True
# <keras.layers.convolutional.Conv2D object at 0x7f7ef1b9d3d0> block2c_se_expand True
# <keras.layers.merge.Multiply object at 0x7f7efc563150> block2c_se_excite True
# <keras.layers.convolutional.Conv2D object at 0x7f7efc55f9d0> block2c_project_conv True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7efc4f3b90> block2c_project_bn True
# <keras.layers.core.dropout.Dropout object at 0x7f7ef276fe90> block2c_drop True
# <keras.layers.merge.Add object at 0x7f7ef276fa10> block2c_add True
# <keras.layers.convolutional.Conv2D object at 0x7f7ef1a82f10> block2d_expand_conv True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7eeb51ef10> block2d_expand_bn True
# <keras.layers.core.activation.Activation object at 0x7f7ef09dafd0> block2d_expand_activation True
# <keras.layers.convolutional.DepthwiseConv2D object at 0x7f7ef1b3be90> block2d_dwconv True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7ef1a599d0> block2d_bn True
# <keras.layers.core.activation.Activation object at 0x7f7ef274edd0> block2d_activation True
# <keras.layers.pooling.GlobalAveragePooling2D object at 0x7f7ef274ea90> block2d_se_squeeze True
# <keras.layers.core.reshape.Reshape object at 0x7f7ef1c44b10> block2d_se_reshape True
# <keras.layers.convolutional.Conv2D object at 0x7f7ef2744590> block2d_se_reduce True
# <keras.layers.convolutional.Conv2D object at 0x7f7ef2795450> block2d_se_expand True
# <keras.layers.merge.Multiply object at 0x7f7ef27886d0> block2d_se_excite True
# <keras.layers.convolutional.Conv2D object at 0x7f7ef27836d0> block2d_project_conv True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7efc5b3a50> block2d_project_bn True
# <keras.layers.core.dropout.Dropout object at 0x7f7ef27f6fd0> block2d_drop True
# <keras.layers.merge.Add object at 0x7f7ef27f06d0> block2d_add True
# <keras.layers.convolutional.Conv2D object at 0x7f7ef1a20c90> block3a_expand_conv True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7ef1a5da10> block3a_expand_bn True
# <keras.layers.core.activation.Activation object at 0x7f7efc664810> block3a_expand_activation True
# <keras.layers.convolutional.ZeroPadding2D object at 0x7f7efc664550> block3a_dwconv_pad True
# <keras.layers.convolutional.DepthwiseConv2D object at 0x7f7eeb5faad0> block3a_dwconv True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7efc5f8e10> block3a_bn True
# <keras.layers.core.activation.Activation object at 0x7f7efc4f0710> block3a_activation True
# <keras.layers.pooling.GlobalAveragePooling2D object at 0x7f7efc6a37d0> block3a_se_squeeze True
# <keras.layers.core.reshape.Reshape object at 0x7f7efc6a3d50> block3a_se_reshape True
# <keras.layers.convolutional.Conv2D object at 0x7f7efc6a3a10> block3a_se_reduce True
# <keras.layers.convolutional.Conv2D object at 0x7f7ef27d9cd0> block3a_se_expand True
# <keras.layers.merge.Multiply object at 0x7f7ef1a07510> block3a_se_excite True
# <keras.layers.convolutional.Conv2D object at 0x7f7ef1b348d0> block3a_project_conv True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7efc6835d0> block3a_project_bn True
# <keras.layers.convolutional.Conv2D object at 0x7f7ef27c9e90> block3b_expand_conv True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7efc675d50> block3b_expand_bn True
# <keras.layers.core.activation.Activation object at 0x7f7ef1a7fa90> block3b_expand_activation True
# <keras.layers.convolutional.DepthwiseConv2D object at 0x7f7efc67fed0> block3b_dwconv True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7ef1a14a50> block3b_bn True
# <keras.layers.core.activation.Activation object at 0x7f7ef1a6a5d0> block3b_activation True
# <keras.layers.pooling.GlobalAveragePooling2D object at 0x7f7ef2827e90> block3b_se_squeeze True
# <keras.layers.core.reshape.Reshape object at 0x7f7ef2821e50> block3b_se_reshape True
# <keras.layers.convolutional.Conv2D object at 0x7f7ef21e0410> block3b_se_reduce True
# <keras.layers.convolutional.Conv2D object at 0x7f7ef19f7750> block3b_se_expand True
# <keras.layers.merge.Multiply object at 0x7f7efc5a29d0> block3b_se_excite True
# <keras.layers.convolutional.Conv2D object at 0x7f7ef1ab2390> block3b_project_conv True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7efc722610> block3b_project_bn True
# <keras.layers.core.dropout.Dropout object at 0x7f7ef2814d10> block3b_drop True
# <keras.layers.merge.Add object at 0x7f7efc708b90> block3b_add True
# <keras.layers.convolutional.Conv2D object at 0x7f7efc708a90> block3c_expand_conv True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7ef19a6ad0> block3c_expand_bn True
# <keras.layers.core.activation.Activation object at 0x7f7ef2878e90> block3c_expand_activation True
# <keras.layers.convolutional.DepthwiseConv2D object at 0x7f7ef286b250> block3c_dwconv True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7ef1cf5c10> block3c_bn True
# <keras.layers.core.activation.Activation object at 0x7f7ef2855ed0> block3c_activation True
# <keras.layers.pooling.GlobalAveragePooling2D object at 0x7f7ef19bd610> block3c_se_squeeze True
# <keras.layers.core.reshape.Reshape object at 0x7f7ef19bdb90> block3c_se_reshape True
# <keras.layers.convolutional.Conv2D object at 0x7f7ef20da6d0> block3c_se_reduce True
# <keras.layers.convolutional.Conv2D object at 0x7f7ef194bf50> block3c_se_expand True
# <keras.layers.merge.Multiply object at 0x7f7efc62d590> block3c_se_excite True
# <keras.layers.convolutional.Conv2D object at 0x7f7efc62d350> block3c_project_conv True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7efc736e10> block3c_project_bn True
# <keras.layers.core.dropout.Dropout object at 0x7f7ef28b06d0> block3c_drop True
# <keras.layers.merge.Add object at 0x7f7ef19db290> block3c_add True
# <keras.layers.convolutional.Conv2D object at 0x7f7ef19dbb90> block3d_expand_conv True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7efc76f8d0> block3d_expand_bn True
# <keras.layers.core.activation.Activation object at 0x7f7ef28a7f90> block3d_expand_activation True
# <keras.layers.convolutional.DepthwiseConv2D object at 0x7f7ef28ab050> block3d_dwconv True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7ef1a196d0> block3d_bn True
# <keras.layers.core.activation.Activation object at 0x7f7ef288e390> block3d_activation True
# <keras.layers.pooling.GlobalAveragePooling2D object at 0x7f7ef1a96b50> block3d_se_squeeze True
# <keras.layers.core.reshape.Reshape object at 0x7f7ef19c8250> block3d_se_reshape True
# <keras.layers.convolutional.Conv2D object at 0x7f7efc821610> block3d_se_reduce True
# <keras.layers.convolutional.Conv2D object at 0x7f7efc814a90> block3d_se_expand True
# <keras.layers.merge.Multiply object at 0x7f7ef1998410> block3d_se_excite True
# <keras.layers.convolutional.Conv2D object at 0x7f7ef28f5e10> block3d_project_conv True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7ef28e2150> block3d_project_bn True
# <keras.layers.core.dropout.Dropout object at 0x7f7ef1920510> block3d_drop True
# <keras.layers.merge.Add object at 0x7f7ef1907e10> block3d_add True
# <keras.layers.convolutional.Conv2D object at 0x7f7ef196ea50> block4a_expand_conv True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7efc8313d0> block4a_expand_bn True
# <keras.layers.core.activation.Activation object at 0x7f7efc8292d0> block4a_expand_activation True
# <keras.layers.convolutional.ZeroPadding2D object at 0x7f7efc84fdd0> block4a_dwconv_pad True
# <keras.layers.convolutional.DepthwiseConv2D object at 0x7f7ef24c0790> block4a_dwconv True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7ef28c4e90> block4a_bn True
# <keras.layers.core.activation.Activation object at 0x7f7ef18cf2d0> block4a_activation True
# <keras.layers.pooling.GlobalAveragePooling2D object at 0x7f7ef293bdd0> block4a_se_squeeze True
# <keras.layers.core.reshape.Reshape object at 0x7f7ef293bc10> block4a_se_reshape True
# <keras.layers.convolutional.Conv2D object at 0x7f7ef19b7410> block4a_se_reduce True
# <keras.layers.convolutional.Conv2D object at 0x7f7ef2924150> block4a_se_expand True
# <keras.layers.merge.Multiply object at 0x7f7ef2914710> block4a_se_excite True
# <keras.layers.convolutional.Conv2D object at 0x7f7ef2914990> block4a_project_conv True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7ef191b210> block4a_project_bn True
# <keras.layers.convolutional.Conv2D object at 0x7f7efc8d5950> block4b_expand_conv True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7ef18d6a50> block4b_expand_bn True
# <keras.layers.core.activation.Activation object at 0x7f7ef2900ed0> block4b_expand_activation True
# <keras.layers.convolutional.DepthwiseConv2D object at 0x7f7ef2977ad0> block4b_dwconv True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7ef190d050> block4b_bn True
# <keras.layers.core.activation.Activation object at 0x7f7efc8cecd0> block4b_activation True
# <keras.layers.pooling.GlobalAveragePooling2D object at 0x7f7efc8ce590> block4b_se_squeeze True
# <keras.layers.core.reshape.Reshape object at 0x7f7efc918090> block4b_se_reshape True
# <keras.layers.convolutional.Conv2D object at 0x7f7efc90e0d0> block4b_se_reduce True
# <keras.layers.convolutional.Conv2D object at 0x7f7ef29571d0> block4b_se_expand True
# <keras.layers.merge.Multiply object at 0x7f7ef197b710> block4b_se_excite True
# <keras.layers.convolutional.Conv2D object at 0x7f7efc922f90> block4b_project_conv True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7ef197fd50> block4b_project_bn True
# <keras.layers.core.dropout.Dropout object at 0x7f7ef189da10> block4b_drop True
# <keras.layers.merge.Add object at 0x7f7efc934250> block4b_add True
# <keras.layers.convolutional.Conv2D object at 0x7f7efc934650> block4c_expand_conv True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7eeb8ef7d0> block4c_expand_bn True
# <keras.layers.core.activation.Activation object at 0x7f7ef18ad8d0> block4c_expand_activation True
# <keras.layers.convolutional.DepthwiseConv2D object at 0x7f7ef18ada50> block4c_dwconv True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7ef29b5c90> block4c_bn True
# <keras.layers.core.activation.Activation object at 0x7f7ef299aa90> block4c_activation True
# <keras.layers.pooling.GlobalAveragePooling2D object at 0x7f7ef299fb90> block4c_se_squeeze True
# <keras.layers.core.reshape.Reshape object at 0x7f7ef299f690> block4c_se_reshape True
# <keras.layers.convolutional.Conv2D object at 0x7f7ef18bffd0> block4c_se_reduce True
# <keras.layers.convolutional.Conv2D object at 0x7f7ef18baa50> block4c_se_expand True
# <keras.layers.merge.Multiply object at 0x7f7f1205b610> block4c_se_excite True
# <keras.layers.convolutional.Conv2D object at 0x7f7f12065490> block4c_project_conv True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7f12053550> block4c_project_bn True
# <keras.layers.core.dropout.Dropout object at 0x7f7ef1875dd0> block4c_drop True
# <keras.layers.merge.Add object at 0x7f7ef1875b10> block4c_add True
# <keras.layers.convolutional.Conv2D object at 0x7f7ef29ef390> block4d_expand_conv True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7ef29e2650> block4d_expand_bn True
# <keras.layers.core.activation.Activation object at 0x7f7ef29eab50> block4d_expand_activation True
# <keras.layers.convolutional.DepthwiseConv2D object at 0x7f7ef29dba90> block4d_dwconv True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7ef18cbb10> block4d_bn True
# <keras.layers.core.activation.Activation object at 0x7f7ef1895690> block4d_activation True
# <keras.layers.pooling.GlobalAveragePooling2D object at 0x7f7ef18190d0> block4d_se_squeeze True
# <keras.layers.core.reshape.Reshape object at 0x7f7ef18198d0> block4d_se_reshape True
# <keras.layers.convolutional.Conv2D object at 0x7f7ef1819c10> block4d_se_reduce True
# <keras.layers.convolutional.Conv2D object at 0x7f7f1207e2d0> block4d_se_expand True
# <keras.layers.merge.Multiply object at 0x7f7f120f0350> block4d_se_excite True
# <keras.layers.convolutional.Conv2D object at 0x7f7ef29c3a50> block4d_project_conv True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7ef19730d0> block4d_project_bn True
# <keras.layers.core.dropout.Dropout object at 0x7f7ef18f1250> block4d_drop True
# <keras.layers.merge.Add object at 0x7f7ef18b10d0> block4d_add True
# <keras.layers.convolutional.Conv2D object at 0x7f7f120b9090> block4e_expand_conv True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7f800541d0> block4e_expand_bn True
# <keras.layers.core.activation.Activation object at 0x7f7ef188bfd0> block4e_expand_activation True
# <keras.layers.convolutional.DepthwiseConv2D object at 0x7f7ef2a1f990> block4e_dwconv True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7ef17c8f50> block4e_bn True
# <keras.layers.core.activation.Activation object at 0x7f7f120c9150> block4e_activation True
# <keras.layers.pooling.GlobalAveragePooling2D object at 0x7f7f80092790> block4e_se_squeeze True
# <keras.layers.core.reshape.Reshape object at 0x7f7f8008a090> block4e_se_reshape True
# <keras.layers.convolutional.Conv2D object at 0x7f7f80021410> block4e_se_reduce True
# <keras.layers.convolutional.Conv2D object at 0x7f7ef17c2510> block4e_se_expand True
# <keras.layers.merge.Multiply object at 0x7f7ef1822410> block4e_se_excite True
# <keras.layers.convolutional.Conv2D object at 0x7f7ef2a78950> block4e_project_conv True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7ef2a6c850> block4e_project_bn True
# <keras.layers.core.dropout.Dropout object at 0x7f7ef2a60ad0> block4e_drop True
# <keras.layers.merge.Add object at 0x7f7f80082f90> block4e_add True
# <keras.layers.convolutional.Conv2D object at 0x7f7f8011c150> block4f_expand_conv True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7f800ace10> block4f_expand_bn True
# <keras.layers.core.activation.Activation object at 0x7f7ef1794e10> block4f_expand_activation True
# <keras.layers.convolutional.DepthwiseConv2D object at 0x7f7ef1937150> block4f_dwconv True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7ef2a41550> block4f_bn True
# <keras.layers.core.activation.Activation object at 0x7f7ef19cfa50> block4f_activation True
# <keras.layers.pooling.GlobalAveragePooling2D object at 0x7f7ef1835810> block4f_se_squeeze True
# <keras.layers.core.reshape.Reshape object at 0x7f7ef18354d0> block4f_se_reshape True
# <keras.layers.convolutional.Conv2D object at 0x7f7ef2ab5a90> block4f_se_reduce True
# <keras.layers.convolutional.Conv2D object at 0x7f7f800a5910> block4f_se_expand True
# <keras.layers.merge.Multiply object at 0x7f7ef185b4d0> block4f_se_excite True
# <keras.layers.convolutional.Conv2D object at 0x7f7eebaf9650> block4f_project_conv True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7ef1745fd0> block4f_project_bn True
# <keras.layers.core.dropout.Dropout object at 0x7f7f801393d0> block4f_drop True
# <keras.layers.merge.Add object at 0x7f7ef179ec10> block4f_add True
# <keras.layers.convolutional.Conv2D object at 0x7f7f80140d10> block5a_expand_conv True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7f120798d0> block5a_expand_bn True
# <keras.layers.core.activation.Activation object at 0x7f7ef184cb50> block5a_expand_activation True
# <keras.layers.convolutional.DepthwiseConv2D object at 0x7f7f80173790> block5a_dwconv True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7f80161310> block5a_bn True
# <keras.layers.core.activation.Activation object at 0x7f7ef2aefa50> block5a_activation True
# <keras.layers.pooling.GlobalAveragePooling2D object at 0x7f7ef17a5910> block5a_se_squeeze True
# <keras.layers.core.reshape.Reshape object at 0x7f7ef17a5250> block5a_se_reshape True
# <keras.layers.convolutional.Conv2D object at 0x7f7f80184950> block5a_se_reduce True
# <keras.layers.convolutional.Conv2D object at 0x7f7f80132ed0> block5a_se_expand True
# <keras.layers.merge.Multiply object at 0x7f7ef17ebdd0> block5a_se_excite True
# <keras.layers.convolutional.Conv2D object at 0x7f7f8ecdd450> block5a_project_conv True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7f8eccc150> block5a_project_bn True
# <keras.layers.convolutional.Conv2D object at 0x7f7ef2ac0350> block5b_expand_conv True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7ef176d910> block5b_expand_bn True
# <keras.layers.core.activation.Activation object at 0x7f7ef2b2b990> block5b_expand_activation True
# <keras.layers.convolutional.DepthwiseConv2D object at 0x7f7ef2b2b4d0> block5b_dwconv True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7ef172f990> block5b_bn True
# <keras.layers.core.activation.Activation object at 0x7f7f8ed3a090> block5b_activation True
# <keras.layers.pooling.GlobalAveragePooling2D object at 0x7f7f8ed52a90> block5b_se_squeeze True
# <keras.layers.core.reshape.Reshape object at 0x7f7eebbeff90> block5b_se_reshape True
# <keras.layers.convolutional.Conv2D object at 0x7f7ef17518d0> block5b_se_reduce True
# <keras.layers.convolutional.Conv2D object at 0x7f7ef2b0dcd0> block5b_se_expand True
# <keras.layers.merge.Multiply object at 0x7f7ef1738850> block5b_se_excite True
# <keras.layers.convolutional.Conv2D object at 0x7f7ef1862810> block5b_project_conv True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7ef2b672d0> block5b_project_bn True
# <keras.layers.core.dropout.Dropout object at 0x7f7ef17387d0> block5b_drop True
# <keras.layers.merge.Add object at 0x7f7f8ed28850> block5b_add True
# <keras.layers.convolutional.Conv2D object at 0x7f7f8ed28c90> block5c_expand_conv True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7ef16db8d0> block5c_expand_bn True
# <keras.layers.core.activation.Activation object at 0x7f7ef17156d0> block5c_expand_activation True
# <keras.layers.convolutional.DepthwiseConv2D object at 0x7f7ef1706f50> block5c_dwconv True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7ef16d0290> block5c_bn True
# <keras.layers.core.activation.Activation object at 0x7f7ef16e9550> block5c_activation True
# <keras.layers.pooling.GlobalAveragePooling2D object at 0x7f7ef16e9a10> block5c_se_squeeze True
# <keras.layers.core.reshape.Reshape object at 0x7f7ef16c1ad0> block5c_se_reshape True
# <keras.layers.convolutional.Conv2D object at 0x7f7ef16c1690> block5c_se_reduce True
# <keras.layers.convolutional.Conv2D object at 0x7f7f8ee50bd0> block5c_se_expand True
# <keras.layers.merge.Multiply object at 0x7f7ef17be1d0> block5c_se_excite True
# <keras.layers.convolutional.Conv2D object at 0x7f7f8ee8e550> block5c_project_conv True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7eebc40550> block5c_project_bn True
# <keras.layers.core.dropout.Dropout object at 0x7f7ef2ba44d0> block5c_drop True
# <keras.layers.merge.Add object at 0x7f7ef17aaf10> block5c_add True
# <keras.layers.convolutional.Conv2D object at 0x7f7ef17fd850> block5d_expand_conv True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7ef183bf10> block5d_expand_bn True
# <keras.layers.core.activation.Activation object at 0x7f7f8007ac50> block5d_expand_activation True
# <keras.layers.convolutional.DepthwiseConv2D object at 0x7f7ef1767610> block5d_dwconv True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7f8ee22c90> block5d_bn True
# <keras.layers.core.activation.Activation object at 0x7f7ef2b88c10> block5d_activation True
# <keras.layers.pooling.GlobalAveragePooling2D object at 0x7f7ef2b821d0> block5d_se_squeeze True
# <keras.layers.core.reshape.Reshape object at 0x7f7ef2b82410> block5d_se_reshape True
# <keras.layers.convolutional.Conv2D object at 0x7f7ef1727810> block5d_se_reduce True
# <keras.layers.convolutional.Conv2D object at 0x7f7f8eeefb50> block5d_se_expand True
# <keras.layers.merge.Multiply object at 0x7f7f8eed0590> block5d_se_excite True
# <keras.layers.convolutional.Conv2D object at 0x7f7ef2bf4890> block5d_project_conv True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7ef2be1dd0> block5d_project_bn True
# <keras.layers.core.dropout.Dropout object at 0x7f7ef2bcfe90> block5d_drop True
# <keras.layers.merge.Add object at 0x7f7ef16a7f90> block5d_add True
# <keras.layers.convolutional.Conv2D object at 0x7f7ef2bc45d0> block5e_expand_conv True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7f8ef5d5d0> block5e_expand_bn True
# <keras.layers.core.activation.Activation object at 0x7f7f8ee87890> block5e_expand_activation True
# <keras.layers.convolutional.DepthwiseConv2D object at 0x7f7f8ee87f50> block5e_dwconv True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7f8efcca50> block5e_bn True
# <keras.layers.core.activation.Activation object at 0x7f7ef2c27cd0> block5e_activation True
# <keras.layers.pooling.GlobalAveragePooling2D object at 0x7f7ef2c1d210> block5e_se_squeeze True
# <keras.layers.core.reshape.Reshape object at 0x7f7ef2c19350> block5e_se_reshape True
# <keras.layers.convolutional.Conv2D object at 0x7f7f8eee5450> block5e_se_reduce True
# <keras.layers.convolutional.Conv2D object at 0x7f7ef16472d0> block5e_se_expand True
# <keras.layers.merge.Multiply object at 0x7f7f8f050310> block5e_se_excite True
# <keras.layers.convolutional.Conv2D object at 0x7f7f8f044750> block5e_project_conv True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7f8f05de50> block5e_project_bn True
# <keras.layers.core.dropout.Dropout object at 0x7f7ef2c38a10> block5e_drop True
# <keras.layers.merge.Add object at 0x7f7ef2c38e90> block5e_add True
# <keras.layers.convolutional.Conv2D object at 0x7f7ef17cf3d0> block5f_expand_conv True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7ef2c79710> block5f_expand_bn True
# <keras.layers.core.activation.Activation object at 0x7f7ef168ac90> block5f_expand_activation True
# <keras.layers.convolutional.DepthwiseConv2D object at 0x7f7ef1710cd0> block5f_dwconv True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7ef16ad150> block5f_bn True
# <keras.layers.core.activation.Activation object at 0x7f7f8f069b10> block5f_activation True
# <keras.layers.pooling.GlobalAveragePooling2D object at 0x7f7f8f03cf90> block5f_se_squeeze True
# <keras.layers.core.reshape.Reshape object at 0x7f7f8f063e90> block5f_se_reshape True
# <keras.layers.convolutional.Conv2D object at 0x7f7f8f063710> block5f_se_reduce True
# <keras.layers.convolutional.Conv2D object at 0x7f7f8f083050> block5f_se_expand True
# <keras.layers.merge.Multiply object at 0x7f7ef1660a50> block5f_se_excite True
# <keras.layers.convolutional.Conv2D object at 0x7f7ef16603d0> block5f_project_conv True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7ef298e410> block5f_project_bn True
# <keras.layers.core.dropout.Dropout object at 0x7f7ef2c6db10> block5f_drop True
# <keras.layers.merge.Add object at 0x7f7ef2c68c50> block5f_add True
# <keras.layers.convolutional.Conv2D object at 0x7f7eebe19350> block6a_expand_conv True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7ef16846d0> block6a_expand_bn True
# <keras.layers.core.activation.Activation object at 0x7f7f8f1103d0> block6a_expand_activation True
# <keras.layers.convolutional.ZeroPadding2D object at 0x7f7f8f107b10> block6a_dwconv_pad True
# <keras.layers.convolutional.DepthwiseConv2D object at 0x7f7f8f107110> block6a_dwconv True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7f8f0a5750> block6a_bn True
# <keras.layers.core.activation.Activation object at 0x7f7f8f0568d0> block6a_activation True
# <keras.layers.pooling.GlobalAveragePooling2D object at 0x7f7ef1784a10> block6a_se_squeeze True
# <keras.layers.core.reshape.Reshape object at 0x7f7ef1784710> block6a_se_reshape True
# <keras.layers.convolutional.Conv2D object at 0x7f7ef2cb8fd0> block6a_se_reduce True
# <keras.layers.convolutional.Conv2D object at 0x7f7ef1626190> block6a_se_expand True
# <keras.layers.merge.Multiply object at 0x7f7ef26f49d0> block6a_se_excite True
# <keras.layers.convolutional.Conv2D object at 0x7f7ef16fde10> block6a_project_conv True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7ef2cfd610> block6a_project_bn True
# <keras.layers.convolutional.Conv2D object at 0x7f7f8f16b5d0> block6b_expand_conv True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7ef15d3210> block6b_expand_bn True
# <keras.layers.core.activation.Activation object at 0x7f7f8f1649d0> block6b_expand_activation True
# <keras.layers.convolutional.DepthwiseConv2D object at 0x7f7f8f1c2790> block6b_dwconv True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7ef15f0c50> block6b_bn True
# <keras.layers.core.activation.Activation object at 0x7f7f8f1bb1d0> block6b_activation True
# <keras.layers.pooling.GlobalAveragePooling2D object at 0x7f7ef2cdae90> block6b_se_squeeze True
# <keras.layers.core.reshape.Reshape object at 0x7f7ef167ca90> block6b_se_reshape True
# <keras.layers.convolutional.Conv2D object at 0x7f7f8f1b5850> block6b_se_reduce True
# <keras.layers.convolutional.Conv2D object at 0x7f7ef2cce950> block6b_se_expand True
# <keras.layers.merge.Multiply object at 0x7f7ef159a1d0> block6b_se_excite True
# <keras.layers.convolutional.Conv2D object at 0x7f7ef1691b50> block6b_project_conv True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7ef166f610> block6b_project_bn True
# <keras.layers.core.dropout.Dropout object at 0x7f7f8f2483d0> block6b_drop True
# <keras.layers.merge.Add object at 0x7f7f8f2482d0> block6b_add True
# <keras.layers.convolutional.Conv2D object at 0x7f7eebf7e990> block6c_expand_conv True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7ef2d361d0> block6c_expand_bn True
# <keras.layers.core.activation.Activation object at 0x7f7ef2d2cc50> block6c_expand_activation True
# <keras.layers.convolutional.DepthwiseConv2D object at 0x7f7ef2d2cdd0> block6c_dwconv True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7ef2d20bd0> block6c_bn True
# <keras.layers.core.activation.Activation object at 0x7f7ef1e214d0> block6c_activation True
# <keras.layers.pooling.GlobalAveragePooling2D object at 0x7f7ef2d14c10> block6c_se_squeeze True
# <keras.layers.core.reshape.Reshape object at 0x7f7ef15b6690> block6c_se_reshape True
# <keras.layers.convolutional.Conv2D object at 0x7f7f8f252dd0> block6c_se_reduce True
# <keras.layers.convolutional.Conv2D object at 0x7f7f8f2a5f90> block6c_se_expand True
# <keras.layers.merge.Multiply object at 0x7f7f8f2c4450> block6c_se_excite True
# <keras.layers.convolutional.Conv2D object at 0x7f7ef2d100d0> block6c_project_conv True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7ef15ad150> block6c_project_bn True
# <keras.layers.core.dropout.Dropout object at 0x7f7ef2d01c90> block6c_drop True
# <keras.layers.merge.Add object at 0x7f7ef15e4190> block6c_add True
# <keras.layers.convolutional.Conv2D object at 0x7f7ef15e4790> block6d_expand_conv True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7ef2d75d10> block6d_expand_bn True
# <keras.layers.core.activation.Activation object at 0x7f7ef2d75610> block6d_expand_activation True
# <keras.layers.convolutional.DepthwiseConv2D object at 0x7f7f8f2b2a50> block6d_dwconv True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7ef1631f10> block6d_bn True
# <keras.layers.core.activation.Activation object at 0x7f7ef1510c10> block6d_activation True
# <keras.layers.pooling.GlobalAveragePooling2D object at 0x7f7f8f414c10> block6d_se_squeeze True
# <keras.layers.core.reshape.Reshape object at 0x7f7ef2dbc610> block6d_se_reshape True
# <keras.layers.convolutional.Conv2D object at 0x7f7ef2dbcbd0> block6d_se_reduce True
# <keras.layers.convolutional.Conv2D object at 0x7f7ef2daba90> block6d_se_expand True
# <keras.layers.merge.Multiply object at 0x7f7f8f1e3f50> block6d_se_excite True
# <keras.layers.convolutional.Conv2D object at 0x7f7f8f4cb690> block6d_project_conv True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7f8f4d9b10> block6d_project_bn True
# <keras.layers.core.dropout.Dropout object at 0x7f7ef2d99c90> block6d_drop True
# <keras.layers.merge.Add object at 0x7f7ef1576fd0> block6d_add True
# <keras.layers.convolutional.Conv2D object at 0x7f7ef154c0d0> block6e_expand_conv True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7eec065410> block6e_expand_bn True
# <keras.layers.core.activation.Activation object at 0x7f7ef2d88290> block6e_expand_activation True
# <keras.layers.convolutional.DepthwiseConv2D object at 0x7f7ef15d0a50> block6e_dwconv True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7ef2bef590> block6e_bn True
# <keras.layers.core.activation.Activation object at 0x7f7f8f529350> block6e_activation True
# <keras.layers.pooling.GlobalAveragePooling2D object at 0x7f7f8f544450> block6e_se_squeeze True
# <keras.layers.core.reshape.Reshape object at 0x7f7f8f544b90> block6e_se_reshape True
# <keras.layers.convolutional.Conv2D object at 0x7f7eec0b5450> block6e_se_reduce True
# <keras.layers.convolutional.Conv2D object at 0x7f7ef15369d0> block6e_se_expand True
# <keras.layers.merge.Multiply object at 0x7f7ef2de8410> block6e_se_excite True
# <keras.layers.convolutional.Conv2D object at 0x7f7ef1541d90> block6e_project_conv True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7ef2dda610> block6e_project_bn True
# <keras.layers.core.dropout.Dropout object at 0x7f7ef14c7210> block6e_drop True
# <keras.layers.merge.Add object at 0x7f7ef14c77d0> block6e_add True
# <keras.layers.convolutional.Conv2D object at 0x7f7eec0e1190> block6f_expand_conv True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7eec0d7250> block6f_expand_bn True
# <keras.layers.core.activation.Activation object at 0x7f7ef151f910> block6f_expand_activation True
# <keras.layers.convolutional.DepthwiseConv2D object at 0x7f7ef151fe10> block6f_dwconv True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7ef2e3a210> block6f_bn True
# <keras.layers.core.activation.Activation object at 0x7f7ef2e34b50> block6f_activation True
# <keras.layers.pooling.GlobalAveragePooling2D object at 0x7f7ef2e2a950> block6f_se_squeeze True
# <keras.layers.core.reshape.Reshape object at 0x7f7f8ee58b50> block6f_se_reshape True
# <keras.layers.convolutional.Conv2D object at 0x7f7f8ee58a90> block6f_se_reduce True
# <keras.layers.convolutional.Conv2D object at 0x7f7ef2e248d0> block6f_se_expand True
# <keras.layers.merge.Multiply object at 0x7f7ef2e0b810> block6f_se_excite True
# <keras.layers.convolutional.Conv2D object at 0x7f7ef2e0bc50> block6f_project_conv True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7f8f6ab5d0> block6f_project_bn True
# <keras.layers.core.dropout.Dropout object at 0x7f7f8f75bc10> block6f_drop True
# <keras.layers.merge.Add object at 0x7f7ef1494810> block6f_add True
# <keras.layers.convolutional.Conv2D object at 0x7f7ef2e7dd90> block6g_expand_conv True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7ef14a2d10> block6g_expand_bn True
# <keras.layers.core.activation.Activation object at 0x7f7f8f72b850> block6g_expand_activation True
# <keras.layers.convolutional.DepthwiseConv2D object at 0x7f7f8f81de50> block6g_dwconv True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7eec1a5f90> block6g_bn True
# <keras.layers.core.activation.Activation object at 0x7f7ef14af590> block6g_activation True
# <keras.layers.pooling.GlobalAveragePooling2D object at 0x7f7f8f8178d0> block6g_se_squeeze True
# <keras.layers.core.reshape.Reshape object at 0x7f7f8f8171d0> block6g_se_reshape True
# <keras.layers.convolutional.Conv2D object at 0x7f7ef2e4ef90> block6g_se_reduce True
# <keras.layers.convolutional.Conv2D object at 0x7f7ef1548090> block6g_se_expand True
# <keras.layers.merge.Multiply object at 0x7f7f8f88b050> block6g_se_excite True
# <keras.layers.convolutional.Conv2D object at 0x7f7f8f8a1150> block6g_project_conv True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7ef149a310> block6g_project_bn True
# <keras.layers.core.dropout.Dropout object at 0x7f7ef2eb33d0> block6g_drop True
# <keras.layers.merge.Add object at 0x7f7ef2ead050> block6g_add True
# <keras.layers.convolutional.Conv2D object at 0x7f7ef14e2b10> block6h_expand_conv True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7ef2e9a790> block6h_expand_bn True
# <keras.layers.core.activation.Activation object at 0x7f7ef1465450> block6h_expand_activation True
# <keras.layers.convolutional.DepthwiseConv2D object at 0x7f7ef1465a50> block6h_dwconv True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7ef0b14c50> block6h_bn True
# <keras.layers.core.activation.Activation object at 0x7f7f8f8bf2d0> block6h_activation True
# <keras.layers.pooling.GlobalAveragePooling2D object at 0x7f7f8f6a4c50> block6h_se_squeeze True
# <keras.layers.core.reshape.Reshape object at 0x7f7f8f6a4250> block6h_se_reshape True
# <keras.layers.convolutional.Conv2D object at 0x7f7ef2e872d0> block6h_se_reduce True
# <keras.layers.convolutional.Conv2D object at 0x7f7f8f95c550> block6h_se_expand True
# <keras.layers.merge.Multiply object at 0x7f7f8f879090> block6h_se_excite True
# <keras.layers.convolutional.Conv2D object at 0x7f7f8f879810> block6h_project_conv True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7ef2ee9090> block6h_project_bn True
# <keras.layers.core.dropout.Dropout object at 0x7f7ef142cd50> block6h_drop True
# <keras.layers.merge.Add object at 0x7f7ef2ee4d90> block6h_add True
# <keras.layers.convolutional.Conv2D object at 0x7f7ef2ed5050> block7a_expand_conv True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7ef14e8590> block7a_expand_bn True
# <keras.layers.core.activation.Activation object at 0x7f7ef13c5b90> block7a_expand_activation True
# <keras.layers.convolutional.DepthwiseConv2D object at 0x7f7ef2eceed0> block7a_dwconv True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7ef13d3e50> block7a_bn True
# <keras.layers.core.activation.Activation object at 0x7f7ef2f3c3d0> block7a_activation True
# <keras.layers.pooling.GlobalAveragePooling2D object at 0x7f7ef2f30650> block7a_se_squeeze True
# <keras.layers.core.reshape.Reshape object at 0x7f7ef0ad5f50> block7a_se_reshape True
# <keras.layers.convolutional.Conv2D object at 0x7f7f8f97d850> block7a_se_reduce True
# <keras.layers.convolutional.Conv2D object at 0x7f7f8f882d10> block7a_se_expand True
# <keras.layers.merge.Multiply object at 0x7f7f8f9be610> block7a_se_excite True
# <keras.layers.convolutional.Conv2D object at 0x7f7ef20f8590> block7a_project_conv True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7ef1470e50> block7a_project_bn True
# <keras.layers.convolutional.Conv2D object at 0x7f7ef2f0f990> block7b_expand_conv True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7ef152c610> block7b_expand_bn True
# <keras.layers.core.activation.Activation object at 0x7f7f8f736d10> block7b_expand_activation True
# <keras.layers.convolutional.DepthwiseConv2D object at 0x7f7f8f736750> block7b_dwconv True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7f8fa27ad0> block7b_bn True
# <keras.layers.core.activation.Activation object at 0x7f7f8f983dd0> block7b_activation True
# <keras.layers.pooling.GlobalAveragePooling2D object at 0x7f7f8f983fd0> block7b_se_squeeze True
# <keras.layers.core.reshape.Reshape object at 0x7f7ef2f7b810> block7b_se_reshape True
# <keras.layers.convolutional.Conv2D object at 0x7f7f8fa54a90> block7b_se_reduce True
# <keras.layers.convolutional.Conv2D object at 0x7f7ef2f742d0> block7b_se_expand True
# <keras.layers.merge.Multiply object at 0x7f7ef2f679d0> block7b_se_excite True
# <keras.layers.convolutional.Conv2D object at 0x7f7ef2f618d0> block7b_project_conv True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7ef143e690> block7b_project_bn True
# <keras.layers.core.dropout.Dropout object at 0x7f7f8fadb610> block7b_drop True
# <keras.layers.merge.Add object at 0x7f7f8fad30d0> block7b_add True
# <keras.layers.convolutional.Conv2D object at 0x7f7f8facc250> top_conv True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f7ef1c18bd0> top_bn True
# <keras.layers.core.activation.Activation object at 0x7f7ef2fb9dd0> top_activation True

# %%
for layer in loaded_model.layers[1].layers:
  if layer.trainable == False:
    print(layer, layer.name, layer.trainable)

# %%
for layer in base_model.layers:
  if layer.trainable == True:
    print(layer, layer.name)

# %%
len(loaded_model.layers)
# Out:
# 7

# %%
len(loaded_model.trainable_variables)
# Out:
# 420

# %%
len(base_model.trainable_variables)
# Out:
# 0

# %%
len(base_model.layers)
# Out:
# 474

# %% [markdown]
# ## Callback for Fine-Tuning All unfrozen layers

# %%
checpoint_fine_tuning= "checkpoints_fine_tuning_all"

checkpoint_callback_fine_tuning_all_unfrozen=model_check_point_callback(checpoint_fine_tuning, save_weights_only=True, save_best_only=True, monitor="val_accuracy")
tensorboard_callback_fine_tuning_all_unfrozen= create_tensorboard_callback("transfer_learning", "101_classes_fine_tuning_all_data_all_unfrozen_layers")
early_stopping_callback_fine_tuning_all_unfrozen= create_early_stopping_callback(monitor="val_loss", patience=5)
learning_rate_reduce_callback_all_unfrozen= reduce_learning_rate_callback(monitor="val_loss", factor=0.2, patience=2, minimum_lr=1e-7)
# Out:
# Saving TensorBoard log files to: transfer_learning/101_classes_fine_tuning_all_data_all_unfrozen_layers/20220817-054105

# %%
loaded_model.compile(loss="sparse_categorical_crossentropy", optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001), metrics=["accuracy"])

# %%
history_fine_tuned_all= loaded_model.fit(train_data, epochs=100, steps_per_epoch=len(train_data) ,validation_data= test_data, validation_steps=int(0.15 * len(test_data)), callbacks=[checkpoint_callback_fine_tuning_all_unfrozen, tensorboard_callback_fine_tuning_all_unfrozen, early_stopping_callback_fine_tuning_all_unfrozen, learning_rate_reduce_callback_all_unfrozen])
# Out:
# Epoch 1/100
# 2368/2368 [==============================] - ETA: 0s - loss: 1.1824 - accuracy: 0.7327
# Epoch 1: val_accuracy improved from -inf to 0.80191, saving model to checkpoints_fine_tuning_all
# 2368/2368 [==============================] - 810s 330ms/step - loss: 1.1824 - accuracy: 0.7327 - val_loss: 0.9101 - val_accuracy: 0.8019 - lr: 1.0000e-04
# Epoch 2/100
# 2368/2368 [==============================] - ETA: 0s - loss: 0.6606 - accuracy: 0.8663
# Epoch 2: val_accuracy improved from 0.80191 to 0.81012, saving model to checkpoints_fine_tuning_all
# 2368/2368 [==============================] - 771s 324ms/step - loss: 0.6606 - accuracy: 0.8663 - val_loss: 0.9025 - val_accuracy: 0.8101 - lr: 1.0000e-04
# Epoch 3/100
# 2368/2368 [==============================] - ETA: 0s - loss: 0.3901 - accuracy: 0.9376
# Epoch 3: val_accuracy improved from 0.81012 to 0.81118, saving model to checkpoints_fine_tuning_all
# 2368/2368 [==============================] - 781s 329ms/step - loss: 0.3901 - accuracy: 0.9376 - val_loss: 0.9736 - val_accuracy: 0.8112 - lr: 1.0000e-04
# Epoch 4/100
# 2368/2368 [==============================] - ETA: 0s - loss: 0.2955 - accuracy: 0.9646
# Epoch 4: val_accuracy did not improve from 0.81118
#
# Epoch 4: ReduceLROnPlateau reducing learning rate to 1.9999999494757503e-05.
# 2368/2368 [==============================] - 767s 323ms/step - loss: 0.2955 - accuracy: 0.9646 - val_loss: 1.0785 - val_accuracy: 0.8040 - lr: 1.0000e-04
# Epoch 5/100
# 2368/2368 [==============================] - ETA: 0s - loss: 0.2083 - accuracy: 0.9922
# Epoch 5: val_accuracy improved from 0.81118 to 0.83236, saving model to checkpoints_fine_tuning_all
# 2368/2368 [==============================] - 768s 324ms/step - loss: 0.2083 - accuracy: 0.9922 - val_loss: 0.9523 - val_accuracy: 0.8324 - lr: 2.0000e-05
# Epoch 6/100
# 2368/2368 [==============================] - ETA: 0s - loss: 0.1845 - accuracy: 0.9989
# Epoch 6: val_accuracy did not improve from 0.83236
#
# Epoch 6: ReduceLROnPlateau reducing learning rate to 3.999999898951501e-06.
# 2368/2368 [==============================] - 767s 323ms/step - loss: 0.1845 - accuracy: 0.9989 - val_loss: 0.9443 - val_accuracy: 0.8324 - lr: 2.0000e-05
# Epoch 7/100
# 2368/2368 [==============================] - ETA: 0s - loss: 0.1764 - accuracy: 0.9997
# Epoch 7: val_accuracy improved from 0.83236 to 0.83792, saving model to checkpoints_fine_tuning_all
# 2368/2368 [==============================] - 770s 324ms/step - loss: 0.1764 - accuracy: 0.9997 - val_loss: 0.9106 - val_accuracy: 0.8379 - lr: 4.0000e-06
# Epoch 7: early stopping

# %%
loaded_model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_layer (InputLayer)    [(None, 224, 224, 3)]     0
#
#  efficientnetb4 (Functional)  (None, None, None, 1792)  17673823
#
#  pooling_layer (GlobalAverag  (None, 1792)             0
#  ePooling2D)
#
#  dropout_layer (Dropout)     (None, 1792)              0
#
#  regularization_layer (Dense  (None, 101)              181093
#  )
#
#  dense (Dense)               (None, 101)               10302
#
#  softmax_float32 (Activation  (None, 101)              0
#  )
#
# =================================================================
# Total params: 17,865,218
# Trainable params: 17,740,011
# Non-trainable params: 125,207
# _________________________________________________________________

# %%
result_loaded_model_2=loaded_model.evaluate(test_data)
result_loaded_model_2
# Out:
# 790/790 [==============================] - 86s 109ms/step - loss: 0.9201 - accuracy: 0.8374
# [0.9201257228851318, 0.8373861312866211]

# %%
plot_loss_curves(history_fine_tuned_all)

# %% [markdown]
# ## Evaluating `loaded_model`

# %%
pred_probs=loaded_model.predict(test_data, verbose=1)
# Out:
# 790/790 [==============================] - 83s 100ms/step

# %%
pred_classes= pred_probs.argmax(axis=1)

pred_classes[:5]
# Out:
# array([29, 81, 91, 53, 97])

# %%
y_labels = []
test_images = []
for images, labels in test_data.unbatch():
  y_labels.append(labels.numpy())
y_labels[:10]
# Out:
# [29, 81, 91, 53, 97, 97, 10, 31, 3, 100]

# %% [markdown]
# ## Accuracy Score

# %%
sklearn_accuracy= accuracy_score(y_true= y_labels, y_pred= pred_classes)
sklearn_accuracy
# Out:
# 0.8373861386138614

# %% [markdown]
# ## Confusion Matrix

# %%
cm = confusion_matrix(y_labels, pred_classes)
# Normalise
cmn = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]==0
fig, ax = plt.subplots(figsize=(50,50))
sns.heatmap(cmn, annot=True, fmt='.2f', xticklabels=class_names, yticklabels=class_names)
plt.ylabel('Actual')
plt.xlabel('Predicted')
plt.show(block=False)

# %% [markdown]
# ## Classification Report

# %%
print(classification_report(y_true= y_labels, y_pred= pred_classes))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.64      0.63      0.63       250
#            1       0.82      0.82      0.82       250
#            2       0.85      0.88      0.87       250
#            3       0.81      0.86      0.84       250
#            4       0.81      0.79      0.80       250
#            5       0.76      0.74      0.75       250
#            6       0.83      0.90      0.87       250
#            7       0.95      0.92      0.94       250
#            8       0.66      0.64      0.65       250
#            9       0.84      0.77      0.80       250
#           10       0.79      0.76      0.78       250
#           11       0.80      0.92      0.86       250
#           12       0.90      0.85      0.87       250
#           13       0.83      0.87      0.85       250
#           14       0.83      0.82      0.82       250
#           15       0.70      0.68      0.69       250
#           16       0.78      0.72      0.75       250
#           17       0.90      0.88      0.89       250
#           18       0.80      0.76      0.78       250
#           19       0.83      0.82      0.83       250
#           20       0.87      0.91      0.89       250
#           21       0.76      0.74      0.75       250
#           22       0.67      0.65      0.66       250
#           23       0.91      0.90      0.91       250
#           24       0.90      0.92      0.91       250
#           25       0.91      0.90      0.90       250
#           26       0.73      0.77      0.75       250
#           27       0.90      0.91      0.90       250
#           28       0.88      0.88      0.88       250
#           29       0.90      0.91      0.90       250
#           30       0.95      0.93      0.94       250
#           31       0.87      0.86      0.86       250
#           32       0.92      0.88      0.90       250
#           33       0.98      1.00      0.99       250
#           34       0.89      0.90      0.89       250
#           35       0.90      0.90      0.90       250
#           36       0.81      0.77      0.79       250
#           37       0.71      0.67      0.69       250
#           38       0.85      0.92      0.88       250
#           39       0.67      0.62      0.64       250
#           40       0.88      0.96      0.91       250
#           41       0.85      0.85      0.85       250
#           42       0.75      0.78      0.76       250
#           43       0.84      0.86      0.85       250
#           44       0.85      0.90      0.88       250
#           45       0.89      0.94      0.92       250
#           46       0.79      0.82      0.80       250
#           47       0.77      0.78      0.78       250
#           48       0.82      0.86      0.84       250
#           49       0.74      0.83      0.78       250
#           50       0.78      0.78      0.78       250
#           51       0.90      0.91      0.91       250
#           52       0.88      0.87      0.87       250
#           53       0.82      0.82      0.82       250
#           54       0.92      0.96      0.94       250
#           55       0.93      0.90      0.91       250
#           56       0.75      0.71      0.73       250
#           57       0.86      0.78      0.82       250
#           58       0.79      0.76      0.77       250
#           59       0.84      0.75      0.79       250
#           60       0.89      0.89      0.89       250
#           61       0.92      0.88      0.90       250
#           62       0.84      0.81      0.83       250
#           63       0.95      0.95      0.95       250
#           64       0.95      0.91      0.93       250
#           65       0.95      0.91      0.93       250
#           66       0.84      0.84      0.84       250
#           67       0.78      0.77      0.77       250
#           68       0.90      0.90      0.90       250
#           69       0.92      0.96      0.94       250
#           70       0.88      0.94      0.91       250
#           71       0.87      0.85      0.86       250
#           72       0.84      0.89      0.87       250
#           73       0.82      0.78      0.80       250
#           74       0.92      0.86      0.89       250
#           75       0.91      0.94      0.93       250
#           76       0.91      0.94      0.93       250
#           77       0.67      0.61      0.64       250
#           78       0.89      0.90      0.89       250
#           79       0.84      0.85      0.85       250
#           80       0.83      0.85      0.84       250
#           81       0.91      0.88      0.89       250
#           82       0.70      0.74      0.72       250
#           83       0.88      0.90      0.89       250
#           84       0.78      0.71      0.75       250
#           85       0.90      0.84      0.87       250
#           86       0.90      0.94      0.92       250
#           87       0.77      0.73      0.75       250
#           88       0.91      0.92      0.91       250
#           89       0.78      0.82      0.80       250
#           90       0.93      0.93      0.93       250
#           91       0.94      0.96      0.95       250
#           92       0.88      0.86      0.87       250
#           93       0.52      0.58      0.55       250
#           94       0.79      0.80      0.79       250
#           95       0.87      0.85      0.86       250
#           96       0.75      0.77      0.76       250
#           97       0.90      0.91      0.90       250
#           98       0.82      0.82      0.82       250
#           99       0.68      0.71      0.70       250
#          100       0.90      0.92      0.91       250
#
#     accuracy                           0.84     25250
#    macro avg       0.84      0.84      0.84     25250
# weighted avg       0.84      0.84      0.84     25250

# %%
classification_report_dict= classification_report(y_labels, pred_classes, output_dict=True)
classification_report_dict
# Out:
# {'0': {'precision': 0.6408163265306123,
#   'recall': 0.628,
#   'f1-score': 0.6343434343434343,
#   'support': 250},
#  '1': {'precision': 0.82, 'recall': 0.82, 'f1-score': 0.82, 'support': 250},
#  '2': {'precision': 0.8532818532818532,
#   'recall': 0.884,
#   'f1-score': 0.8683693516699411,
#   'support': 250},
#  '3': {'precision': 0.8089887640449438,
#   'recall': 0.864,
#   'f1-score': 0.8355899419729206,
#   'support': 250},
#  '4': {'precision': 0.8114754098360656,
#   'recall': 0.792,
#   'f1-score': 0.8016194331983807,
#   'support': 250},
#  '5': {'precision': 0.7551020408163265,
#   'recall': 0.74,
#   'f1-score': 0.7474747474747474,
#   'support': 250},
#  '6': {'precision': 0.8339483394833949,
#   'recall': 0.904,
#   'f1-score': 0.8675623800383877,
#   'support': 250},
#  '7': {'precision': 0.9467213114754098,
#   'recall': 0.924,
#   'f1-score': 0.9352226720647773,
#   'support': 250},
#  '8': {'precision': 0.6597510373443983,
#   'recall': 0.636,
#   'f1-score': 0.6476578411405296,
#   'support': 250},
#  '9': {'precision': 0.8384279475982532,
#   'recall': 0.768,
#   'f1-score': 0.8016701461377871,
#   'support': 250},
#  '10': {'precision': 0.7892561983471075,
#   'recall': 0.764,
#   'f1-score': 0.7764227642276423,
#   'support': 250},
#  '11': {'precision': 0.8035087719298246,
#   'recall': 0.916,
#   'f1-score': 0.8560747663551401,
#   'support': 250},
#  '12': {'precision': 0.8987341772151899,
#   'recall': 0.852,
#   'f1-score': 0.8747433264887063,
#   'support': 250},
#  '13': {'precision': 0.8314176245210728,
#   'recall': 0.868,
#   'f1-score': 0.8493150684931506,
#   'support': 250},
#  '14': {'precision': 0.8259109311740891,
#   'recall': 0.816,
#   'f1-score': 0.8209255533199195,
#   'support': 250},
#  '15': {'precision': 0.6967213114754098,
#   'recall': 0.68,
#   'f1-score': 0.688259109311741,
#   'support': 250},
#  '16': {'precision': 0.7758620689655172,
#   'recall': 0.72,
#   'f1-score': 0.7468879668049794,
#   'support': 250},
#  '17': {'precision': 0.8975409836065574,
#   'recall': 0.876,
#   'f1-score': 0.8866396761133603,
#   'support': 250},
#  '18': {'precision': 0.799163179916318,
#   'recall': 0.764,
#   'f1-score': 0.7811860940695297,
#   'support': 250},
#  '19': {'precision': 0.8273092369477911,
#   'recall': 0.824,
#   'f1-score': 0.8256513026052105,
#   'support': 250},
#  '20': {'precision': 0.8735632183908046,
#   'recall': 0.912,
#   'f1-score': 0.8923679060665362,
#   'support': 250},
#  '21': {'precision': 0.7603305785123967,
#   'recall': 0.736,
#   'f1-score': 0.7479674796747968,
#   'support': 250},
#  '22': {'precision': 0.6735537190082644,
#   'recall': 0.652,
#   'f1-score': 0.6626016260162602,
#   'support': 250},
#  '23': {'precision': 0.9076305220883534,
#   'recall': 0.904,
#   'f1-score': 0.9058116232464929,
#   'support': 250},
#  '24': {'precision': 0.8980392156862745,
#   'recall': 0.916,
#   'f1-score': 0.906930693069307,
#   'support': 250},
#  '25': {'precision': 0.9105691056910569,
#   'recall': 0.896,
#   'f1-score': 0.903225806451613,
#   'support': 250},
#  '26': {'precision': 0.7272727272727273,
#   'recall': 0.768,
#   'f1-score': 0.7470817120622568,
#   'support': 250},
#  '27': {'precision': 0.9007936507936508,
#   'recall': 0.908,
#   'f1-score': 0.9043824701195219,
#   'support': 250},
#  '28': {'precision': 0.8795180722891566,
#   'recall': 0.876,
#   'f1-score': 0.8777555110220441,
#   'support': 250},
#  '29': {'precision': 0.8972332015810277,
#   'recall': 0.908,
#   'f1-score': 0.9025844930417496,
#   'support': 250},
#  '30': {'precision': 0.9510204081632653,
#   'recall': 0.932,
#   'f1-score': 0.9414141414141414,
#   'support': 250},
#  '31': {'precision': 0.8663967611336032,
#   'recall': 0.856,
#   'f1-score': 0.8611670020120724,
#   'support': 250},
#  '32': {'precision': 0.9163179916317992,
#   'recall': 0.876,
#   'f1-score': 0.8957055214723927,
#   'support': 250},
#  '33': {'precision': 0.9764705882352941,
#   'recall': 0.996,
#   'f1-score': 0.986138613861386,
#   'support': 250},
#  '34': {'precision': 0.8924302788844621,
#   'recall': 0.896,
#   'f1-score': 0.8942115768463074,
#   'support': 250},
#  '35': {'precision': 0.900398406374502,
#   'recall': 0.904,
#   'f1-score': 0.9021956087824352,
#   'support': 250},
#  '36': {'precision': 0.8135593220338984,
#   'recall': 0.768,
#   'f1-score': 0.7901234567901235,
#   'support': 250},
#  '37': {'precision': 0.7148936170212766,
#   'recall': 0.672,
#   'f1-score': 0.6927835051546393,
#   'support': 250},
#  '38': {'precision': 0.8518518518518519,
#   'recall': 0.92,
#   'f1-score': 0.8846153846153846,
#   'support': 250},
#  '39': {'precision': 0.670995670995671,
#   'recall': 0.62,
#   'f1-score': 0.6444906444906445,
#   'support': 250},
#  '40': {'precision': 0.8754578754578755,
#   'recall': 0.956,
#   'f1-score': 0.9139579349904398,
#   'support': 250},
#  '41': {'precision': 0.848,
#   'recall': 0.848,
#   'f1-score': 0.848,
#   'support': 250},
#  '42': {'precision': 0.7461538461538462,
#   'recall': 0.776,
#   'f1-score': 0.7607843137254902,
#   'support': 250},
#  '43': {'precision': 0.84251968503937,
#   'recall': 0.856,
#   'f1-score': 0.8492063492063492,
#   'support': 250},
#  '44': {'precision': 0.8549618320610687,
#   'recall': 0.896,
#   'f1-score': 0.875,
#   'support': 250},
#  '45': {'precision': 0.8935361216730038,
#   'recall': 0.94,
#   'f1-score': 0.9161793372319688,
#   'support': 250},
#  '46': {'precision': 0.7854406130268199,
#   'recall': 0.82,
#   'f1-score': 0.8023483365949119,
#   'support': 250},
#  '47': {'precision': 0.7747035573122529,
#   'recall': 0.784,
#   'f1-score': 0.7793240556660039,
#   'support': 250},
#  '48': {'precision': 0.8199233716475096,
#   'recall': 0.856,
#   'f1-score': 0.837573385518591,
#   'support': 250},
#  '49': {'precision': 0.7402135231316725,
#   'recall': 0.832,
#   'f1-score': 0.7834274952919021,
#   'support': 250},
#  '50': {'precision': 0.784,
#   'recall': 0.784,
#   'f1-score': 0.7840000000000001,
#   'support': 250},
#  '51': {'precision': 0.9011857707509882,
#   'recall': 0.912,
#   'f1-score': 0.9065606361829026,
#   'support': 250},
#  '52': {'precision': 0.8785425101214575,
#   'recall': 0.868,
#   'f1-score': 0.8732394366197184,
#   'support': 250},
#  '53': {'precision': 0.8232931726907631,
#   'recall': 0.82,
#   'f1-score': 0.8216432865731463,
#   'support': 250},
#  '54': {'precision': 0.9230769230769231,
#   'recall': 0.96,
#   'f1-score': 0.9411764705882353,
#   'support': 250},
#  '55': {'precision': 0.9294605809128631,
#   'recall': 0.896,
#   'f1-score': 0.9124236252545824,
#   'support': 250},
#  '56': {'precision': 0.7478991596638656,
#   'recall': 0.712,
#   'f1-score': 0.7295081967213115,
#   'support': 250},
#  '57': {'precision': 0.8552631578947368,
#   'recall': 0.78,
#   'f1-score': 0.8158995815899581,
#   'support': 250},
#  '58': {'precision': 0.7907949790794979,
#   'recall': 0.756,
#   'f1-score': 0.7730061349693252,
#   'support': 250},
#  '59': {'precision': 0.8392857142857143,
#   'recall': 0.752,
#   'f1-score': 0.7932489451476793,
#   'support': 250},
#  '60': {'precision': 0.888,
#   'recall': 0.888,
#   'f1-score': 0.888,
#   'support': 250},
#  '61': {'precision': 0.9246861924686193,
#   'recall': 0.884,
#   'f1-score': 0.9038854805725972,
#   'support': 250},
#  '62': {'precision': 0.8388429752066116,
#   'recall': 0.812,
#   'f1-score': 0.8252032520325203,
#   'support': 250},
#  '63': {'precision': 0.9518072289156626,
#   'recall': 0.948,
#   'f1-score': 0.9498997995991985,
#   'support': 250},
#  '64': {'precision': 0.9539748953974896,
#   'recall': 0.912,
#   'f1-score': 0.9325153374233129,
#   'support': 250},
#  '65': {'precision': 0.95,
#   'recall': 0.912,
#   'f1-score': 0.9306122448979591,
#   'support': 250},
#  '66': {'precision': 0.8433734939759037,
#   'recall': 0.84,
#   'f1-score': 0.8416833667334669,
#   'support': 250},
#  '67': {'precision': 0.7751004016064257,
#   'recall': 0.772,
#   'f1-score': 0.7735470941883766,
#   'support': 250},
#  '68': {'precision': 0.9032258064516129,
#   'recall': 0.896,
#   'f1-score': 0.8995983935742972,
#   'support': 250},
#  '69': {'precision': 0.9227799227799228,
#   'recall': 0.956,
#   'f1-score': 0.9390962671905697,
#   'support': 250},
#  '70': {'precision': 0.8838951310861424,
#   'recall': 0.944,
#   'f1-score': 0.9129593810444875,
#   'support': 250},
#  '71': {'precision': 0.8658536585365854,
#   'recall': 0.852,
#   'f1-score': 0.8588709677419355,
#   'support': 250},
#  '72': {'precision': 0.8446969696969697,
#   'recall': 0.892,
#   'f1-score': 0.8677042801556422,
#   'support': 250},
#  '73': {'precision': 0.8158995815899581,
#   'recall': 0.78,
#   'f1-score': 0.7975460122699386,
#   'support': 250},
#  '74': {'precision': 0.9224137931034483,
#   'recall': 0.856,
#   'f1-score': 0.8879668049792531,
#   'support': 250},
#  '75': {'precision': 0.9108527131782945,
#   'recall': 0.94,
#   'f1-score': 0.9251968503937008,
#   'support': 250},
#  '76': {'precision': 0.9111969111969112,
#   'recall': 0.944,
#   'f1-score': 0.9273084479371315,
#   'support': 250},
#  '77': {'precision': 0.6652173913043479,
#   'recall': 0.612,
#   'f1-score': 0.6375,
#   'support': 250},
#  '78': {'precision': 0.8888888888888888,
#   'recall': 0.896,
#   'f1-score': 0.8924302788844621,
#   'support': 250},
#  '79': {'precision': 0.841897233201581,
#   'recall': 0.852,
#   'f1-score': 0.8469184890656064,
#   'support': 250},
#  '80': {'precision': 0.8313725490196079,
#   'recall': 0.848,
#   'f1-score': 0.8396039603960396,
#   'support': 250},
#  '81': {'precision': 0.9087136929460581,
#   'recall': 0.876,
#   'f1-score': 0.8920570264765784,
#   'support': 250},
#  '82': {'precision': 0.6992481203007519,
#   'recall': 0.744,
#   'f1-score': 0.7209302325581395,
#   'support': 250},
#  '83': {'precision': 0.8784313725490196,
#   'recall': 0.896,
#   'f1-score': 0.8871287128712871,
#   'support': 250},
#  '84': {'precision': 0.7841409691629956,
#   'recall': 0.712,
#   'f1-score': 0.7463312368972747,
#   'support': 250},
#  '85': {'precision': 0.8974358974358975,
#   'recall': 0.84,
#   'f1-score': 0.8677685950413223,
#   'support': 250},
#  '86': {'precision': 0.9042145593869731,
#   'recall': 0.944,
#   'f1-score': 0.923679060665362,
#   'support': 250},
#  '87': {'precision': 0.774468085106383,
#   'recall': 0.728,
#   'f1-score': 0.7505154639175258,
#   'support': 250},
#  '88': {'precision': 0.9051383399209486,
#   'recall': 0.916,
#   'f1-score': 0.9105367793240556,
#   'support': 250},
#  '89': {'precision': 0.7786259541984732,
#   'recall': 0.816,
#   'f1-score': 0.7968749999999999,
#   'support': 250},
#  '90': {'precision': 0.928,
#   'recall': 0.928,
#   'f1-score': 0.928,
#   'support': 250},
#  '91': {'precision': 0.9446640316205533,
#   'recall': 0.956,
#   'f1-score': 0.9502982107355865,
#   'support': 250},
#  '92': {'precision': 0.8811475409836066,
#   'recall': 0.86,
#   'f1-score': 0.8704453441295547,
#   'support': 250},
#  '93': {'precision': 0.5232974910394266,
#   'recall': 0.584,
#   'f1-score': 0.5519848771266542,
#   'support': 250},
#  '94': {'precision': 0.78515625,
#   'recall': 0.804,
#   'f1-score': 0.7944664031620554,
#   'support': 250},
#  '95': {'precision': 0.8724279835390947,
#   'recall': 0.848,
#   'f1-score': 0.8600405679513186,
#   'support': 250},
#  '96': {'precision': 0.748062015503876,
#   'recall': 0.772,
#   'f1-score': 0.7598425196850394,
#   'support': 250},
#  '97': {'precision': 0.9007936507936508,
#   'recall': 0.908,
#   'f1-score': 0.9043824701195219,
#   'support': 250},
#  '98': {'precision': 0.816,
#   'recall': 0.816,
#   'f1-score': 0.816,
#   'support': 250},
#  '99': {'precision': 0.6833976833976834,
#   'recall': 0.708,
#   'f1-score': 0.6954813359528487,
#   'support': 250},
#  '100': {'precision': 0.8953488372093024,
#   'recall': 0.924,
#   'f1-score': 0.9094488188976377,
#   'support': 250},
#  'accuracy': 0.8373861386138614,
#  'macro avg': {'precision': 0.8375562082062316,
#   'recall': 0.8373861386138616,
#   'f1-score': 0.8370290815693582,
#   'support': 25250},
#  'weighted avg': {'precision': 0.8375562082062314,
#   'recall': 0.8373861386138614,
#   'f1-score': 0.8370290815693583,
#   'support': 25250}}

# %% [markdown]
# ## Visualizing the F1-score

# %%
class_f1_scores= {}

# Looping through the classification report dictionary items
for k, v in classification_report_dict.items():
  if k == "accuracy":
    break

  else:
    class_f1_scores[class_names[int(k)]] = v["f1-score"]


class_f1_scores
# Out:
# {'apple_pie': 0.6343434343434343,
#  'baby_back_ribs': 0.82,
#  'baklava': 0.8683693516699411,
#  'beef_carpaccio': 0.8355899419729206,
#  'beef_tartare': 0.8016194331983807,
#  'beet_salad': 0.7474747474747474,
#  'beignets': 0.8675623800383877,
#  'bibimbap': 0.9352226720647773,
#  'bread_pudding': 0.6476578411405296,
#  'breakfast_burrito': 0.8016701461377871,
#  'bruschetta': 0.7764227642276423,
#  'caesar_salad': 0.8560747663551401,
#  'cannoli': 0.8747433264887063,
#  'caprese_salad': 0.8493150684931506,
#  'carrot_cake': 0.8209255533199195,
#  'ceviche': 0.688259109311741,
#  'cheesecake': 0.7468879668049794,
#  'cheese_plate': 0.8866396761133603,
#  'chicken_curry': 0.7811860940695297,
#  'chicken_quesadilla': 0.8256513026052105,
#  'chicken_wings': 0.8923679060665362,
#  'chocolate_cake': 0.7479674796747968,
#  'chocolate_mousse': 0.6626016260162602,
#  'churros': 0.9058116232464929,
#  'clam_chowder': 0.906930693069307,
#  'club_sandwich': 0.903225806451613,
#  'crab_cakes': 0.7470817120622568,
#  'creme_brulee': 0.9043824701195219,
#  'croque_madame': 0.8777555110220441,
#  'cup_cakes': 0.9025844930417496,
#  'deviled_eggs': 0.9414141414141414,
#  'donuts': 0.8611670020120724,
#  'dumplings': 0.8957055214723927,
#  'edamame': 0.986138613861386,
#  'eggs_benedict': 0.8942115768463074,
#  'escargots': 0.9021956087824352,
#  'falafel': 0.7901234567901235,
#  'filet_mignon': 0.6927835051546393,
#  'fish_and_chips': 0.8846153846153846,
#  'foie_gras': 0.6444906444906445,
#  'french_fries': 0.9139579349904398,
#  'french_onion_soup': 0.848,
#  'french_toast': 0.7607843137254902,
#  'fried_calamari': 0.8492063492063492,
#  'fried_rice': 0.875,
#  'frozen_yogurt': 0.9161793372319688,
#  'garlic_bread': 0.8023483365949119,
#  'gnocchi': 0.7793240556660039,
#  'greek_salad': 0.837573385518591,
#  'grilled_cheese_sandwich': 0.7834274952919021,
#  'grilled_salmon': 0.7840000000000001,
#  'guacamole': 0.9065606361829026,
#  'gyoza': 0.8732394366197184,
#  'hamburger': 0.8216432865731463,
#  'hot_and_sour_soup': 0.9411764705882353,
#  'hot_dog': 0.9124236252545824,
#  'huevos_rancheros': 0.7295081967213115,
#  'hummus': 0.8158995815899581,
#  'ice_cream': 0.7730061349693252,
#  'lasagna': 0.7932489451476793,
#  'lobster_bisque': 0.888,
#  'lobster_roll_sandwich': 0.9038854805725972,
#  'macaroni_and_cheese': 0.8252032520325203,
#  'macarons': 0.9498997995991985,
#  'miso_soup': 0.9325153374233129,
#  'mussels': 0.9306122448979591,
#  'nachos': 0.8416833667334669,
#  'omelette': 0.7735470941883766,
#  'onion_rings': 0.8995983935742972,
#  'oysters': 0.9390962671905697,
#  'pad_thai': 0.9129593810444875,
#  'paella': 0.8588709677419355,
#  'pancakes': 0.8677042801556422,
#  'panna_cotta': 0.7975460122699386,
#  'peking_duck': 0.8879668049792531,
#  'pho': 0.9251968503937008,
#  'pizza': 0.9273084479371315,
#  'pork_chop': 0.6375,
#  'poutine': 0.8924302788844621,
#  'prime_rib': 0.8469184890656064,
#  'pulled_pork_sandwich': 0.8396039603960396,
#  'ramen': 0.8920570264765784,
#  'ravioli': 0.7209302325581395,
#  'red_velvet_cake': 0.8871287128712871,
#  'risotto': 0.7463312368972747,
#  'samosa': 0.8677685950413223,
#  'sashimi': 0.923679060665362,
#  'scallops': 0.7505154639175258,
#  'seaweed_salad': 0.9105367793240556,
#  'shrimp_and_grits': 0.7968749999999999,
#  'spaghetti_bolognese': 0.928,
#  'spaghetti_carbonara': 0.9502982107355865,
#  'spring_rolls': 0.8704453441295547,
#  'steak': 0.5519848771266542,
#  'strawberry_shortcake': 0.7944664031620554,
#  'sushi': 0.8600405679513186,
#  'tacos': 0.7598425196850394,
#  'takoyaki': 0.9043824701195219,
#  'tiramisu': 0.816,
#  'tuna_tartare': 0.6954813359528487,
#  'waffles': 0.9094488188976377}

# %%
f1_scores= pd.DataFrame({"class_names": list(class_f1_scores.keys()), "f1-score": list(class_f1_scores.values())}).sort_values("f1-score", ascending=False)

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(12, 25))
scores = ax.barh(range(len(f1_scores)), f1_scores["f1-score"].values)
ax.set_yticks(range(len(f1_scores)))
ax.set_yticklabels(list(f1_scores["class_names"]))
ax.set_xlabel("f1-score")
ax.set_title("F1-Scores for 10 Different Classes")
ax.invert_yaxis(); # reverse the order

def autolabel(rects): # Modified version of: https://matplotlib.org/examples/api/barchart_demo.html
  """
  Attach a text label above each bar displaying its height (it's value).
  """
  for rect in rects:
    width = rect.get_width()
    ax.text(1.03*width, rect.get_y() + rect.get_height()/1.5,
            f"{width:.2f}",
            ha='center', va='bottom')

autolabel(scores)

# %% [markdown]
# ## Tensorboard

# %%
# !tensorboard dev upload --logdir ./transfer_learning \
--name "Transfer Learning on the Food101 dataset with EfficientNetB4" \
--description "Training a Transfer Learning model with EfficientNetB4 to beat the DeepFood paper which is based on the Food101 dataset." \
--one_shot

# %% [markdown]
# ### Tensorboard Link
#
# Link -> https://tensorboard.dev/experiment/WeVV8PPUROanjwTYBT9pog/#scalars

# %%
# !tensorboard dev list

# %% [markdown]
# ## Evaluating on custom dataset

# %%
# !wget https://storage.googleapis.com/ztm_tf_course/food_vision/custom_food_images.zip
# Out:
# --2022-08-17 07:18:43--  https://storage.googleapis.com/ztm_tf_course/food_vision/custom_food_images.zip
# Resolving storage.googleapis.com (storage.googleapis.com)... 74.125.200.128, 74.125.130.128, 74.125.68.128, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|74.125.200.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 13192985 (13M) [application/zip]
# Saving to: ‘custom_food_images.zip’
#
# custom_food_images. 100%[===================>]  12.58M  28.1MB/s    in 0.4s
#
# 2022-08-17 07:18:44 (28.1 MB/s) - ‘custom_food_images.zip’ saved [13192985/13192985]

# %%
unzip_data('custom_food_images.zip')

# %%
custom_food_images = ["custom_food_images/" + img_path for img_path in os.listdir("custom_food_images")]
custom_food_images
# Out:
# ['custom_food_images/pizza-dad.jpeg',
#  'custom_food_images/chicken_wings.jpeg',
#  'custom_food_images/steak.jpeg',
#  'custom_food_images/sushi.jpeg',
#  'custom_food_images/ramen.jpeg',
#  'custom_food_images/hamburger.jpeg']

# %%
for img in custom_food_images:
  img = load_and_prep_image(img, scale=False) # load in target image and turn it into tensor
  pred_prob = loaded_model.predict(tf.expand_dims(img, axis=0)) # make prediction on image with shape [None, 224, 224, 3]
  pred_class = class_names[pred_prob.argmax()] # find the predicted class label
  # Plot the image with appropriate annotations
  plt.figure()
  plt.imshow(img/255.) # imshow() requires float inputs to be normalized
  plt.title(f"pred: {pred_class}, prob: {pred_prob.max():.2f}")
  plt.axis(False)
