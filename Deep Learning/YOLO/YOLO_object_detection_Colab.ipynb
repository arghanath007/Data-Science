# %% [markdown]
# # Using YOLO for Object Detection
#
# Link -> https://www.youtube.com/watch?v=IfRMV2MY9n0&list=PLeo1K3hjS3uu7CxAacxVndI4bE_o3BDtO&index=33&t=262s
#
# Link -> https://www.youtube.com/watch?v=bTIKY2NYBUg (For Colab)

# %%
# !nvidia-smi
# Out:
# Sat Feb  5 04:07:58 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla K80           Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   71C    P8    76W / 149W |      0MiB / 11441MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %% [markdown]
# ## Cloning the Darknet Github repository
#
# Link ->  https://github.com/AlexeyAB/darknet/

# %%
import os
os.environ['PATH'] += ':/usr/local/cuda/bin'
# !rm -fr darknet
# !git clone https://github.com/AlexeyAB/darknet/
# Out:
# Cloning into 'darknet'...
# remote: Enumerating objects: 15395, done.
# remote: Total 15395 (delta 0), reused 0 (delta 0), pack-reused 15395
# Receiving objects: 100% (15395/15395), 13.99 MiB | 18.95 MiB/s, done.
# Resolving deltas: 100% (10354/10354), done.

# %% [markdown]
# ## Installing some dependencies

# %%
# !apt install gcc-5 g++-5 -y
# !ln -s /usr/bin/gcc-5 /usr/local/cuda/bin/gcc 
# !ln -s /usr/bin/g++-5 /usr/local/cuda/bin/g++
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# g++-5 is already the newest version (5.5.0-12ubuntu1).
# gcc-5 is already the newest version (5.5.0-12ubuntu1).
# The following packages were automatically installed and are no longer required:
#   cuda-command-line-tools-10-0 cuda-command-line-tools-10-1
#   cuda-command-line-tools-11-0 cuda-compiler-10-0 cuda-compiler-10-1
#   cuda-compiler-11-0 cuda-cuobjdump-10-0 cuda-cuobjdump-10-1
#   cuda-cuobjdump-11-0 cuda-cupti-10-0 cuda-cupti-10-1 cuda-cupti-11-0
#   cuda-cupti-dev-11-0 cuda-documentation-10-0 cuda-documentation-10-1
#   cuda-documentation-11-0 cuda-documentation-11-1 cuda-gdb-10-0 cuda-gdb-10-1
#   cuda-gdb-11-0 cuda-gpu-library-advisor-10-0 cuda-gpu-library-advisor-10-1
#   cuda-libraries-10-0 cuda-libraries-10-1 cuda-libraries-11-0
#   cuda-memcheck-10-0 cuda-memcheck-10-1 cuda-memcheck-11-0 cuda-nsight-10-0
# ...

# %% [markdown]
# ## Enabling GPU
#
# > Going into the darknet folder to enable the GPU and then compile the entire program

# %%
# %cd darknet
# !sed -i 's/GPU=0/GPU=1/g' Makefile #Initializing GPU
# !sed -i 's/OPENCV=0/OPENCV=1/g' Makefile
# !make
# Out:
# /content/darknet
# mkdir -p ./obj/
# mkdir -p backup
# chmod +x *.sh
# g++ -std=c++11 -std=c++11 -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/image_opencv.cpp -o obj/image_opencv.o
# ./src/image_opencv.cpp: In function ‘void draw_detections_cv_v3(void**, detection*, int, float, char**, image**, int, int)’:
# ./src/image_opencv.cpp:946:23: warning: variable ‘rgb’ set but not used [-Wunused-but-set-variable]
#                  float rgb[3];
#                        ^
# ./src/image_opencv.cpp: In function ‘void cv_draw_object(image, float*, int, int, int*, float*, int*, int, char**)’:
# ./src/image_opencv.cpp:1444:14: warning: unused variable ‘buff’ [-Wunused-variable]
#          char buff[100];
#               ^
# ...

# %% [markdown]
# ## Getting the YOLO weights file

# %%
# !wget https://pjreddie.com/media/files/yolov3.weights
# !chmod a+x ./darknet
# Out:
# --2022-02-05 04:09:17--  https://pjreddie.com/media/files/yolov3.weights
# Resolving pjreddie.com (pjreddie.com)... 128.208.4.108
# Connecting to pjreddie.com (pjreddie.com)|128.208.4.108|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 248007048 (237M) [application/octet-stream]
# Saving to: ‘yolov3.weights’
#
# yolov3.weights      100%[===================>] 236.52M  62.0MB/s    in 4.1s
#
# 2022-02-05 04:09:22 (58.0 MB/s) - ‘yolov3.weights’ saved [248007048/248007048]

# %% [markdown]
# ## Changing the working directory
#
# 1.   List item
# 2.   List item

# %%
# !pwd
# Out:
# /content/darknet

# %% [markdown]
# ## Downloading more dependencies

# %%
# !apt install ffmpeg libopencv-dev libgtk-3-dev python-numpy python3-numpy libdc1394-22 libdc1394-22-dev libjpeg-dev libtiff5-dev libavcodec-dev libavformat-dev libswscale-dev libxine2-dev libgstreamer1.0-dev libgstreamer-plugins-base1.0-dev libv4l-dev libtbb-dev qtbase5-dev libfaac-dev libmp3lame-dev libopencore-amrnb-dev libopencore-amrwb-dev libtheora-dev libvorbis-dev libxvidcore-dev x264 v4l-utils unzip
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# libjpeg-dev is already the newest version (8c-2ubuntu8).
# libmp3lame-dev is already the newest version (3.100-2).
# libtheora-dev is already the newest version (1.1.1+dfsg.1-14).
# libv4l-dev is already the newest version (1.14.2-1).
# libvorbis-dev is already the newest version (1.3.5-4.2).
# python-numpy is already the newest version (1:1.13.3-2ubuntu1).
# python3-numpy is already the newest version (1:1.13.3-2ubuntu1).
# libdc1394-22 is already the newest version (2.2.5-1).
# libdc1394-22-dev is already the newest version (2.2.5-1).
# libopencore-amrnb-dev is already the newest version (0.1.3-2.1).
# libopencore-amrwb-dev is already the newest version (0.1.3-2.1).
# libtbb-dev is already the newest version (2017~U7-8).
# libxine2-dev is already the newest version (1.2.8-2build2).
# libxvidcore-dev is already the newest version (2:1.3.5-1).
# ...

# %% [markdown]
# ## Uploading a file(image) to colab for object detection within the image.
#
# > This is a Colab build in function which will give us an upload button to upload the file
#
# Link -> https://www.youtube.com/watch?v=IGQBtbKSVhY(Video)

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-24c3a88b-8ac4-4d81-8a3c-57e1733866e8" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-24c3a88b-8ac4-4d81-8a3c-57e1733866e8">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving test.mp4 to test.mp4

# %%
# !./darknet detector demo cfg/coco.data cfg/yolov3.cfg yolov3.weights -dont_show test.mp4 -i 0 -out_filename output1.avi -thresh 0.7
# Out:
#  CUDA-version: 11010 (11020), GPU count: 1
#  OpenCV version: 3.2.0
# Demo
#  0 : compute_capability = 370, cudnn_half = 0, GPU: Tesla K80
# net.optimized_memory = 0
# mini_batch = 1, batch = 1, time_steps = 1, train = 0
#    layer   filters  size/strd(dil)      input                output
#    0 Create CUDA-stream - 0
# conv     32       3 x 3/ 1    416 x 416 x   3 ->  416 x 416 x  32 0.299 BF
#    1 conv     64       3 x 3/ 2    416 x 416 x  32 ->  208 x 208 x  64 1.595 BF
#    2 conv     32       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  32 0.177 BF
#    3 conv     64       3 x 3/ 1    208 x 208 x  32 ->  208 x 208 x  64 1.595 BF
#    4 Shortcut Layer: 1,  wt = 0, wn = 0, outputs: 208 x 208 x  64 0.003 BF
#    5 conv    128       3 x 3/ 2    208 x 208 x  64 ->  104 x 104 x 128 1.595 BF
#    6 conv     64       1 x 1/ 1    104 x 104 x 128 ->  104 x 104 x  64 0.177 BF
#    7 conv    128       3 x 3/ 1    104 x 104 x  64 ->  104 x 104 x 128 1.595 BF
# ...

# %% [markdown]
# ## Downloading the video which was processed for object detection by YOLO

# %%
from google.colab import files
files.download('output1.avi')

# %% [markdown]
# ## Trying a different video(traffic footage)
#
# Link -> https://www.youtube.com/watch?v=jjlBnrzSGjc&t=18s (Video of Traffic)

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-8cb9c372-6c47-4b22-9c2f-f062cad2b976" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8cb9c372-6c47-4b22-9c2f-f062cad2b976">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving traffic.mp4 to traffic.mp4

# %%
# !./darknet detector demo cfg/coco.data cfg/yolov3.cfg yolov3.weights -dont_show traffic.mp4 -i 0 -out_filename traffic.avi -thresh 0.7
# Out:
# Streaming output truncated to the last 5000 lines.
# car: 100%
# car: 99%
# car: 99%
# car: 99%
# car: 99%
# car: 98%
# car: 98%
# car: 97%
# car: 97%
# car: 96%
# car: 94%
# car: 94%
# car: 94%
# car: 93%
# car: 92%
# car: 91%
# car: 90%
# car: 87%
# car: 83%
# person: 86%
#
# FPS:11.8 	 AVG_FPS:11.2
#
#  cvWriteFrame
# Objects:
#
# bus: 94%
# bus: 80%
# car: 100%
# car: 99%
# car: 99%
# car: 99%
# car: 98%
# car: 98%
# car: 98%
# car: 97%
# car: 96%
# car: 96%
# car: 94%
# car: 92%
# car: 91%
# car: 90%
# car: 90%
# car: 90%
# car: 90%
# car: 89%
# car: 85%
# car: 74%
# car: 73%
# car: 70%
# person: 74%
#
# FPS:11.9 	 AVG_FPS:11.2
#
#  cvWriteFrame
# Objects:
#
# bus: 96%
# bus: 90%
# car: 100%
# car: 99%
# car: 99%
# car: 99%
# car: 99%
# car: 98%
# car: 97%
# car: 97%
# car: 96%
# car: 96%
# car: 93%
# car: 90%
# car: 90%
# car: 90%
# car: 90%
# car: 86%
# car: 85%
# car: 80%
# car: 78%
# car: 72%
# car: 71%
# person: 83%
#
# FPS:11.9 	 AVG_FPS:11.2
#
#  cvWriteFrame
# Objects:
# ...

# %%
from google.colab import files
files.download('traffic.avi')
