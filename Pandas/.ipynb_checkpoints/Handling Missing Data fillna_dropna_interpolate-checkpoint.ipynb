# %%
import pandas as pd
df= pd.read_csv('C:\\Users\\JohnWick\\Desktop\\Machine Learning\\Resources Folder\\pandas\\5_handling_missing_data_fillna_dropna_interpolate\\weather_data.csv')
df
# Out:
#          day  temperature  windspeed   event
# 0   1/1/2017         32.0        6.0    Rain
# 1   1/4/2017          NaN        9.0   Sunny
# 2   1/5/2017         28.0        NaN    Snow
# 3   1/6/2017          NaN        7.0     NaN
# 4   1/7/2017         32.0        NaN    Rain
# 5   1/8/2017          NaN        NaN   Sunny
# 6   1/9/2017          NaN        NaN     NaN
# 7  1/10/2017         34.0        8.0  Cloudy
# 8  1/11/2017         40.0       12.0   Sunny

# %%
import pandas as pd
df= pd.read_csv('C:\\Users\\JohnWick\\Desktop\\Machine Learning\\Resources Folder\\pandas\\5_handling_missing_data_fillna_dropna_interpolate\\weather_data.csv', parse_dates=['day'])
df
# Out:
#          day  temperature  windspeed   event
# 0 2017-01-01         32.0        6.0    Rain
# 1 2017-01-04          NaN        9.0   Sunny
# 2 2017-01-05         28.0        NaN    Snow
# 3 2017-01-06          NaN        7.0     NaN
# 4 2017-01-07         32.0        NaN    Rain
# 5 2017-01-08          NaN        NaN   Sunny
# 6 2017-01-09          NaN        NaN     NaN
# 7 2017-01-10         34.0        8.0  Cloudy
# 8 2017-01-11         40.0       12.0   Sunny

# %%
type(df.day[0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
type(df.day)
# Out:
# pandas.core.series.Series

# %%
new_df1= df.fillna(0)
new_df1
# Out:
#            temperature  windspeed   event
# day
# 1/1/2017          32.0        6.0    Rain
# 1/4/2017           0.0        9.0   Sunny
# 1/5/2017          28.0        0.0    Snow
# 1/6/2017           0.0        7.0       0
# 1/7/2017          32.0        0.0    Rain
# 1/8/2017           0.0        0.0   Sunny
# 1/9/2017           0.0        0.0       0
# 1/10/2017         34.0        8.0  Cloudy
# 1/11/2017         40.0       12.0   Sunny

# %%
new_df2=df.fillna({
    'temperature': 0,
    'windspeed': 0,
    'event': 'no event',
})
new_df2
# Out:
#            temperature  windspeed     event
# day
# 1/1/2017          32.0        6.0      Rain
# 1/4/2017           0.0        9.0     Sunny
# 1/5/2017          28.0        0.0      Snow
# 1/6/2017           0.0        7.0  no event
# 1/7/2017          32.0        0.0      Rain
# 1/8/2017           0.0        0.0     Sunny
# 1/9/2017           0.0        0.0  no event
# 1/10/2017         34.0        8.0    Cloudy
# 1/11/2017         40.0       12.0     Sunny

# %%
new_df3= df.fillna(method='ffill')
new_df3
# Out:
#            temperature  windspeed   event
# day
# 1/1/2017          32.0        6.0    Rain
# 1/4/2017          32.0        9.0   Sunny
# 1/5/2017          28.0        9.0    Snow
# 1/6/2017          28.0        7.0    Snow
# 1/7/2017          32.0        7.0    Rain
# 1/8/2017          32.0        7.0   Sunny
# 1/9/2017          32.0        7.0   Sunny
# 1/10/2017         34.0        8.0  Cloudy
# 1/11/2017         40.0       12.0   Sunny

# %%
new_df4= df.fillna(method='bfill')
new_df4
# Out:
#            temperature  windspeed   event
# day
# 1/1/2017          32.0        6.0    Rain
# 1/4/2017          28.0        9.0   Sunny
# 1/5/2017          28.0        7.0    Snow
# 1/6/2017          32.0        7.0    Rain
# 1/7/2017          32.0        8.0    Rain
# 1/8/2017          34.0        8.0   Sunny
# 1/9/2017          34.0        8.0  Cloudy
# 1/10/2017         34.0        8.0  Cloudy
# 1/11/2017         40.0       12.0   Sunny

# %%
new_df6= df.fillna(method='bfill', axis='columns')
new_df6
# Out:
#           temperature windspeed   event
# day
# 1/1/2017         32.0       6.0    Rain
# 1/4/2017          9.0       9.0   Sunny
# 1/5/2017         28.0      Snow    Snow
# 1/6/2017          7.0       7.0     NaN
# 1/7/2017         32.0      Rain    Rain
# 1/8/2017        Sunny     Sunny   Sunny
# 1/9/2017          NaN       NaN     NaN
# 1/10/2017        34.0       8.0  Cloudy
# 1/11/2017        40.0      12.0   Sunny

# %%
new_df7= df.fillna(method='ffill', axis='columns')
new_df7
# Out:
#           temperature windspeed   event
# day
# 1/1/2017         32.0       6.0    Rain
# 1/4/2017          NaN       9.0   Sunny
# 1/5/2017         28.0      28.0    Snow
# 1/6/2017          NaN       7.0     7.0
# 1/7/2017         32.0      32.0    Rain
# 1/8/2017          NaN       NaN   Sunny
# 1/9/2017          NaN       NaN     NaN
# 1/10/2017        34.0       8.0  Cloudy
# 1/11/2017        40.0      12.0   Sunny

# %%
new_df8= df.fillna(method='ffill',limit=1)
new_df8
# Out:
#            temperature  windspeed   event
# day
# 1/1/2017          32.0        6.0    Rain
# 1/4/2017          32.0        9.0   Sunny
# 1/5/2017          28.0        9.0    Snow
# 1/6/2017          28.0        7.0    Snow
# 1/7/2017          32.0        7.0    Rain
# 1/8/2017          32.0        NaN   Sunny
# 1/9/2017           NaN        NaN   Sunny
# 1/10/2017         34.0        8.0  Cloudy
# 1/11/2017         40.0       12.0   Sunny

# %%
new_df9= df.interpolate()
new_df9
# Out:
#            temperature  windspeed   event
# day
# 1/1/2017     32.000000       6.00    Rain
# 1/4/2017     30.000000       9.00   Sunny
# 1/5/2017     28.000000       8.00    Snow
# 1/6/2017     30.000000       7.00     NaN
# 1/7/2017     32.000000       7.25    Rain
# 1/8/2017     32.666667       7.50   Sunny
# 1/9/2017     33.333333       7.75     NaN
# 1/10/2017    34.000000       8.00  Cloudy
# 1/11/2017    40.000000      12.00   Sunny

# %%
new_df10= df.interpolate(method='time')
new_df10
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-28-ea610f19f0bd> in <module>
# ----> 1 new_df10= df.interpolate(method='time')
#       2 new_df10
#
# E:\Anaconda\lib\site-packages\pandas\core\generic.py in interpolate(self, method, axis, limit, inplace, limit_direction, limit_area, downcast, **kwargs)
#    7220                 "those NaNs before interpolating."
#    7221             )
# -> 7222         new_data = obj._mgr.interpolate(
#    7223             method=method,
#    7224             axis=axis,
#
# E:\Anaconda\lib\site-packages\pandas\core\internals\managers.py in interpolate(self, **kwargs)
#     591
#     592     def interpolate(self, **kwargs) -> "BlockManager":
# --> 593         return self.apply("interpolate", **kwargs)
#     594
#     595     def shift(self, periods: int, axis: int, fill_value) -> "BlockManager":
#
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-26-ea610f19f0bd> in <module>
# ----> 1 new_df10= df.interpolate(method='time')
#       2 new_df10
#
# E:\Anaconda\lib\site-packages\pandas\core\generic.py in interpolate(self, method, axis, limit, inplace, limit_direction, limit_area, downcast, **kwargs)
#    7220                 "those NaNs before interpolating."
#    7221             )
# -> 7222         new_data = obj._mgr.interpolate(
#    7223             method=method,
#    7224             axis=axis,
#
# E:\Anaconda\lib\site-packages\pandas\core\internals\managers.py in interpolate(self, **kwargs)
#     591
#     592     def interpolate(self, **kwargs) -> "BlockManager":
# --> 593         return self.apply("interpolate", **kwargs)
#     594
#     595     def shift(self, periods: int, axis: int, fill_value) -> "BlockManager":
#
# ...

# %%
import pandas as pd
df_new= pd.read_csv('C:\\Users\\JohnWick\\Desktop\\Machine Learning\\Resources Folder\\pandas\\5_handling_missing_data_fillna_dropna_interpolate\\weather_data.csv', parse_dates=['day'])
df_new
# Out:
#          day  temperature  windspeed   event
# 0 2017-01-01         32.0        6.0    Rain
# 1 2017-01-04          NaN        9.0   Sunny
# 2 2017-01-05         28.0        NaN    Snow
# 3 2017-01-06          NaN        7.0     NaN
# 4 2017-01-07         32.0        NaN    Rain
# 5 2017-01-08          NaN        NaN   Sunny
# 6 2017-01-09          NaN        NaN     NaN
# 7 2017-01-10         34.0        8.0  Cloudy
# 8 2017-01-11         40.0       12.0   Sunny

# %%
df_new.set_index('day', inplace=True)

# %%
df_new
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01         32.0        6.0    Rain
# 2017-01-04          NaN        9.0   Sunny
# 2017-01-05         28.0        NaN    Snow
# 2017-01-06          NaN        7.0     NaN
# 2017-01-07         32.0        NaN    Rain
# 2017-01-08          NaN        NaN   Sunny
# 2017-01-09          NaN        NaN     NaN
# 2017-01-10         34.0        8.0  Cloudy
# 2017-01-11         40.0       12.0   Sunny

# %%
df_new1=df_new.interpolate(method='time')
df_new1
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01    32.000000       6.00    Rain
# 2017-01-04    29.000000       9.00   Sunny
# 2017-01-05    28.000000       8.00    Snow
# 2017-01-06    30.000000       7.00     NaN
# 2017-01-07    32.000000       7.25    Rain
# 2017-01-08    32.666667       7.50   Sunny
# 2017-01-09    33.333333       7.75     NaN
# 2017-01-10    34.000000       8.00  Cloudy
# 2017-01-11    40.000000      12.00   Sunny

# %%
df_new2=df_new.dropna()
df_new2
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01         32.0        6.0    Rain
# 2017-01-10         34.0        8.0  Cloudy
# 2017-01-11         40.0       12.0   Sunny

# %%
df_new3=df_new.dropna(how='all')
df_new3
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01         32.0        6.0    Rain
# 2017-01-04          NaN        9.0   Sunny
# 2017-01-05         28.0        NaN    Snow
# 2017-01-06          NaN        7.0     NaN
# 2017-01-07         32.0        NaN    Rain
# 2017-01-08          NaN        NaN   Sunny
# 2017-01-10         34.0        8.0  Cloudy
# 2017-01-11         40.0       12.0   Sunny

# %%
df_new4=df_new.dropna(thresh=1)
df_new4
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01         32.0        6.0    Rain
# 2017-01-04          NaN        9.0   Sunny
# 2017-01-05         28.0        NaN    Snow
# 2017-01-06          NaN        7.0     NaN
# 2017-01-07         32.0        NaN    Rain
# 2017-01-08          NaN        NaN   Sunny
# 2017-01-10         34.0        8.0  Cloudy
# 2017-01-11         40.0       12.0   Sunny

# %%
df_new5=df_new.dropna(thresh=2)
df_new5
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01         32.0        6.0    Rain
# 2017-01-04          NaN        9.0   Sunny
# 2017-01-05         28.0        NaN    Snow
# 2017-01-07         32.0        NaN    Rain
# 2017-01-10         34.0        8.0  Cloudy
# 2017-01-11         40.0       12.0   Sunny

# %%
df_new5
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01         32.0        6.0    Rain
# 2017-01-04          NaN        9.0   Sunny
# 2017-01-05         28.0        NaN    Snow
# 2017-01-07         32.0        NaN    Rain
# 2017-01-10         34.0        8.0  Cloudy
# 2017-01-11         40.0       12.0   Sunny

# %%
dt=pd.date_range('01-01-2017', '01-11-2017')
dt
# Out:
# DatetimeIndex(['2017-01-01', '2017-01-02', '2017-01-03', '2017-01-04',
#                '2017-01-05', '2017-01-06', '2017-01-07', '2017-01-08',
#                '2017-01-09', '2017-01-10', '2017-01-11'],
#               dtype='datetime64[ns]', freq='D')

# %%
idx=pd.DatetimeIndex(dt)
idx
# Out:
# DatetimeIndex(['2017-01-01', '2017-01-02', '2017-01-03', '2017-01-04',
#                '2017-01-05', '2017-01-06', '2017-01-07', '2017-01-08',
#                '2017-01-09', '2017-01-10', '2017-01-11'],
#               dtype='datetime64[ns]', freq='D')

# %%
df_new5.reindex(idx)
# Out:
#             temperature  windspeed   event
# 2017-01-01         32.0        6.0    Rain
# 2017-01-02          NaN        NaN     NaN
# 2017-01-03          NaN        NaN     NaN
# 2017-01-04          NaN        9.0   Sunny
# 2017-01-05         28.0        NaN    Snow
# 2017-01-06          NaN        NaN     NaN
# 2017-01-07         32.0        NaN    Rain
# 2017-01-08          NaN        NaN     NaN
# 2017-01-09          NaN        NaN     NaN
# 2017-01-10         34.0        8.0  Cloudy
# 2017-01-11         40.0       12.0   Sunny
