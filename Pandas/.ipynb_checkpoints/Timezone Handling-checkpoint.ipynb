# %%
import pandas as pd
df=pd.read_csv('/home/arghanath/Documents/Machine Learning/Resources Folder/pandas/19_ts_timezone/msft.csv', header=1, index_col='Date Time', parse_dates=True)
df
# Out:
#                      Price
# Date Time
# 2017-08-17 09:00:00  72.38
# 2017-08-17 09:15:00  71.00
# 2017-08-17 09:30:00  71.67
# 2017-08-17 10:00:00  72.80
# 2017-08-17 10:30:00  73.00
# 2017-08-17 11:00:00  72.50

# %%
df.index
# Out:
# DatetimeIndex(['2017-08-17 09:00:00', '2017-08-17 09:15:00',
#                '2017-08-17 09:30:00', '2017-08-17 10:00:00',
#                '2017-08-17 10:30:00', '2017-08-17 11:00:00'],
#               dtype='datetime64[ns]', name='Date Time', freq=None)

# %%
df=df.tz_localize(tz='US/Eastern')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-d1833caa8e8a> in <module>
# ----> 1 df=df.tz_localize(tz='US/Eastern')
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in tz_localize(self, tz, axis, level, copy, ambiguous, nonexistent)
#    9944             if level not in (None, 0, ax.name):
#    9945                 raise ValueError(f"The level {level} is not valid")
# -> 9946             ax = _tz_localize(ax, tz, ambiguous, nonexistent)
#    9947
#    9948         result = self.copy(deep=copy)
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in _tz_localize(ax, tz, ambiguous, nonexistent)
#    9932                     ax = DatetimeIndex([], tz=tz)
#    9933             else:
# -> 9934                 ax = ax.tz_localize(tz, ambiguous=ambiguous, nonexistent=nonexistent)
#    9935             return ax
#    9936
#
# ...

# %%
df.index
# Out:
# DatetimeIndex(['2017-08-17 09:00:00-04:00', '2017-08-17 09:15:00-04:00',
#                '2017-08-17 09:30:00-04:00', '2017-08-17 10:00:00-04:00',
#                '2017-08-17 10:30:00-04:00', '2017-08-17 11:00:00-04:00'],
#               dtype='datetime64[ns, US/Eastern]', name='Date Time', freq=None)

# %%
dfNew=df.tz_convert(tz='Europe/berlin')
dfNew.index
# Out:
# DatetimeIndex(['2017-08-17 15:00:00+02:00', '2017-08-17 15:15:00+02:00',
#                '2017-08-17 15:30:00+02:00', '2017-08-17 16:00:00+02:00',
#                '2017-08-17 16:30:00+02:00', '2017-08-17 17:00:00+02:00'],
#               dtype='datetime64[ns, Europe/Berlin]', name='Date Time', freq=None)

# %%
dfNew
# Out:
#                            Price
# Date Time
# 2017-08-17 15:00:00+02:00  72.38
# 2017-08-17 15:15:00+02:00  71.00
# 2017-08-17 15:30:00+02:00  71.67
# 2017-08-17 16:00:00+02:00  72.80
# 2017-08-17 16:30:00+02:00  73.00
# 2017-08-17 17:00:00+02:00  72.50

# %%
from pytz import all_timezones
all_timezones
# Out:
# ['Africa/Abidjan',
#  'Africa/Accra',
#  'Africa/Addis_Ababa',
#  'Africa/Algiers',
#  'Africa/Asmara',
#  'Africa/Asmera',
#  'Africa/Bamako',
#  'Africa/Bangui',
#  'Africa/Banjul',
#  'Africa/Bissau',
#  'Africa/Blantyre',
#  'Africa/Brazzaville',
#  'Africa/Bujumbura',
#  'Africa/Cairo',
#  'Africa/Casablanca',
#  'Africa/Ceuta',
#  'Africa/Conakry',
#  'Africa/Dakar',
#  'Africa/Dar_es_Salaam',
#  'Africa/Djibouti',
#  'Africa/Douala',
#  'Africa/El_Aaiun',
#  'Africa/Freetown',
#  'Africa/Gaborone',
#  'Africa/Harare',
#  'Africa/Johannesburg',
#  'Africa/Juba',
#  'Africa/Kampala',
#  'Africa/Khartoum',
#  'Africa/Kigali',
#  'Africa/Kinshasa',
#  'Africa/Lagos',
#  'Africa/Libreville',
#  'Africa/Lome',
#  'Africa/Luanda',
#  'Africa/Lubumbashi',
#  'Africa/Lusaka',
#  'Africa/Malabo',
#  'Africa/Maputo',
#  'Africa/Maseru',
#  'Africa/Mbabane',
#  'Africa/Mogadishu',
#  'Africa/Monrovia',
#  'Africa/Nairobi',
#  'Africa/Ndjamena',
#  'Africa/Niamey',
#  'Africa/Nouakchott',
# ...

# %%
dfCalcutta= dfNew.tz_convert(tz='Asia/Calcutta')
dfCalcutta
# Out:
#                            Price
# Date Time
# 2017-08-17 18:30:00+05:30  72.38
# 2017-08-17 18:45:00+05:30  71.00
# 2017-08-17 19:00:00+05:30  71.67
# 2017-08-17 19:30:00+05:30  72.80
# 2017-08-17 20:00:00+05:30  73.00
# 2017-08-17 20:30:00+05:30  72.50

# %%
dfCalcutta.index
# Out:
# DatetimeIndex(['2017-08-17 18:30:00+05:30', '2017-08-17 18:45:00+05:30',
#                '2017-08-17 19:00:00+05:30', '2017-08-17 19:30:00+05:30',
#                '2017-08-17 20:00:00+05:30', '2017-08-17 20:30:00+05:30'],
#               dtype='datetime64[ns, Asia/Calcutta]', name='Date Time', freq=None)

# %%
dfKolkata=df.tz_convert(tz='Asia/Kolkata')
dfKolkata
# Out:
#                            Price
# Date Time
# 2017-08-17 18:30:00+05:30  72.38
# 2017-08-17 18:45:00+05:30  71.00
# 2017-08-17 19:00:00+05:30  71.67
# 2017-08-17 19:30:00+05:30  72.80
# 2017-08-17 20:00:00+05:30  73.00
# 2017-08-17 20:30:00+05:30  72.50

# %%
range=pd.date_range(start='10/5/2000', periods=20, freq='Q', tz='Asia/Kolkata')
range
# Out:
# DatetimeIndex(['2000-12-31 00:00:00+05:30', '2001-03-31 00:00:00+05:30',
#                '2001-06-30 00:00:00+05:30', '2001-09-30 00:00:00+05:30',
#                '2001-12-31 00:00:00+05:30', '2002-03-31 00:00:00+05:30',
#                '2002-06-30 00:00:00+05:30', '2002-09-30 00:00:00+05:30',
#                '2002-12-31 00:00:00+05:30', '2003-03-31 00:00:00+05:30',
#                '2003-06-30 00:00:00+05:30', '2003-09-30 00:00:00+05:30',
#                '2003-12-31 00:00:00+05:30', '2004-03-31 00:00:00+05:30',
#                '2004-06-30 00:00:00+05:30', '2004-09-30 00:00:00+05:30',
#                '2004-12-31 00:00:00+05:30', '2005-03-31 00:00:00+05:30',
#                '2005-06-30 00:00:00+05:30', '2005-09-30 00:00:00+05:30'],
#               dtype='datetime64[ns, Asia/Kolkata]', freq='Q-DEC')

# %%
rangeNew=pd.date_range(start='10/5/2000', periods=20, freq='Q', tz='dateutil/Asia/Kolkata')
rangeNew
# Out:
# DatetimeIndex(['2000-12-31 00:00:00+05:30', '2001-03-31 00:00:00+05:30',
#                '2001-06-30 00:00:00+05:30', '2001-09-30 00:00:00+05:30',
#                '2001-12-31 00:00:00+05:30', '2002-03-31 00:00:00+05:30',
#                '2002-06-30 00:00:00+05:30', '2002-09-30 00:00:00+05:30',
#                '2002-12-31 00:00:00+05:30', '2003-03-31 00:00:00+05:30',
#                '2003-06-30 00:00:00+05:30', '2003-09-30 00:00:00+05:30',
#                '2003-12-31 00:00:00+05:30', '2004-03-31 00:00:00+05:30',
#                '2004-06-30 00:00:00+05:30', '2004-09-30 00:00:00+05:30',
#                '2004-12-31 00:00:00+05:30', '2005-03-31 00:00:00+05:30',
#                '2005-06-30 00:00:00+05:30', '2005-09-30 00:00:00+05:30'],
#               dtype='datetime64[ns, tzfile('/usr/share/zoneinfo/Asia/Kolkata')]', freq='Q-DEC')

# %%
rngNew=pd.date_range(start='2017-08-22', periods=15, freq='30min')
rngNew
# Out:
# DatetimeIndex(['2017-08-22 00:00:00', '2017-08-22 00:30:00',
#                '2017-08-22 01:00:00', '2017-08-22 01:30:00',
#                '2017-08-22 02:00:00', '2017-08-22 02:30:00',
#                '2017-08-22 03:00:00', '2017-08-22 03:30:00',
#                '2017-08-22 04:00:00', '2017-08-22 04:30:00',
#                '2017-08-22 05:00:00', '2017-08-22 05:30:00',
#                '2017-08-22 06:00:00', '2017-08-22 06:30:00',
#                '2017-08-22 07:00:00'],
#               dtype='datetime64[ns]', freq='30T')

# %%
rangeNew
# Out:
# DatetimeIndex(['2000-12-31 00:00:00+05:30', '2001-03-31 00:00:00+05:30',
#                '2001-06-30 00:00:00+05:30', '2001-09-30 00:00:00+05:30',
#                '2001-12-31 00:00:00+05:30', '2002-03-31 00:00:00+05:30',
#                '2002-06-30 00:00:00+05:30', '2002-09-30 00:00:00+05:30',
#                '2002-12-31 00:00:00+05:30', '2003-03-31 00:00:00+05:30',
#                '2003-06-30 00:00:00+05:30', '2003-09-30 00:00:00+05:30',
#                '2003-12-31 00:00:00+05:30', '2004-03-31 00:00:00+05:30',
#                '2004-06-30 00:00:00+05:30', '2004-09-30 00:00:00+05:30',
#                '2004-12-31 00:00:00+05:30', '2005-03-31 00:00:00+05:30',
#                '2005-06-30 00:00:00+05:30', '2005-09-30 00:00:00+05:30'],
#               dtype='datetime64[ns, tzfile('/usr/share/zoneinfo/Asia/Kolkata')]', freq='Q-DEC')

# %%
s=pd.Series(index=rngNew, data=d)
s
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-42-a677a52531ad> in <module>
# ----> 1 s=pd.Series(index=rngNew, data=d)
#       2 s
#
# NameError: name 'd' is not defined
