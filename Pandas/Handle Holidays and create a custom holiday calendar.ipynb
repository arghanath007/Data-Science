# %%
import pandas as pd
df=pd.read_csv('/home/arghanath/Documents/Machine Learning/Resources Folder/pandas/16_ts_holidays/aapl_no_dates.csv')
df
# Out:
#       Open    High     Low   Close    Volume
# 0   144.88  145.30  143.10  143.50  14277848
# 1   143.69  144.79  142.72  144.09  21569557
# 2   143.02  143.50  142.41  142.73  24128782
# 3   142.90  144.75  142.90  144.18  19201712
# 4   144.11  145.95  143.37  145.06  21090636
# 5   144.73  145.85  144.38  145.53  19781836
# 6   145.87  146.18  144.82  145.74  24884478
# 7   145.50  148.49  145.44  147.77  25199373
# 8   147.97  149.33  147.33  149.04  20132061
# 9   148.82  150.90  148.57  149.56  23793456
# 10  149.20  150.13  148.67  150.08  17868792
# 11  150.48  151.42  149.95  151.02  20922969
# 12  151.50  151.74  150.19  150.34  17243748
# 13  149.99  150.44  148.88  150.27  26252630

# %%
from pandas.tseries.holiday import USFederalHolidayCalendar
from pandas.tseries.offsets import CustomBusinessDay

usb=CustomBusinessDay(calendar=USFederalHolidayCalendar())
usb

# %%
rng=pd.date_range(start='7/1/2017', end='7/21/2017', freq=usb)

# %%
df.set_index(rng,inplace=True)
df
# Out:
#               Open    High     Low   Close    Volume
# 2017-07-03  144.88  145.30  143.10  143.50  14277848
# 2017-07-05  143.69  144.79  142.72  144.09  21569557
# 2017-07-06  143.02  143.50  142.41  142.73  24128782
# 2017-07-07  142.90  144.75  142.90  144.18  19201712
# 2017-07-10  144.11  145.95  143.37  145.06  21090636
# 2017-07-11  144.73  145.85  144.38  145.53  19781836
# 2017-07-12  145.87  146.18  144.82  145.74  24884478
# 2017-07-13  145.50  148.49  145.44  147.77  25199373
# 2017-07-14  147.97  149.33  147.33  149.04  20132061
# 2017-07-17  148.82  150.90  148.57  149.56  23793456
# 2017-07-18  149.20  150.13  148.67  150.08  17868792
# 2017-07-19  150.48  151.42  149.95  151.02  20922969
# 2017-07-20  151.50  151.74  150.19  150.34  17243748
# 2017-07-21  149.99  150.44  148.88  150.27  26252630

# %%
from pandas.tseries.holiday import AbstractHolidayCalendar, nearest_workday, Holiday
class myBirthdayCalendar(AbstractHolidayCalendar):
    """
    My Birthday Calendar
    """
    rules=[
        Holiday('Argha birthday is', month=5, day=10)
    ]
    
    myBirthDay= CustomBusinessDay(calendar=myBirthdayCalendar())
    pd.date_range('5/1/2017', '5/30/2017', freq=myBirthDay)

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-c0845914b755> in <module>
# ----> 1 pd.date_range(start='4/1/2017', end='4/30/2017', freq=myc)
#
# NameError: name 'myc' is not defined

# %%
from pandas.tseries.holiday import AbstractHolidayCalendar, nearest_workday, Holiday
class myCalendar(AbstractHolidayCalendar):
    rules = [
        Holiday('My Birth Day', month=5, day=10),#, observance=nearest_workday),
    ]
    
my_bday = CustomBusinessDay(calendar=myCalendar())
pd.date_range('5/1/2017','5/30/2017',freq=my_bday)
# Out:
# DatetimeIndex(['2017-05-01', '2017-05-02', '2017-05-03', '2017-05-04',
#                '2017-05-05', '2017-05-08', '2017-05-09', '2017-05-11',
#                '2017-05-12', '2017-05-15', '2017-05-16', '2017-05-17',
#                '2017-05-18', '2017-05-19', '2017-05-22', '2017-05-23',
#                '2017-05-24', '2017-05-25', '2017-05-26', '2017-05-29',
#                '2017-05-30'],
#               dtype='datetime64[ns]', freq='C')

# %%
CustomBusinessDay(weekmask='Sun Mon Tue Wed Thu')
pd.date_range('5/1/2017','5/30/2017',freq='B')
# Out:
# DatetimeIndex(['2017-05-01', '2017-05-02', '2017-05-03', '2017-05-04',
#                '2017-05-05', '2017-05-08', '2017-05-09', '2017-05-10',
#                '2017-05-11', '2017-05-12', '2017-05-15', '2017-05-16',
#                '2017-05-17', '2017-05-18', '2017-05-19', '2017-05-22',
#                '2017-05-23', '2017-05-24', '2017-05-25', '2017-05-26',
#                '2017-05-29', '2017-05-30'],
#               dtype='datetime64[ns]', freq='B')
