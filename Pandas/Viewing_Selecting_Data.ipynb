# %%
import pandas as pd
car_sales=pd.read_csv('car-sales.csv')
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales.head()
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00

# %%
car_sales.loc[7] #Refers to index
# Out:
# Make                 Honda
# Colour                Blue
# Odometer (KM)        54738
# Doors                    4
# Price            $7,000.00
# Name: 7, dtype: object

# %%
car_sales.iloc[7] #iloc refers to position
# Out:
# Make                 Honda
# Colour                Blue
# Odometer (KM)        54738
# Doors                    4
# Price            $7,000.00
# Name: 7, dtype: object

# %%
car_sales.iloc[:7]
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00

# %%
car_sales['Colour']
# Out:
# 0    White
# 1      Red
# 2     Blue
# 3    Black
# 4    White
# 5    Green
# 6     Blue
# 7     Blue
# 8    White
# 9    White
# Name: Colour, dtype: object

# %%
car_sales[car_sales['Colour'] == 'Green']
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 5  Toyota  Green          99213      4  $4,500.00

# %%
car_sales['Make'].unique()
# Out:
# array(['Toyota', 'Honda', 'BMW', 'Nissan'], dtype=object)

# %%
pd.crosstab(car_sales['Make'], car_sales['Doors'])
# Out:
# Doors   3  4  5
# Make
# BMW     0  0  1
# Honda   0  3  0
# Nissan  0  2  0
# Toyota  1  3  0

# %%
car_sales['Doors'].plot()
# Out:
# <AxesSubplot:>

# %%
car_sales['Doors'].hist()
# Out:
# <AxesSubplot:>

# %%
car_sales['Price']=car_sales['Price'].str.replace('[\$\,\.]','').astype(int)
# Out:
# /tmp/ipykernel_20056/1522778397.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   car_sales['Price']=car_sales['Price'].str.replace('[\$\,\.]','').astype(int)

# %%
car_sales['Price'].hist()
# Out:
# <AxesSubplot:>

# %%
car_sales['Price']
# Out:
# 0     400000
# 1     500000
# 2     700000
# 3    2200000
# 4     350000
# 5     450000
# 6     750000
# 7     700000
# 8     625000
# 9     970000
# Name: Price, dtype: int64

# %%
car_sales['Price'].plot()
# Out:
# <AxesSubplot:>

# %%
car_sales['Make']=car_sales['Make'].str.lower()
car_sales['Make']
# Out:
# 0    toyota
# 1     honda
# 2    toyota
# 3       bmw
# 4    nissan
# 5    toyota
# 6     honda
# 7     honda
# 8    toyota
# 9    nissan
# Name: Make, dtype: object

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  toyota  White         150043      4   400000
# 1   honda    Red          87899      4   500000
# 2  toyota   Blue          32549      3   700000
# 3     bmw  Black          11179      5  2200000
# 4  nissan  White         213095      4   350000
# 5  toyota  Green          99213      4   450000
# 6   honda   Blue          45698      4   750000
# 7   honda   Blue          54738      4   700000
# 8  toyota  White          60000      4   625000
# 9  nissan  White          31600      4   970000

# %%
car_sales2=pd.read_csv('car-sales-missing-data.csv')
car_sales2
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_sales2['Odometer'].fillna(car_sales2['Odometer'].mean(), inplace=True)
car_sales2
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500
# 6   Honda    NaN   92302.666667    4.0   $7,500
# 7   Honda   Blue   92302.666667    4.0      NaN
# 8  Toyota  White   60000.000000    NaN      NaN
# 9     NaN  White   31600.000000    4.0   $9,700

# %% [markdown]
# ## 'Series' can be of Any length when we are adding it to the DataFrame whereas if we use a 'list' then it has to have the same length as the length of the DataFrame other it will give an error.

# %%
car_sales.sample(frac=0.5) #Fraction of the sample
# Out:
#      Make Colour  Odometer (KM)  Doors   Price
# 8  toyota  White          60000      4  625000
# 1   honda    Red          87899      4  500000
# 6   honda   Blue          45698      4  750000
# 7   honda   Blue          54738      4  700000
# 9  nissan  White          31600      4  970000

# %%
car_sales_shuffled=car_sales.sample(frac=1) #Taking the whole Dataset
car_sales_shuffled
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 9  nissan  White          31600      4   970000
# 0  toyota  White         150043      4   400000
# 8  toyota  White          60000      4   625000
# 4  nissan  White         213095      4   350000
# 5  toyota  Green          99213      4   450000
# 2  toyota   Blue          32549      3   700000
# 3     bmw  Black          11179      5  2200000
# 6   honda   Blue          45698      4   750000
# 1   honda    Red          87899      4   500000
# 7   honda   Blue          54738      4   700000

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  toyota  White         150043      4   400000
# 1   honda    Red          87899      4   500000
# 2  toyota   Blue          32549      3   700000
# 3     bmw  Black          11179      5  2200000
# 4  nissan  White         213095      4   350000
# 5  toyota  Green          99213      4   450000
# 6   honda   Blue          45698      4   750000
# 7   honda   Blue          54738      4   700000
# 8  toyota  White          60000      4   625000
# 9  nissan  White          31600      4   970000

# %%
# Selecting only a fraction of the Dataset. This is handy when were are working on a large amount or a huge Dataset.
car_sales_shuffled.sample(frac=0.4)
# Out:
#      Make Colour  Odometer (KM)  Doors   Price
# 6   honda   Blue          45698      4  750000
# 0  toyota  White         150043      4  400000
# 9  nissan  White          31600      4  970000
# 1   honda    Red          87899      4  500000

# %%
car_sales_shuffled.reset_index() #Reset the index as the name suggests. It adds the old index into a new column for the newly created DataFrame. Like Below.
# Out:
#    index    Make Colour  Odometer (KM)  Doors    Price
# 0      9  nissan  White          31600      4   970000
# 1      0  toyota  White         150043      4   400000
# 2      8  toyota  White          60000      4   625000
# 3      4  nissan  White         213095      4   350000
# 4      5  toyota  Green          99213      4   450000
# 5      2  toyota   Blue          32549      3   700000
# 6      3     bmw  Black          11179      5  2200000
# 7      6   honda   Blue          45698      4   750000
# 8      1   honda    Red          87899      4   500000
# 9      7   honda   Blue          54738      4   700000

# %%
car_sales_shuffled['Price']=car_sales_shuffled['Price'].apply(lambda x:x/100) #Lambda Function or anonymous function in python.
car_sales_shuffled
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 9  nissan  White          31600      4   9700.0
# 0  toyota  White         150043      4   4000.0
# 8  toyota  White          60000      4   6250.0
# 4  nissan  White         213095      4   3500.0
# 5  toyota  Green          99213      4   4500.0
# 2  toyota   Blue          32549      3   7000.0
# 3     bmw  Black          11179      5  22000.0
# 6   honda   Blue          45698      4   7500.0
# 1   honda    Red          87899      4   5000.0
# 7   honda   Blue          54738      4   7000.0

# %% [markdown]
# # Motivation
#
# ## Try it,run the code
# ## Search for it
# ## Try Again
# ## Ask
